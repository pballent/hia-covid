# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import os

# %% [markdown]
# ## Import Mobility Data

# %%
# keep FIPS as string to preserve leading zeroes
# https://www.google.com/covid19/mobility/

# %%
mob = pd.read_csv(r"/Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets/hia_covid_inputs/2020_US_Region_Mobility_Report.csv", dtype={'census_fips_code': 'str'} )

# %%
sns.displot(mob.date, height=4, aspect=2)

# %%
mob['date'] = mob['date'].astype('datetime64')

# %%
mob_renam_col = [i.replace('percent_change_from_baseline', 'PCT_CFB') for i in mob.columns]

# %%
mob.columns = mob_renam_col

# %%
mob_renam_col
# Out:
# ['country_region_code',
#  'country_region',
#  'sub_region_1',
#  'sub_region_2',
#  'metro_area',
#  'iso_3166_2_code',
#  'census_fips_code',
#  'date',
#  'retail_and_recreation_PCT_CFB',
#  'grocery_and_pharmacy_PCT_CFB',
#  'parks_PCT_CFB',
#  'transit_stations_PCT_CFB',
#  'workplaces_PCT_CFB',
#  'residential_PCT_CFB']

# %%
mob.dtypes
# Out:
# country_region_code                      object
# country_region                           object
# sub_region_1                             object
# sub_region_2                             object
# metro_area                              float64
# iso_3166_2_code                          object
# census_fips_code                         object
# date                             datetime64[ns]
# retail_and_recreation_PCT_CFB           float64
# grocery_and_pharmacy_PCT_CFB            float64
# parks_PCT_CFB                           float64
# transit_stations_PCT_CFB                float64
# workplaces_PCT_CFB                      float64
# residential_PCT_CFB                     float64
# dtype: object

# %%
mob.sort_values(by="date", inplace=True)

# %%
mob.head(5)
# Out:
#        country_region_code country_region sub_region_1      sub_region_2  \
# 0                       US  United States          NaN               NaN
# 78743                   US  United States      Florida   Escambia County
# 552960                  US  United States    Tennessee  Claiborne County
# 553394                  US  United States    Tennessee      Cocke County
# 78459                   US  United States      Florida      Duval County
#
#         metro_area iso_3166_2_code census_fips_code       date  \
# 0              NaN             NaN              NaN 2020-02-15
# 78743          NaN             NaN            12033 2020-02-15
# 552960         NaN             NaN            47025 2020-02-15
# 553394         NaN             NaN            47029 2020-02-15
# 78459          NaN             NaN            12031 2020-02-15
#
#         retail_and_recreation_PCT_CFB  grocery_and_pharmacy_PCT_CFB  \
# 0                                 6.0                           2.0
# 78743                             5.0                           0.0
# 552960                           -2.0                           9.0
# 553394                           13.0                           4.0
# 78459                             2.0                           0.0
#
#         parks_PCT_CFB  transit_stations_PCT_CFB  workplaces_PCT_CFB  \
# 0                15.0                       3.0                 2.0
# 78743            63.0                      15.0                 3.0
# 552960            NaN                       NaN                -5.0
# 553394          -10.0                       NaN                 4.0
# 78459            10.0                       5.0                -1.0
#
#         residential_PCT_CFB
# 0                      -1.0
# 78743                  -1.0
# 552960                  NaN
# 553394                  NaN
# 78459                  -1.0

# %% [markdown]
# ## Compute Rolling Average of Mobility Data

# %%
list_all_locations = list(mob.census_fips_code.unique())
list_frames = []
for i in list_all_locations:
    frame = mob[mob.census_fips_code == i]
    frame['retail_and_recreation_PCT_CFB_RollingAvg'] = frame.rolling(7, min_periods=7, center=False, on="date")['retail_and_recreation_PCT_CFB'].mean()
    frame['grocery_and_pharmacy_PCT_CFB_RollingAvg'] = frame.rolling(7, min_periods=7, center=False, on="date")['grocery_and_pharmacy_PCT_CFB'].mean()
    frame['parks_PCT_CFB_RollingAvg'] = frame.rolling(7, min_periods=7, center=False, on="date")['parks_PCT_CFB'].mean()
    frame['transit_stations_PCT_CFB_RollingAvg'] = frame.rolling(7, min_periods=7, center=False, on="date")['transit_stations_PCT_CFB'].mean()
    frame['workplaces_PCT_CFB_RollingAvg'] = frame.rolling(7, min_periods=7, center=False, on="date")['workplaces_PCT_CFB'].mean()
    frame['residential_PCT_CFB_RollingAvg'] = frame.rolling(7, min_periods=7, center=False, on="date")['residential_PCT_CFB'].mean()
    list_frames.append(frame)
# Out:
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
recombine = pd.concat(list_frames)

# %%
mobility_final = recombine

# %%
mobility_final[(mobility_final.census_fips_code == "12009") & (mobility_final.date > '2020-10-01')].head(-18)
# Out:
#       country_region_code country_region sub_region_1    sub_region_2  \
# 75966                  US  United States      Florida  Brevard County
# 75967                  US  United States      Florida  Brevard County
# 75968                  US  United States      Florida  Brevard County
# 75969                  US  United States      Florida  Brevard County
# 75970                  US  United States      Florida  Brevard County
# 75971                  US  United States      Florida  Brevard County
# 75972                  US  United States      Florida  Brevard County
# 75973                  US  United States      Florida  Brevard County
# 75974                  US  United States      Florida  Brevard County
# 75975                  US  United States      Florida  Brevard County
# 75976                  US  United States      Florida  Brevard County
# 75977                  US  United States      Florida  Brevard County
# 75978                  US  United States      Florida  Brevard County
# 75979                  US  United States      Florida  Brevard County
# 75980                  US  United States      Florida  Brevard County
# 75981                  US  United States      Florida  Brevard County
# 75982                  US  United States      Florida  Brevard County
# 75983                  US  United States      Florida  Brevard County
# 75984                  US  United States      Florida  Brevard County
# 75985                  US  United States      Florida  Brevard County
# 75986                  US  United States      Florida  Brevard County
# 75987                  US  United States      Florida  Brevard County
# 75988                  US  United States      Florida  Brevard County
# 75989                  US  United States      Florida  Brevard County
# 75990                  US  United States      Florida  Brevard County
# 75991                  US  United States      Florida  Brevard County
# 75992                  US  United States      Florida  Brevard County
# 75993                  US  United States      Florida  Brevard County
# 75994                  US  United States      Florida  Brevard County
# 75995                  US  United States      Florida  Brevard County
# 75996                  US  United States      Florida  Brevard County
# 75997                  US  United States      Florida  Brevard County
# 75998                  US  United States      Florida  Brevard County
# 75999                  US  United States      Florida  Brevard County
# 76000                  US  United States      Florida  Brevard County
# 76001                  US  United States      Florida  Brevard County
#
#        metro_area iso_3166_2_code census_fips_code       date  \
# 75966         NaN             NaN            12009 2020-10-02
# 75967         NaN             NaN            12009 2020-10-03
# 75968         NaN             NaN            12009 2020-10-04
# 75969         NaN             NaN            12009 2020-10-05
# 75970         NaN             NaN            12009 2020-10-06
# 75971         NaN             NaN            12009 2020-10-07
# 75972         NaN             NaN            12009 2020-10-08
# 75973         NaN             NaN            12009 2020-10-09
# 75974         NaN             NaN            12009 2020-10-10
# 75975         NaN             NaN            12009 2020-10-11
# 75976         NaN             NaN            12009 2020-10-12
# 75977         NaN             NaN            12009 2020-10-13
# 75978         NaN             NaN            12009 2020-10-14
# 75979         NaN             NaN            12009 2020-10-15
# 75980         NaN             NaN            12009 2020-10-16
# 75981         NaN             NaN            12009 2020-10-17
# 75982         NaN             NaN            12009 2020-10-18
# 75983         NaN             NaN            12009 2020-10-19
# 75984         NaN             NaN            12009 2020-10-20
# 75985         NaN             NaN            12009 2020-10-21
# 75986         NaN             NaN            12009 2020-10-22
# 75987         NaN             NaN            12009 2020-10-23
# 75988         NaN             NaN            12009 2020-10-24
# 75989         NaN             NaN            12009 2020-10-25
# 75990         NaN             NaN            12009 2020-10-26
# 75991         NaN             NaN            12009 2020-10-27
# 75992         NaN             NaN            12009 2020-10-28
# 75993         NaN             NaN            12009 2020-10-29
# 75994         NaN             NaN            12009 2020-10-30
# 75995         NaN             NaN            12009 2020-10-31
# 75996         NaN             NaN            12009 2020-11-01
# 75997         NaN             NaN            12009 2020-11-02
# 75998         NaN             NaN            12009 2020-11-03
# 75999         NaN             NaN            12009 2020-11-04
# 76000         NaN             NaN            12009 2020-11-05
# 76001         NaN             NaN            12009 2020-11-06
#
#        retail_and_recreation_PCT_CFB  grocery_and_pharmacy_PCT_CFB  \
# 75966                          -18.0                         -11.0
# 75967                          -23.0                         -15.0
# 75968                          -19.0                         -13.0
# 75969                          -22.0                         -14.0
# 75970                          -19.0                         -12.0
# 75971                          -19.0                         -11.0
# 75972                          -20.0                         -13.0
# 75973                          -19.0                         -12.0
# 75974                          -21.0                         -14.0
# 75975                          -20.0                         -15.0
# 75976                          -20.0                         -13.0
# 75977                          -19.0                         -12.0
# 75978                          -17.0                         -10.0
# 75979                          -18.0                         -11.0
# 75980                          -19.0                         -12.0
# 75981                          -19.0                         -12.0
# 75982                          -20.0                         -16.0
# 75983                          -22.0                         -17.0
# 75984                          -19.0                         -12.0
# 75985                          -18.0                         -10.0
# 75986                          -19.0                         -12.0
# 75987                          -19.0                         -12.0
# 75988                          -19.0                         -11.0
# 75989                          -19.0                         -14.0
# 75990                          -20.0                         -12.0
# 75991                          -17.0                         -10.0
# 75992                          -17.0                          -9.0
# 75993                          -16.0                         -10.0
# 75994                          -15.0                          -8.0
# 75995                          -17.0                          -7.0
# 75996                          -21.0                         -17.0
# 75997                          -19.0                         -11.0
# 75998                          -11.0                          -7.0
# 75999                          -20.0                         -13.0
# 76000                          -19.0                         -12.0
# 76001                          -19.0                         -12.0
#
#        parks_PCT_CFB  transit_stations_PCT_CFB  workplaces_PCT_CFB  \
# 75966           -6.0                     -16.0               -26.0
# 75967          -34.0                     -32.0               -17.0
# 75968          -32.0                     -24.0               -19.0
# 75969          -27.0                     -14.0               -28.0
# 75970          -10.0                      -9.0               -28.0
# 75971          -15.0                     -15.0               -27.0
# 75972           -3.0                      -8.0               -27.0
# 75973          -14.0                     -16.0               -26.0
# 75974          -19.0                     -30.0               -16.0
# 75975          -18.0                     -23.0               -18.0
# 75976           -9.0                     -15.0               -30.0
# 75977           -5.0                      -8.0               -27.0
# 75978          -12.0                     -14.0               -27.0
# 75979           -2.0                     -10.0               -27.0
# 75980          -10.0                     -13.0               -26.0
# 75981            8.0                     -23.0               -17.0
# 75982          -24.0                     -22.0               -19.0
# 75983          -29.0                     -14.0               -27.0
# 75984          -10.0                     -10.0               -27.0
# 75985          -22.0                     -18.0               -26.0
# 75986           -1.0                     -16.0               -26.0
# 75987          -10.0                     -20.0               -26.0
# 75988            3.0                     -30.0               -15.0
# 75989          -21.0                     -26.0               -18.0
# 75990          -11.0                     -18.0               -26.0
# 75991           -2.0                     -13.0               -26.0
# 75992           -7.0                     -19.0               -26.0
# 75993            2.0                     -14.0               -25.0
# 75994           -1.0                     -20.0               -25.0
# 75995            3.0                     -27.0               -14.0
# 75996          -39.0                     -31.0               -19.0
# 75997          -26.0                     -20.0               -26.0
# 75998            2.0                     -11.0               -27.0
# 75999          -20.0                     -19.0               -26.0
# 76000           -9.0                     -15.0               -26.0
# 76001          -17.0                     -21.0               -25.0
#
#        residential_PCT_CFB  retail_and_recreation_PCT_CFB_RollingAvg  \
# 75966                  6.0                                -19.571429
# 75967                  5.0                                -20.000000
# 75968                  4.0                                -20.142857
# 75969                  7.0                                -19.714286
# 75970                  7.0                                -19.571429
# 75971                  7.0                                -19.714286
# 75972                  7.0                                -20.000000
# 75973                  7.0                                -20.142857
# 75974                  5.0                                -19.857143
# 75975                  4.0                                -20.000000
# 75976                  7.0                                -19.714286
# 75977                  7.0                                -19.714286
# 75978                  7.0                                -19.428571
# 75979                  7.0                                -19.142857
# 75980                  7.0                                -19.142857
# 75981                  3.0                                -18.857143
# 75982                  4.0                                -18.857143
# 75983                  7.0                                -19.142857
# 75984                  8.0                                -19.142857
# 75985                  8.0                                -19.285714
# 75986                  7.0                                -19.428571
# 75987                  7.0                                -19.428571
# 75988                  3.0                                -19.428571
# 75989                  4.0                                -19.285714
# 75990                  6.0                                -19.000000
# 75991                  7.0                                -18.714286
# 75992                  6.0                                -18.571429
# 75993                  6.0                                -18.142857
# 75994                  6.0                                -17.571429
# 75995                  2.0                                -17.285714
# 75996                  4.0                                -17.571429
# 75997                  6.0                                -17.428571
# 75998                  7.0                                -16.571429
# 75999                  8.0                                -17.000000
# 76000                  7.0                                -17.428571
# 76001                  7.0                                -18.000000
#
#        grocery_and_pharmacy_PCT_CFB_RollingAvg  parks_PCT_CFB_RollingAvg  \
# 75966                               -12.285714                -13.428571
# 75967                               -12.857143                -18.857143
# 75968                               -13.000000                -22.000000
# 75969                               -12.428571                -20.714286
# 75970                               -12.428571                -18.428571
# 75971                               -12.571429                -18.571429
# 75972                               -12.714286                -18.142857
# 75973                               -12.857143                -19.285714
# 75974                               -12.714286                -17.142857
# 75975                               -13.000000                -15.142857
# 75976                               -12.857143                -12.571429
# 75977                               -12.857143                -11.857143
# 75978                               -12.714286                -11.428571
# 75979                               -12.428571                -11.285714
# 75980                               -12.428571                -10.714286
# 75981                               -12.142857                 -6.857143
# 75982                               -12.285714                 -7.714286
# 75983                               -12.857143                -10.571429
# 75984                               -12.857143                -11.285714
# 75985                               -12.857143                -12.714286
# 75986                               -13.000000                -12.571429
# 75987                               -13.000000                -12.571429
# 75988                               -12.857143                -13.285714
# 75989                               -12.571429                -12.857143
# 75990                               -11.857143                -10.285714
# 75991                               -11.571429                 -9.142857
# 75992                               -11.428571                 -7.000000
# 75993                               -11.142857                 -6.571429
# 75994                               -10.571429                 -5.285714
# 75995                               -10.000000                 -5.285714
# 75996                               -10.428571                 -7.857143
# 75997                               -10.285714                -10.000000
# 75998                                -9.857143                 -9.428571
# 75999                               -10.428571                -11.285714
# 76000                               -10.714286                -12.857143
# 76001                               -11.285714                -15.142857
#
#        transit_stations_PCT_CFB_RollingAvg  workplaces_PCT_CFB_RollingAvg  \
# 75966                           -20.142857                     -24.142857
# 75967                           -20.285714                     -24.428571
# 75968                           -19.714286                     -24.571429
# 75969                           -19.000000                     -24.571429
# 75970                           -18.000000                     -24.714286
# 75971                           -17.571429                     -24.571429
# 75972                           -16.857143                     -24.571429
# 75973                           -16.857143                     -24.571429
# 75974                           -16.571429                     -24.428571
# 75975                           -16.428571                     -24.285714
# 75976                           -16.571429                     -24.571429
# 75977                           -16.428571                     -24.428571
# 75978                           -16.285714                     -24.428571
# 75979                           -16.571429                     -24.428571
# 75980                           -16.142857                     -24.428571
# 75981                           -15.142857                     -24.571429
# 75982                           -15.000000                     -24.714286
# 75983                           -14.857143                     -24.285714
# 75984                           -15.142857                     -24.285714
# 75985                           -15.714286                     -24.142857
# 75986                           -16.571429                     -24.000000
# 75987                           -17.571429                     -24.000000
# 75988                           -18.571429                     -23.714286
# 75989                           -19.142857                     -23.571429
# 75990                           -19.714286                     -23.428571
# 75991                           -20.142857                     -23.285714
# 75992                           -20.285714                     -23.285714
# 75993                           -20.000000                     -23.142857
# 75994                           -20.000000                     -23.000000
# 75995                           -19.571429                     -22.857143
# 75996                           -20.285714                     -23.000000
# 75997                           -20.571429                     -23.000000
# 75998                           -20.285714                     -23.142857
# 75999                           -20.285714                     -23.142857
# 76000                           -20.428571                     -23.285714
# 76001                           -20.571429                     -23.285714
#
#        residential_PCT_CFB_RollingAvg
# 75966                        6.142857
# 75967                        6.285714
# 75968                        6.285714
# 75969                        6.142857
# 75970                        6.142857
# 75971                        6.142857
# 75972                        6.142857
# 75973                        6.285714
# 75974                        6.285714
# 75975                        6.285714
# 75976                        6.285714
# 75977                        6.285714
# 75978                        6.285714
# 75979                        6.285714
# 75980                        6.285714
# 75981                        6.000000
# 75982                        6.000000
# 75983                        6.000000
# 75984                        6.142857
# 75985                        6.285714
# 75986                        6.285714
# 75987                        6.285714
# 75988                        6.285714
# 75989                        6.285714
# 75990                        6.142857
# 75991                        6.000000
# 75992                        5.714286
# 75993                        5.571429
# 75994                        5.428571
# 75995                        5.285714
# 75996                        5.285714
# 75997                        5.285714
# 75998                        5.285714
# 75999                        5.571429
# 76000                        5.714286
# 76001                        5.857143

# %% [markdown]
# ## Join Full County-Level Dataset

# %%
counties = pd.read_csv(r"/Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets/counties_dataset_full.csv",dtype={'County_FIPS':'str'})

# %%
counties.dtypes
# Out:
# Unnamed: 0                 int64
# County_FIPS               object
# StateCD                   object
# Name                      object
# HS_DIPLOMA_ONLY_2018     float64
# SOME_COLLEGE_2018        float64
# BACHELORS_PLUS_2018      float64
# Poverty_PCT_2018         float64
# UrbanCD                    int64
# Median_Income_2018       float64
# Population_ACS           float64
# Population_Black_ACS     float64
# Population_Hisp_ACS      float64
# Population_Native_ACS    float64
# PCT_Black_ACS            float64
# PCT_Hisp_ACS             float64
# PCT_Native_ACS           float64
# UrbanCD_Description       object
# Metro                     object
# dtype: object

# %%
counties['census_fips_code'] = counties['County_FIPS'].astype('str')

# %%
mobility_counties = mobility_final.merge(counties, on = "census_fips_code", how="left")

# %%
mobility_counties.dtypes
# Out:
# country_region_code                                 object
# country_region                                      object
# sub_region_1                                        object
# sub_region_2                                        object
# metro_area                                         float64
# iso_3166_2_code                                     object
# census_fips_code                                    object
# date                                        datetime64[ns]
# retail_and_recreation_PCT_CFB                      float64
# grocery_and_pharmacy_PCT_CFB                       float64
# parks_PCT_CFB                                      float64
# transit_stations_PCT_CFB                           float64
# workplaces_PCT_CFB                                 float64
# residential_PCT_CFB                                float64
# retail_and_recreation_PCT_CFB_RollingAvg           float64
# grocery_and_pharmacy_PCT_CFB_RollingAvg            float64
# parks_PCT_CFB_RollingAvg                           float64
# transit_stations_PCT_CFB_RollingAvg                float64
# workplaces_PCT_CFB_RollingAvg                      float64
# residential_PCT_CFB_RollingAvg                     float64
# Unnamed: 0                                         float64
# County_FIPS                                         object
# StateCD                                             object
# Name                                                object
# HS_DIPLOMA_ONLY_2018                               float64
# SOME_COLLEGE_2018                                  float64
# BACHELORS_PLUS_2018                                float64
# Poverty_PCT_2018                                   float64
# UrbanCD                                            float64
# Median_Income_2018                                 float64
# Population_ACS                                     float64
# Population_Black_ACS                               float64
# Population_Hisp_ACS                                float64
# Population_Native_ACS                              float64
# PCT_Black_ACS                                      float64
# PCT_Hisp_ACS                                       float64
# PCT_Native_ACS                                     float64
# UrbanCD_Description                                 object
# Metro                                               object
# dtype: object

# %%
mobility_counties[mobility_counties.census_fips_code == ""]
# Out:
# Empty DataFrame
# Columns: [country_region_code, country_region, sub_region_1, sub_region_2, metro_area, iso_3166_2_code, census_fips_code, date, retail_and_recreation_PCT_CFB, grocery_and_pharmacy_PCT_CFB, parks_PCT_CFB, transit_stations_PCT_CFB, workplaces_PCT_CFB, residential_PCT_CFB, retail_and_recreation_PCT_CFB_RollingAvg, grocery_and_pharmacy_PCT_CFB_RollingAvg, parks_PCT_CFB_RollingAvg, transit_stations_PCT_CFB_RollingAvg, workplaces_PCT_CFB_RollingAvg, residential_PCT_CFB_RollingAvg, Unnamed: 0, County_FIPS, StateCD, Name, HS_DIPLOMA_ONLY_2018, SOME_COLLEGE_2018, BACHELORS_PLUS_2018, Poverty_PCT_2018, UrbanCD, Median_Income_2018, Population_ACS, Population_Black_ACS, Population_Hisp_ACS, Population_Native_ACS, PCT_Black_ACS, PCT_Hisp_ACS, PCT_Native_ACS, UrbanCD_Description, Metro]
# Index: []
#
# [0 rows x 39 columns]

# %%
mobility_counties.head(5)
# Out:
#   country_region_code country_region sub_region_1     sub_region_2  \
# 0                  US  United States      Florida  Escambia County
# 1                  US  United States      Florida  Escambia County
# 2                  US  United States      Florida  Escambia County
# 3                  US  United States      Florida  Escambia County
# 4                  US  United States      Florida  Escambia County
#
#    metro_area iso_3166_2_code census_fips_code       date  \
# 0         NaN             NaN            12033 2020-02-15
# 1         NaN             NaN            12033 2020-02-16
# 2         NaN             NaN            12033 2020-02-17
# 3         NaN             NaN            12033 2020-02-18
# 4         NaN             NaN            12033 2020-02-19
#
#    retail_and_recreation_PCT_CFB  grocery_and_pharmacy_PCT_CFB  ...  \
# 0                            5.0                           0.0  ...
# 1                            1.0                          -8.0  ...
# 2                            5.0                          -2.0  ...
# 3                            1.0                          -1.0  ...
# 4                            7.0                           0.0  ...
#
#    Median_Income_2018  Population_ACS  Population_Black_ACS  \
# 0             50644.0        309924.0               67398.0
# 1             50644.0        309924.0               67398.0
# 2             50644.0        309924.0               67398.0
# 3             50644.0        309924.0               67398.0
# 4             50644.0        309924.0               67398.0
#
#    Population_Hisp_ACS  Population_Native_ACS  PCT_Black_ACS  PCT_Hisp_ACS  \
# 0              16935.0                 1411.0      21.746622      5.464243
# 1              16935.0                 1411.0      21.746622      5.464243
# 2              16935.0                 1411.0      21.746622      5.464243
# 3              16935.0                 1411.0      21.746622      5.464243
# 4              16935.0                 1411.0      21.746622      5.464243
#
#    PCT_Native_ACS                                UrbanCD_Description  \
# 0        0.455273  In small metro area of less than 1 million res...
# 1        0.455273  In small metro area of less than 1 million res...
# 2        0.455273  In small metro area of less than 1 million res...
# 3        0.455273  In small metro area of less than 1 million res...
# 4        0.455273  In small metro area of less than 1 million res...
#
#            Metro
# 0  Smaller_metro
# 1  Smaller_metro
# 2  Smaller_metro
# 3  Smaller_metro
# 4  Smaller_metro
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Bring in the COVID Data to be Joined In

# %%
covid = pd.read_csv(r"/Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets/covid_dataset_full.csv",dtype={'County_FIPS':'str'})

# %%
covid.Date = covid.Date.astype("datetime64")

# %%
mobility_counties['Date'] = mobility_counties['date']

# %%
mobility_covid_urban = covid.merge(mobility_counties, on =['Date','County_FIPS'], how="left")

# %%
mobility_covid_urban[mobility_covid_urban.date.isna() == True]
# Out:
#          Unnamed: 0_x       Date   Admin2    State  Confirmed  Deaths  \
# 0                   0 2020-01-22  Autauga  Alabama          0       0
# 1                   1 2020-01-23  Autauga  Alabama          0       0
# 2                   2 2020-01-24  Autauga  Alabama          0       0
# 3                   3 2020-01-25  Autauga  Alabama          0       0
# 4                   4 2020-01-26  Autauga  Alabama          0       0
# ...               ...        ...      ...      ...        ...     ...
# 1033724       1015548 2020-11-15   Weston  Wyoming        339       0
# 1033730       1015554 2020-11-21   Weston  Wyoming        366       0
# 1033731       1015555 2020-11-22   Weston  Wyoming        372       0
# 1033734       1015558 2020-11-25   Weston  Wyoming        386       1
# 1033735       1015559 2020-11-26   Weston  Wyoming        386       1
#
#         Country/Region  Deaths_Previous  Confirmed_Previous  Deaths_New  ...  \
# 0                   US              NaN                 NaN         NaN  ...
# 1                   US              0.0                 0.0         0.0  ...
# 2                   US              0.0                 0.0         0.0  ...
# 3                   US              0.0                 0.0         0.0  ...
# 4                   US              0.0                 0.0         0.0  ...
# ...                ...              ...                 ...         ...  ...
# 1033724             US              0.0               336.0         0.0  ...
# 1033730             US              0.0               364.0         0.0  ...
# 1033731             US              0.0               366.0         0.0  ...
# 1033734             US              1.0               383.0         0.0  ...
# 1033735             US              1.0               386.0         0.0  ...
#
#          Median_Income_2018  Population_ACS  Population_Black_ACS  \
# 0                       NaN             NaN                   NaN
# 1                       NaN             NaN                   NaN
# 2                       NaN             NaN                   NaN
# 3                       NaN             NaN                   NaN
# 4                       NaN             NaN                   NaN
# ...                     ...             ...                   ...
# 1033724                 NaN             NaN                   NaN
# 1033730                 NaN             NaN                   NaN
# 1033731                 NaN             NaN                   NaN
# 1033734                 NaN             NaN                   NaN
# 1033735                 NaN             NaN                   NaN
#
#          Population_Hisp_ACS  Population_Native_ACS PCT_Black_ACS  \
# 0                        NaN                    NaN           NaN
# 1                        NaN                    NaN           NaN
# 2                        NaN                    NaN           NaN
# 3                        NaN                    NaN           NaN
# 4                        NaN                    NaN           NaN
# ...                      ...                    ...           ...
# 1033724                  NaN                    NaN           NaN
# 1033730                  NaN                    NaN           NaN
# 1033731                  NaN                    NaN           NaN
# 1033734                  NaN                    NaN           NaN
# 1033735                  NaN                    NaN           NaN
#
#          PCT_Hisp_ACS  PCT_Native_ACS  UrbanCD_Description  Metro
# 0                 NaN             NaN                  NaN    NaN
# 1                 NaN             NaN                  NaN    NaN
# 2                 NaN             NaN                  NaN    NaN
# 3                 NaN             NaN                  NaN    NaN
# 4                 NaN             NaN                  NaN    NaN
# ...               ...             ...                  ...    ...
# 1033724           NaN             NaN                  NaN    NaN
# 1033730           NaN             NaN                  NaN    NaN
# 1033731           NaN             NaN                  NaN    NaN
# 1033734           NaN             NaN                  NaN    NaN
# 1033735           NaN             NaN                  NaN    NaN
#
# [299523 rows x 64 columns]

# %%
# Can't deal with the + signs, so remove these 

large_columns = list(mobility_covid_urban.columns)
large_columns = [x.replace('+','') for x in large_columns]
mobility_covid_urban.columns = large_columns

# %%
a = mobility_covid_urban[['State','State Code','StateCD']]
a.isna().value_counts()

a['State Code']
# Out:
# 0          AL
# 1          AL
# 2          AL
# 3          AL
# 4          AL
#            ..
# 1033731    WY
# 1033732    WY
# 1033733    WY
# 1033734    WY
# 1033735    WY
# Name: State Code, Length: 1033736, dtype: object

# %%
list(mobility_covid_urban.columns)
# Out:
# ['Unnamed: 0_x',
#  'Date',
#  'Admin2',
#  'State',
#  'Confirmed',
#  'Deaths',
#  'Country/Region',
#  'Deaths_Previous',
#  'Confirmed_Previous',
#  'Deaths_New',
#  'Deaths_New_7',
#  'Deaths_New_14',
#  'Deaths_New_21',
#  'Deaths_New_28',
#  'Confirmed_New',
#  'locationcol',
#  'Confirmed_New_RollingAvg',
#  'Deaths_New_RollingAvg',
#  'Deaths_New_7_RollingAvg',
#  'Deaths_New_14_RollingAvg',
#  'Deaths_New_21_RollingAvg',
#  'Deaths_New_28_RollingAvg',
#  'County_FIPS',
#  'State Code',
#  'Region',
#  'Division',
#  'country_region_code',
#  'country_region',
#  'sub_region_1',
#  'sub_region_2',
#  'metro_area',
#  'iso_3166_2_code',
#  'census_fips_code',
#  'date',
#  'retail_and_recreation_PCT_CFB',
#  'grocery_and_pharmacy_PCT_CFB',
#  'parks_PCT_CFB',
#  'transit_stations_PCT_CFB',
#  'workplaces_PCT_CFB',
#  'residential_PCT_CFB',
#  'retail_and_recreation_PCT_CFB_RollingAvg',
#  'grocery_and_pharmacy_PCT_CFB_RollingAvg',
#  'parks_PCT_CFB_RollingAvg',
#  'transit_stations_PCT_CFB_RollingAvg',
#  'workplaces_PCT_CFB_RollingAvg',
#  'residential_PCT_CFB_RollingAvg',
#  'Unnamed: 0_y',
#  'StateCD',
#  'Name',
#  'HS_DIPLOMA_ONLY_2018',
#  'SOME_COLLEGE_2018',
#  'BACHELORS_PLUS_2018',
#  'Poverty_PCT_2018',
#  'UrbanCD',
#  'Median_Income_2018',
#  'Population_ACS',
#  'Population_Black_ACS',
#  'Population_Hisp_ACS',
#  'Population_Native_ACS',
#  'PCT_Black_ACS',
#  'PCT_Hisp_ACS',
#  'PCT_Native_ACS',
#  'UrbanCD_Description',
#  'Metro']

# %%
columns = [ 'Date',
 'County_FIPS',
 'State Code',
 'Name',
 'retail_and_recreation_PCT_CFB',
 'grocery_and_pharmacy_PCT_CFB',
 'parks_PCT_CFB',
 'transit_stations_PCT_CFB',
 'workplaces_PCT_CFB',
 'residential_PCT_CFB',
 'retail_and_recreation_PCT_CFB_RollingAvg',
 'grocery_and_pharmacy_PCT_CFB_RollingAvg',
 'parks_PCT_CFB_RollingAvg',
 'transit_stations_PCT_CFB_RollingAvg',
 'workplaces_PCT_CFB_RollingAvg',
 'residential_PCT_CFB_RollingAvg',
 'HS_DIPLOMA_ONLY_2018',
 'SOME_COLLEGE_2018',
 'BACHELORS_PLUS_2018',
 'Poverty_PCT_2018',
 'UrbanCD',
 'Median_Income_2018',
 'Population_ACS',
 'Population_Black_ACS',
 'Population_Hisp_ACS',
 'Population_Native_ACS',
 'PCT_Black_ACS',
 'PCT_Hisp_ACS',
 'PCT_Native_ACS',
 'UrbanCD_Description',
 'Metro',
 'Date',
 'State',
 'Confirmed',
 'Deaths',
 'Country/Region',
 'Deaths_Previous',
 'Confirmed_Previous',
 'Deaths_New',
 'Deaths_New_7',
 'Deaths_New_14',
 'Deaths_New_21',
 'Deaths_New_28',
 'Confirmed_New',
 'locationcol',
 'Confirmed_New_RollingAvg',
 'Deaths_New_RollingAvg',
 'Deaths_New_7_RollingAvg',
 'Deaths_New_14_RollingAvg',
 'Deaths_New_21_RollingAvg',
 'Deaths_New_28_RollingAvg',
 ]

# %%
combined_dataset_sub = mobility_covid_urban[columns]

# %%
combined_dataset_sub
# Out:
#               Date County_FIPS State Code           Name  \
# 0       2020-01-22       01001         AL            NaN
# 1       2020-01-23       01001         AL            NaN
# 2       2020-01-24       01001         AL            NaN
# 3       2020-01-25       01001         AL            NaN
# 4       2020-01-26       01001         AL            NaN
# ...            ...         ...        ...            ...
# 1033731 2020-11-22       56045         WY            NaN
# 1033732 2020-11-23       56045         WY  Weston County
# 1033733 2020-11-24       56045         WY  Weston County
# 1033734 2020-11-25       56045         WY            NaN
# 1033735 2020-11-26       56045         WY            NaN
#
#          retail_and_recreation_PCT_CFB  grocery_and_pharmacy_PCT_CFB  \
# 0                                  NaN                           NaN
# 1                                  NaN                           NaN
# 2                                  NaN                           NaN
# 3                                  NaN                           NaN
# 4                                  NaN                           NaN
# ...                                ...                           ...
# 1033731                            NaN                           NaN
# 1033732                            NaN                           NaN
# 1033733                            NaN                           NaN
# 1033734                            NaN                           NaN
# 1033735                            NaN                           NaN
#
#          parks_PCT_CFB  transit_stations_PCT_CFB  workplaces_PCT_CFB  \
# 0                  NaN                       NaN                 NaN
# 1                  NaN                       NaN                 NaN
# 2                  NaN                       NaN                 NaN
# 3                  NaN                       NaN                 NaN
# 4                  NaN                       NaN                 NaN
# ...                ...                       ...                 ...
# 1033731            NaN                       NaN                 NaN
# 1033732            NaN                       NaN               -23.0
# 1033733            NaN                       NaN               -21.0
# 1033734            NaN                       NaN                 NaN
# 1033735            NaN                       NaN                 NaN
#
#          residential_PCT_CFB  ...  Deaths_New_21  Deaths_New_28  \
# 0                        NaN  ...            0.0            0.0
# 1                        NaN  ...            0.0            0.0
# 2                        NaN  ...            0.0            0.0
# 3                        NaN  ...            0.0            0.0
# 4                        NaN  ...            0.0            0.0
# ...                      ...  ...            ...            ...
# 1033731                  NaN  ...            NaN            NaN
# 1033732                  NaN  ...            NaN            NaN
# 1033733                  NaN  ...            NaN            NaN
# 1033734                  NaN  ...            NaN            NaN
# 1033735                  NaN  ...            NaN            NaN
#
#          Confirmed_New      locationcol  Confirmed_New_RollingAvg  \
# 0                  NaN  Autauga|Alabama                       NaN
# 1                  0.0  Autauga|Alabama                       NaN
# 2                  0.0  Autauga|Alabama                       NaN
# 3                  0.0  Autauga|Alabama                       NaN
# 4                  0.0  Autauga|Alabama                       NaN
# ...                ...              ...                       ...
# 1033731            6.0   Weston|Wyoming                  4.714286
# 1033732            0.0   Weston|Wyoming                  4.857143
# 1033733           11.0   Weston|Wyoming                  5.285714
# 1033734            3.0   Weston|Wyoming                  4.714286
# 1033735            0.0   Weston|Wyoming                  4.428571
#
#          Deaths_New_RollingAvg  Deaths_New_7_RollingAvg  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 1033731               0.000000                      NaN
# 1033732               0.142857                      NaN
# 1033733               0.142857                      NaN
# 1033734               0.142857                      NaN
# 1033735               0.142857                      NaN
#
#          Deaths_New_14_RollingAvg  Deaths_New_21_RollingAvg  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 1033731                       NaN                       NaN
# 1033732                       NaN                       NaN
# 1033733                       NaN                       NaN
# 1033734                       NaN                       NaN
# 1033735                       NaN                       NaN
#
#          Deaths_New_28_RollingAvg
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 1033731                       NaN
# 1033732                       NaN
# 1033733                       NaN
# 1033734                       NaN
# 1033735                       NaN
#
# [1033736 rows x 51 columns]

# %%
#check to see matching
combined_dataset_sub[['State','State Code']].sample(frac=.00004)
# Out:
#                   State State Code
# 131272          Georgia         GA
# 768452     Rhode Island         RI
# 201157         Illinois         IL
# 352892         Kentucky         KY
# 998388    West Virginia         WV
# 7886            Alabama         AL
# 673909             Ohio         OH
# 526323          Montana         MT
# 255513             Iowa         IA
# 707349         Oklahoma         OK
# 487325         Missouri         MO
# 260847             Iowa         IA
# 329312         Kentucky         KY
# 771672   South Carolina         SC
# 675063             Ohio         OH
# 943587         Virginia         VA
# 466299      Mississippi         MS
# 789054     South Dakota         SD
# 96896          Colorado         CO
# 671012             Ohio         OH
# 529744          Montana         MT
# 874029            Texas         TX
# 1028368         Wyoming         WY
# 315558           Kansas         KS
# 986357    West Virginia         WV
# 319235         Kentucky         KY
# 306704           Kansas         KS
# 276894             Iowa         IA
# 652983     North Dakota         ND
# 713765           Oregon         OR
# 561706           Nevada         NV
# 105716          Florida         FL
# 845846            Texas         TX
# 999225    West Virginia         WV
# 85564          Colorado         CO
# 315621           Kansas         KS
# 494538         Missouri         MO
# 448092        Minnesota         MN
# 88051          Colorado         CO
# 758473      Puerto Rico        NaN
# 387956         Maryland         MD

# %%
def create_percapita_measures(dataframe):
    list_col = list(dataframe.columns)
    for i in list(dataframe.columns):
        if "death" in i.lower() or "confirmed" in i.lower() and "previous" not in i.lower() :
            try:
                new_col_name = i+'_PER_100K'
                dataframe[new_col_name] = dataframe[i]/(dataframe['Population_ACS']/100000)
            except:
                print("error occurred for {i}".format(i=i))

# %%
create_percapita_measures(combined_dataset_sub)
# Out:
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
list(combined_dataset_sub.columns)
# Out:
# ['Date',
#  'County_FIPS',
#  'State Code',
#  'Name',
#  'retail_and_recreation_PCT_CFB',
#  'grocery_and_pharmacy_PCT_CFB',
#  'parks_PCT_CFB',
#  'transit_stations_PCT_CFB',
#  'workplaces_PCT_CFB',
#  'residential_PCT_CFB',
#  'retail_and_recreation_PCT_CFB_RollingAvg',
#  'grocery_and_pharmacy_PCT_CFB_RollingAvg',
#  'parks_PCT_CFB_RollingAvg',
#  'transit_stations_PCT_CFB_RollingAvg',
#  'workplaces_PCT_CFB_RollingAvg',
#  'residential_PCT_CFB_RollingAvg',
#  'HS_DIPLOMA_ONLY_2018',
#  'SOME_COLLEGE_2018',
#  'BACHELORS_PLUS_2018',
#  'Poverty_PCT_2018',
#  'UrbanCD',
#  'Median_Income_2018',
#  'Population_ACS',
#  'Population_Black_ACS',
#  'Population_Hisp_ACS',
#  'Population_Native_ACS',
#  'PCT_Black_ACS',
#  'PCT_Hisp_ACS',
#  'PCT_Native_ACS',
#  'UrbanCD_Description',
#  'Metro',
#  'Date',
#  'State',
#  'Confirmed',
#  'Deaths',
#  'Country/Region',
#  'Deaths_Previous',
#  'Confirmed_Previous',
#  'Deaths_New',
#  'Deaths_New_7',
#  'Deaths_New_14',
#  'Deaths_New_21',
#  'Deaths_New_28',
#  'Confirmed_New',
#  'locationcol',
#  'Confirmed_New_RollingAvg',
#  'Deaths_New_RollingAvg',
#  'Deaths_New_7_RollingAvg',
#  'Deaths_New_14_RollingAvg',
#  'Deaths_New_21_RollingAvg',
#  'Deaths_New_28_RollingAvg',
#  'Confirmed_PER_100K',
#  'Deaths_PER_100K',
#  'Deaths_Previous_PER_100K',
#  'Deaths_New_PER_100K',
#  'Deaths_New_7_PER_100K',
#  'Deaths_New_14_PER_100K',
#  'Deaths_New_21_PER_100K',
#  'Deaths_New_28_PER_100K',
#  'Confirmed_New_PER_100K',
#  'Confirmed_New_RollingAvg_PER_100K',
#  'Deaths_New_RollingAvg_PER_100K',
#  'Deaths_New_7_RollingAvg_PER_100K',
#  'Deaths_New_14_RollingAvg_PER_100K',
#  'Deaths_New_21_RollingAvg_PER_100K',
#  'Deaths_New_28_RollingAvg_PER_100K']

# %%
combined_dataset_sub.dtypes
# Out:
# Date                                 datetime64[ns]
# County_FIPS                                  object
# State Code                                   object
# Name                                         object
# retail_and_recreation_PCT_CFB               float64
#                                           ...
# Deaths_New_RollingAvg_PER_100K              float64
# Deaths_New_7_RollingAvg_PER_100K            float64
# Deaths_New_14_RollingAvg_PER_100K           float64
# Deaths_New_21_RollingAvg_PER_100K           float64
# Deaths_New_28_RollingAvg_PER_100K           float64
# Length: 66, dtype: object

# %%
combined_dataset_sub.Deaths_New_7_RollingAvg_PER_100K.isna().value_counts()
# Out:
# False    685448
# True     348288
# Name: Deaths_New_7_RollingAvg_PER_100K, dtype: int64

# %%
combined_dataset_sub.Population_ACS.isna().value_counts()
# Out:
# False    697861
# True     335875
# Name: Population_ACS, dtype: int64

# %%
combined_dataset_sub.Deaths_New_7_RollingAvg_PER_100K.isna().value_counts()
# Out:
# False    685448
# True     348288
# Name: Deaths_New_7_RollingAvg_PER_100K, dtype: int64

# %%
combined_dataset_sub.Metro.isna().value_counts()
# Out:
# False    697861
# True     335875
# Name: Metro, dtype: int64

# %% [markdown]
# ## Get Regions

# %%
regions = pd.read_csv('https://raw.githubusercontent.com/cphalpert/census-regions/master/us%20census%20bureau%20regions%20and%20divisions.csv')

# %%
regions= regions.drop(['State'], axis=1)

# %%
regions
# Out:
#    State Code     Region            Division
# 0          AK       West             Pacific
# 1          AL      South  East South Central
# 2          AR      South  West South Central
# 3          AZ       West            Mountain
# 4          CA       West             Pacific
# 5          CO       West            Mountain
# 6          CT  Northeast         New England
# 7          DC      South      South Atlantic
# 8          DE      South      South Atlantic
# 9          FL      South      South Atlantic
# 10         GA      South      South Atlantic
# 11         HI       West             Pacific
# 12         IA    Midwest  West North Central
# 13         ID       West            Mountain
# 14         IL    Midwest  East North Central
# 15         IN    Midwest  East North Central
# 16         KS    Midwest  West North Central
# 17         KY      South  East South Central
# 18         LA      South  West South Central
# 19         MA  Northeast         New England
# 20         MD      South      South Atlantic
# 21         ME  Northeast         New England
# 22         MI    Midwest  East North Central
# 23         MN    Midwest  West North Central
# 24         MO    Midwest  West North Central
# 25         MS      South  East South Central
# 26         MT       West            Mountain
# 27         NC      South      South Atlantic
# 28         ND    Midwest  West North Central
# 29         NE    Midwest  West North Central
# 30         NH  Northeast         New England
# 31         NJ  Northeast     Middle Atlantic
# 32         NM       West            Mountain
# 33         NV       West            Mountain
# 34         NY  Northeast     Middle Atlantic
# 35         OH    Midwest  East North Central
# 36         OK      South  West South Central
# 37         OR       West             Pacific
# 38         PA  Northeast     Middle Atlantic
# 39         RI  Northeast         New England
# 40         SC      South      South Atlantic
# 41         SD    Midwest  West North Central
# 42         TN      South  East South Central
# 43         TX      South  West South Central
# 44         UT       West            Mountain
# 45         VA      South      South Atlantic
# 46         VT  Northeast         New England
# 47         WA       West             Pacific
# 48         WI    Midwest  East North Central
# 49         WV      South      South Atlantic
# 50         WY       West            Mountain

# %%
combined_dataset_sub_regions = combined_dataset_sub.merge(regions, on="State Code", how="left")

# %%
combined_dataset_sub_regions.Division.isna().value_counts()
# Out:
# False    1008962
# True       24774
# Name: Division, dtype: int64

# %%
# These are all Puerto Rico, which is not included in the dataset, unfortunately
combined_dataset_sub_regions[combined_dataset_sub_regions.Region.isna() == True]['County_FIPS'].value_counts().head(50)
# Out:
# 72029    310
# 72067    310
# 72121    310
# 72054    310
# 72021    310
# 72045    310
# 72103    310
# 72003    310
# 72057    310
# 72151    310
# 72041    310
# 72147    310
# 72069    310
# 72093    310
# 72043    310
# 72085    310
# 72053    310
# 72037    310
# 72039    310
# 72019    310
# 72055    310
# 72101    310
# 72099    310
# 72007    310
# 72049    310
# 72063    310
# 72149    310
# 72005    310
# 72071    310
# 72105    310
# 72083    310
# 72025    310
# 72073    310
# 72013    310
# 72133    310
# 72113    310
# 72047    310
# 72027    310
# 72001    310
# 72023    310
# 72125    310
# 72135    310
# 72115    310
# 72123    310
# 72091    310
# 72009    310
# 72129    310
# 72015    310
# 72035    310
# 72011    310
# Name: County_FIPS, dtype: int64

# %% [markdown]
# ## Export to File

# %%
os.chdir(r'/Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets/')
path = str(os.getcwd())
filename = "hia_covid_combined.csv"
combined_dataset_sub_regions.to_csv(filename)
print("{filename} has been created in {path}".format(filename=filename, path=path))

# %%
os.chdir(r'/Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets/')
path = str(os.getcwd())
filename = "hia_covid_combined_sample.csv"
combined_dataset_sub_regions.sample(frac=.10).to_csv(filename)
print("{filename} has been created in {path}".format(filename=filename, path=path))

# %%
# ratio to check join 
combined_dataset_sub_regions.shape[0]/mobility_counties.shape[0]

# %%
os.chdir(r'/Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets/')
path = str(os.getcwd())
filename = "hia_covid_combined_post0601.csv"
combined_dataset_sub_regions[combined_dataset_sub.Date >= '2020-06-01'].to_csv(filename)
print("{filename} has been created in {path}".format(filename=filename, path=path))
