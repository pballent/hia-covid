# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm

# %% [markdown]
# ## Import Mobility Data

# %%
# keep FIPS as string to preserve leading zeroes

# %%
mob = pd.read_csv(r"/Users/philip.ballentine/Downloads/Region_Mobility_Report_CSVs/2020_US_Region_Mobility_Report.csv", dtype={'census_fips_code': 'str'} )

# %%
mob['date'] = mob['date'].astype('datetime64')

# %%
mob_renam_col = [i.replace('percent_change_from_baseline', 'PCT_CFB') for i in mob.columns]

# %%
mob.columns = mob_renam_col

# %%
mob_renam_col
# Out:
# ['country_region_code',
#  'country_region',
#  'sub_region_1',
#  'sub_region_2',
#  'metro_area',
#  'iso_3166_2_code',
#  'census_fips_code',
#  'date',
#  'retail_and_recreation_PCT_CFB',
#  'grocery_and_pharmacy_PCT_CFB',
#  'parks_PCT_CFB',
#  'transit_stations_PCT_CFB',
#  'workplaces_PCT_CFB',
#  'residential_PCT_CFB']

# %%
mob.dtypes
# Out:
# country_region_code                      object
# country_region                           object
# sub_region_1                             object
# sub_region_2                             object
# metro_area                              float64
# iso_3166_2_code                          object
# census_fips_code                         object
# date                             datetime64[ns]
# retail_and_recreation_PCT_CFB           float64
# grocery_and_pharmacy_PCT_CFB            float64
# parks_PCT_CFB                           float64
# transit_stations_PCT_CFB                float64
# workplaces_PCT_CFB                      float64
# residential_PCT_CFB                     float64
# dtype: object

# %%
mob.sort_values(by="date", inplace=True)

# %%
mob.head(5)
# Out:
#        country_region_code country_region sub_region_1     sub_region_2  \
# 0                       US  United States          NaN              NaN
# 72735                   US  United States      Florida   Brevard County
# 527841                  US  United States    Tennessee              NaN
# 528114                  US  United States    Tennessee  Anderson County
# 72487                   US  United States      Florida  Bradford County
#
#         metro_area iso_3166_2_code census_fips_code       date  \
# 0              NaN             NaN              NaN 2020-02-15
# 72735          NaN             NaN            12009 2020-02-15
# 527841         NaN           US-TN              NaN 2020-02-15
# 528114         NaN             NaN            47001 2020-02-15
# 72487          NaN             NaN            12007 2020-02-15
#
#         retail_and_recreation_PCT_CFB  grocery_and_pharmacy_PCT_CFB  \
# 0                                 6.0                           2.0
# 72735                             4.0                           0.0
# 527841                            7.0                           4.0
# 528114                            8.0                           5.0
# 72487                             4.0                           1.0
#
#         parks_PCT_CFB  transit_stations_PCT_CFB  workplaces_PCT_CFB  \
# 0                15.0                       3.0                 2.0
# 72735             6.0                      18.0                 1.0
# 527841           54.0                       4.0                 3.0
# 528114            NaN                       NaN                 1.0
# 72487             NaN                       NaN                -2.0
#
#         residential_PCT_CFB
# 0                      -1.0
# 72735                   0.0
# 527841                 -1.0
# 528114                 -1.0
# 72487                   NaN

# %% [markdown]
# ## Compute Rolling Average of Mobility Data

# %%
list_all_locations = list(mob.census_fips_code.unique())
list_frames = []
for i in list_all_locations:
    frame = mob[mob.census_fips_code == i]
    frame['retail_and_recreation_PCT_CFB_RollingAvg'] = frame.rolling(7, min_periods=7, center=False, on="date")['retail_and_recreation_PCT_CFB'].mean()
    frame['grocery_and_pharmacy_PCT_CFB_RollingAvg'] = frame.rolling(7, min_periods=7, center=False, on="date")['grocery_and_pharmacy_PCT_CFB'].mean()
    frame['parks_PCT_CFB_RollingAvg'] = frame.rolling(7, min_periods=7, center=False, on="date")['parks_PCT_CFB'].mean()
    frame['transit_stations_PCT_CFB_RollingAvg'] = frame.rolling(7, min_periods=7, center=False, on="date")['transit_stations_PCT_CFB'].mean()
    frame['workplaces_PCT_CFB_RollingAvg'] = frame.rolling(7, min_periods=7, center=False, on="date")['workplaces_PCT_CFB'].mean()
    frame['residential_PCT_CFB_RollingAvg'] = frame.rolling(7, min_periods=7, center=False, on="date")['residential_PCT_CFB'].mean()
    list_frames.append(frame)
# Out:
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
recombine = pd.concat(list_frames)

# %%
mobility_final = recombine

# %%
mobility_final[(mobility_final.census_fips_code == "12009") & (mobility_final.date > '2020-10-01')].head(-18)
# Out:
#       country_region_code country_region sub_region_1    sub_region_2  \
# 72965                  US  United States      Florida  Brevard County
# 72966                  US  United States      Florida  Brevard County
# 72967                  US  United States      Florida  Brevard County
# 72968                  US  United States      Florida  Brevard County
# 72969                  US  United States      Florida  Brevard County
# 72970                  US  United States      Florida  Brevard County
# 72971                  US  United States      Florida  Brevard County
# 72972                  US  United States      Florida  Brevard County
# 72973                  US  United States      Florida  Brevard County
# 72974                  US  United States      Florida  Brevard County
# 72975                  US  United States      Florida  Brevard County
# 72976                  US  United States      Florida  Brevard County
# 72977                  US  United States      Florida  Brevard County
# 72978                  US  United States      Florida  Brevard County
# 72979                  US  United States      Florida  Brevard County
# 72980                  US  United States      Florida  Brevard County
# 72981                  US  United States      Florida  Brevard County
# 72982                  US  United States      Florida  Brevard County
# 72983                  US  United States      Florida  Brevard County
# 72984                  US  United States      Florida  Brevard County
# 72985                  US  United States      Florida  Brevard County
# 72986                  US  United States      Florida  Brevard County
# 72987                  US  United States      Florida  Brevard County
# 72988                  US  United States      Florida  Brevard County
# 72989                  US  United States      Florida  Brevard County
#
#        metro_area iso_3166_2_code census_fips_code       date  \
# 72965         NaN             NaN            12009 2020-10-02
# 72966         NaN             NaN            12009 2020-10-03
# 72967         NaN             NaN            12009 2020-10-04
# 72968         NaN             NaN            12009 2020-10-05
# 72969         NaN             NaN            12009 2020-10-06
# 72970         NaN             NaN            12009 2020-10-07
# 72971         NaN             NaN            12009 2020-10-08
# 72972         NaN             NaN            12009 2020-10-09
# 72973         NaN             NaN            12009 2020-10-10
# 72974         NaN             NaN            12009 2020-10-11
# 72975         NaN             NaN            12009 2020-10-12
# 72976         NaN             NaN            12009 2020-10-13
# 72977         NaN             NaN            12009 2020-10-14
# 72978         NaN             NaN            12009 2020-10-15
# 72979         NaN             NaN            12009 2020-10-16
# 72980         NaN             NaN            12009 2020-10-17
# 72981         NaN             NaN            12009 2020-10-18
# 72982         NaN             NaN            12009 2020-10-19
# 72983         NaN             NaN            12009 2020-10-20
# 72984         NaN             NaN            12009 2020-10-21
# 72985         NaN             NaN            12009 2020-10-22
# 72986         NaN             NaN            12009 2020-10-23
# 72987         NaN             NaN            12009 2020-10-24
# 72988         NaN             NaN            12009 2020-10-25
# 72989         NaN             NaN            12009 2020-10-26
#
#        retail_and_recreation_PCT_CFB  grocery_and_pharmacy_PCT_CFB  \
# 72965                          -18.0                         -11.0
# 72966                          -23.0                         -15.0
# 72967                          -19.0                         -13.0
# 72968                          -22.0                         -14.0
# 72969                          -19.0                         -12.0
# 72970                          -19.0                         -11.0
# 72971                          -20.0                         -13.0
# 72972                          -19.0                         -12.0
# 72973                          -21.0                         -14.0
# 72974                          -20.0                         -15.0
# 72975                          -20.0                         -13.0
# 72976                          -19.0                         -12.0
# 72977                          -17.0                         -10.0
# 72978                          -18.0                         -11.0
# 72979                          -19.0                         -12.0
# 72980                          -19.0                         -12.0
# 72981                          -20.0                         -16.0
# 72982                          -22.0                         -17.0
# 72983                          -19.0                         -12.0
# 72984                          -18.0                         -10.0
# 72985                          -19.0                         -12.0
# 72986                          -19.0                         -12.0
# 72987                          -19.0                         -11.0
# 72988                          -19.0                         -14.0
# 72989                          -20.0                         -12.0
#
#        parks_PCT_CFB  transit_stations_PCT_CFB  workplaces_PCT_CFB  \
# 72965           -6.0                     -16.0               -26.0
# 72966          -34.0                     -32.0               -17.0
# 72967          -32.0                     -24.0               -19.0
# 72968          -27.0                     -14.0               -28.0
# 72969          -10.0                      -9.0               -28.0
# 72970          -15.0                     -15.0               -27.0
# 72971           -3.0                      -8.0               -27.0
# 72972          -14.0                     -16.0               -26.0
# 72973          -19.0                     -30.0               -16.0
# 72974          -18.0                     -23.0               -18.0
# 72975           -9.0                     -15.0               -30.0
# 72976           -5.0                      -8.0               -27.0
# 72977          -12.0                     -14.0               -27.0
# 72978           -2.0                     -10.0               -27.0
# 72979          -10.0                     -13.0               -26.0
# 72980            8.0                     -23.0               -17.0
# 72981          -24.0                     -22.0               -19.0
# 72982          -29.0                     -14.0               -27.0
# 72983          -10.0                     -10.0               -27.0
# 72984          -22.0                     -18.0               -26.0
# 72985           -1.0                     -16.0               -26.0
# 72986          -10.0                     -20.0               -26.0
# 72987            3.0                     -30.0               -15.0
# 72988          -21.0                     -26.0               -18.0
# 72989          -11.0                     -18.0               -26.0
#
#        residential_PCT_CFB  retail_and_recreation_PCT_CFB_RollingAvg  \
# 72965                  6.0                                -19.571429
# 72966                  5.0                                -20.000000
# 72967                  4.0                                -20.142857
# 72968                  7.0                                -19.714286
# 72969                  7.0                                -19.571429
# 72970                  7.0                                -19.714286
# 72971                  7.0                                -20.000000
# 72972                  7.0                                -20.142857
# 72973                  5.0                                -19.857143
# 72974                  4.0                                -20.000000
# 72975                  7.0                                -19.714286
# 72976                  7.0                                -19.714286
# 72977                  7.0                                -19.428571
# 72978                  7.0                                -19.142857
# 72979                  7.0                                -19.142857
# 72980                  3.0                                -18.857143
# 72981                  4.0                                -18.857143
# 72982                  7.0                                -19.142857
# 72983                  8.0                                -19.142857
# 72984                  8.0                                -19.285714
# 72985                  7.0                                -19.428571
# 72986                  7.0                                -19.428571
# 72987                  3.0                                -19.428571
# 72988                  4.0                                -19.285714
# 72989                  6.0                                -19.000000
#
#        grocery_and_pharmacy_PCT_CFB_RollingAvg  parks_PCT_CFB_RollingAvg  \
# 72965                               -12.285714                -13.428571
# 72966                               -12.857143                -18.857143
# 72967                               -13.000000                -22.000000
# 72968                               -12.428571                -20.714286
# 72969                               -12.428571                -18.428571
# 72970                               -12.571429                -18.571429
# 72971                               -12.714286                -18.142857
# 72972                               -12.857143                -19.285714
# 72973                               -12.714286                -17.142857
# 72974                               -13.000000                -15.142857
# 72975                               -12.857143                -12.571429
# 72976                               -12.857143                -11.857143
# 72977                               -12.714286                -11.428571
# 72978                               -12.428571                -11.285714
# 72979                               -12.428571                -10.714286
# 72980                               -12.142857                 -6.857143
# 72981                               -12.285714                 -7.714286
# 72982                               -12.857143                -10.571429
# 72983                               -12.857143                -11.285714
# 72984                               -12.857143                -12.714286
# 72985                               -13.000000                -12.571429
# 72986                               -13.000000                -12.571429
# 72987                               -12.857143                -13.285714
# 72988                               -12.571429                -12.857143
# 72989                               -11.857143                -10.285714
#
#        transit_stations_PCT_CFB_RollingAvg  workplaces_PCT_CFB_RollingAvg  \
# 72965                           -20.142857                     -24.142857
# 72966                           -20.285714                     -24.428571
# 72967                           -19.714286                     -24.571429
# 72968                           -19.000000                     -24.571429
# 72969                           -18.000000                     -24.714286
# 72970                           -17.571429                     -24.571429
# 72971                           -16.857143                     -24.571429
# 72972                           -16.857143                     -24.571429
# 72973                           -16.571429                     -24.428571
# 72974                           -16.428571                     -24.285714
# 72975                           -16.571429                     -24.571429
# 72976                           -16.428571                     -24.428571
# 72977                           -16.285714                     -24.428571
# 72978                           -16.571429                     -24.428571
# 72979                           -16.142857                     -24.428571
# 72980                           -15.142857                     -24.571429
# 72981                           -15.000000                     -24.714286
# 72982                           -14.857143                     -24.285714
# 72983                           -15.142857                     -24.285714
# 72984                           -15.714286                     -24.142857
# 72985                           -16.571429                     -24.000000
# 72986                           -17.571429                     -24.000000
# 72987                           -18.571429                     -23.714286
# 72988                           -19.142857                     -23.571429
# 72989                           -19.714286                     -23.428571
#
#        residential_PCT_CFB_RollingAvg
# 72965                        6.142857
# 72966                        6.285714
# 72967                        6.285714
# 72968                        6.142857
# 72969                        6.142857
# 72970                        6.142857
# 72971                        6.142857
# 72972                        6.285714
# 72973                        6.285714
# 72974                        6.285714
# 72975                        6.285714
# 72976                        6.285714
# 72977                        6.285714
# 72978                        6.285714
# 72979                        6.285714
# 72980                        6.000000
# 72981                        6.000000
# 72982                        6.000000
# 72983                        6.142857
# 72984                        6.285714
# 72985                        6.285714
# 72986                        6.285714
# 72987                        6.285714
# 72988                        6.285714
# 72989                        6.142857

# %% [markdown]
# ## Join Full County-Level Dataset

# %%
counties = pd.read_csv(r"/Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets/counties_dataset_full.csv",dtype={'County_FIPS':'str'})

# %%
counties.dtypes
# Out:
# Unnamed: 0                 int64
# County_FIPS               object
# StateCD                   object
# Name                      object
# HS_DIPLOMA_ONLY_2018     float64
# SOME_COLLEGE_2018        float64
# BACHELORS_PLUS_2018      float64
# Poverty_PCT_2018         float64
# UrbanCD                    int64
# Median_Income_2018       float64
# Population_ACS           float64
# Population_Black_ACS     float64
# Population_Hisp_ACS      float64
# Population_Native_ACS    float64
# PCT_Black_ACS            float64
# PCT_Hisp_ACS             float64
# PCT_Native_ACS           float64
# UrbanCD_Description       object
# Metro                     object
# dtype: object

# %%
counties['census_fips_code'] = counties['County_FIPS'].astype('str')

# %%
mobility_counties = mobility_final.merge(counties, on = "census_fips_code")

# %%
mobility_counties.dtypes
# Out:
# country_region_code                                 object
# country_region                                      object
# sub_region_1                                        object
# sub_region_2                                        object
# metro_area                                         float64
# iso_3166_2_code                                     object
# census_fips_code                                    object
# date                                        datetime64[ns]
# retail_and_recreation_PCT_CFB                      float64
# grocery_and_pharmacy_PCT_CFB                       float64
# parks_PCT_CFB                                      float64
# transit_stations_PCT_CFB                           float64
# workplaces_PCT_CFB                                 float64
# residential_PCT_CFB                                float64
# retail_and_recreation_PCT_CFB_RollingAvg           float64
# grocery_and_pharmacy_PCT_CFB_RollingAvg            float64
# parks_PCT_CFB_RollingAvg                           float64
# transit_stations_PCT_CFB_RollingAvg                float64
# workplaces_PCT_CFB_RollingAvg                      float64
# residential_PCT_CFB_RollingAvg                     float64
# Unnamed: 0                                           int64
# County_FIPS                                         object
# StateCD                                             object
# Name                                                object
# HS_DIPLOMA_ONLY_2018                               float64
# SOME_COLLEGE_2018                                  float64
# BACHELORS_PLUS_2018                                float64
# Poverty_PCT_2018                                   float64
# UrbanCD                                              int64
# Median_Income_2018                                 float64
# Population_ACS                                     float64
# Population_Black_ACS                               float64
# Population_Hisp_ACS                                float64
# Population_Native_ACS                              float64
# PCT_Black_ACS                                      float64
# PCT_Hisp_ACS                                       float64
# PCT_Native_ACS                                     float64
# UrbanCD_Description                                 object
# Metro                                               object
# dtype: object

# %%
mobility_counties[mobility_counties.census_fips_code == ""]
# Out:
# Empty DataFrame
# Columns: [country_region_code, country_region, sub_region_1, sub_region_2, metro_area, iso_3166_2_code, census_fips_code, date, retail_and_recreation_PCT_CFB, grocery_and_pharmacy_PCT_CFB, parks_PCT_CFB, transit_stations_PCT_CFB, workplaces_PCT_CFB, residential_PCT_CFB, retail_and_recreation_PCT_CFB_RollingAvg, grocery_and_pharmacy_PCT_CFB_RollingAvg, parks_PCT_CFB_RollingAvg, transit_stations_PCT_CFB_RollingAvg, workplaces_PCT_CFB_RollingAvg, residential_PCT_CFB_RollingAvg, Unnamed: 0, County_FIPS, StateCD, Name, HS_DIPLOMA_ONLY_2018, SOME_COLLEGE_2018, BACHELORS_PLUS_2018, Poverty_PCT_2018, UrbanCD, Median_Income_2018, Population_ACS, Population_Black_ACS, Population_Hisp_ACS, Population_Native_ACS, PCT_Black_ACS, PCT_Hisp_ACS, PCT_Native_ACS, UrbanCD_Description, Metro]
# Index: []
#
# [0 rows x 39 columns]

# %%
mobility_counties.head(5)
# Out:
#   country_region_code country_region sub_region_1    sub_region_2  metro_area  \
# 0                  US  United States      Florida  Brevard County         NaN
# 1                  US  United States      Florida  Brevard County         NaN
# 2                  US  United States      Florida  Brevard County         NaN
# 3                  US  United States      Florida  Brevard County         NaN
# 4                  US  United States      Florida  Brevard County         NaN
#
#   iso_3166_2_code census_fips_code       date  retail_and_recreation_PCT_CFB  \
# 0             NaN            12009 2020-02-15                            4.0
# 1             NaN            12009 2020-02-16                            6.0
# 2             NaN            12009 2020-02-17                            6.0
# 3             NaN            12009 2020-02-18                            4.0
# 4             NaN            12009 2020-02-19                            3.0
#
#    grocery_and_pharmacy_PCT_CFB  ...  Median_Income_2018  Population_ACS  \
# 0                           0.0  ...             57612.0        568183.0
# 1                           1.0  ...             57612.0        568183.0
# 2                           1.0  ...             57612.0        568183.0
# 3                           1.0  ...             57612.0        568183.0
# 4                           0.0  ...             57612.0        568183.0
#
#    Population_Black_ACS  Population_Hisp_ACS  Population_Native_ACS  \
# 0               57728.0              55042.0                 1945.0
# 1               57728.0              55042.0                 1945.0
# 2               57728.0              55042.0                 1945.0
# 3               57728.0              55042.0                 1945.0
# 4               57728.0              55042.0                 1945.0
#
#    PCT_Black_ACS  PCT_Hisp_ACS  PCT_Native_ACS  \
# 0      10.160107      9.687372        0.342319
# 1      10.160107      9.687372        0.342319
# 2      10.160107      9.687372        0.342319
# 3      10.160107      9.687372        0.342319
# 4      10.160107      9.687372        0.342319
#
#                                  UrbanCD_Description          Metro
# 0  In small metro area of less than 1 million res...  Smaller_metro
# 1  In small metro area of less than 1 million res...  Smaller_metro
# 2  In small metro area of less than 1 million res...  Smaller_metro
# 3  In small metro area of less than 1 million res...  Smaller_metro
# 4  In small metro area of less than 1 million res...  Smaller_metro
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Bring in the COVID Data to be Joined In

# %%
covid = pd.read_csv(r"/Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets/covid_dataset_full.csv",dtype={'County_FIPS':'str'})

# %%
covid.Date = covid.Date.astype("datetime64")

# %%
mobility_counties['Date'] = mobility_counties['date']

# %%
mobility_covid_urban = mobility_counties.merge(covid, on =['Date','County_FIPS'])

# %%
# Can't deal with the + signs, so remove these 

large_columns = list(mobility_covid_urban.columns)
large_columns = [x.replace('+','') for x in large_columns]
mobility_covid_urban.columns = large_columns

# %%
list(mobility_covid_urban.columns)
# Out:
# ['country_region_code',
#  'country_region',
#  'sub_region_1',
#  'sub_region_2',
#  'metro_area',
#  'iso_3166_2_code',
#  'census_fips_code',
#  'date',
#  'retail_and_recreation_PCT_CFB',
#  'grocery_and_pharmacy_PCT_CFB',
#  'parks_PCT_CFB',
#  'transit_stations_PCT_CFB',
#  'workplaces_PCT_CFB',
#  'residential_PCT_CFB',
#  'retail_and_recreation_PCT_CFB_RollingAvg',
#  'grocery_and_pharmacy_PCT_CFB_RollingAvg',
#  'parks_PCT_CFB_RollingAvg',
#  'transit_stations_PCT_CFB_RollingAvg',
#  'workplaces_PCT_CFB_RollingAvg',
#  'residential_PCT_CFB_RollingAvg',
#  'Unnamed: 0_x',
#  'County_FIPS',
#  'StateCD',
#  'Name',
#  'HS_DIPLOMA_ONLY_2018',
#  'SOME_COLLEGE_2018',
#  'BACHELORS_PLUS_2018',
#  'Poverty_PCT_2018',
#  'UrbanCD',
#  'Median_Income_2018',
#  'Population_ACS',
#  'Population_Black_ACS',
#  'Population_Hisp_ACS',
#  'Population_Native_ACS',
#  'PCT_Black_ACS',
#  'PCT_Hisp_ACS',
#  'PCT_Native_ACS',
#  'UrbanCD_Description',
#  'Metro',
#  'Date',
#  'Unnamed: 0_y',
#  'Admin2',
#  'State',
#  'Confirmed',
#  'Deaths',
#  'Country/Region',
#  'Deaths_Previous',
#  'Confirmed_Previous',
#  'Deaths_New',
#  'Deaths_New_7',
#  'Deaths_New_14',
#  'Deaths_New_21',
#  'Deaths_New_28',
#  'Confirmed_New',
#  'locationcol',
#  'Confirmed_New_RollingAvg',
#  'Deaths_New_7_RollingAvg',
#  'Deaths_New_14_RollingAvg',
#  'Deaths_New_21_RollingAvg',
#  'Deaths_New_28_RollingAvg',
#  'State Code',
#  'Region',
#  'Division']

# %%
columns = [ 'date',
 'County_FIPS',
 'StateCD',
 'Name',
 'retail_and_recreation_PCT_CFB',
 'grocery_and_pharmacy_PCT_CFB',
 'parks_PCT_CFB',
 'transit_stations_PCT_CFB',
 'workplaces_PCT_CFB',
 'residential_PCT_CFB',
 'retail_and_recreation_PCT_CFB_RollingAvg',
 'grocery_and_pharmacy_PCT_CFB_RollingAvg',
 'parks_PCT_CFB_RollingAvg',
 'transit_stations_PCT_CFB_RollingAvg',
 'workplaces_PCT_CFB_RollingAvg',
 'residential_PCT_CFB_RollingAvg',
 'HS_DIPLOMA_ONLY_2018',
 'SOME_COLLEGE_2018',
 'BACHELORS_PLUS_2018',
 'Poverty_PCT_2018',
 'UrbanCD',
 'Median_Income_2018',
 'Population_ACS',
 'Population_Black_ACS',
 'Population_Hisp_ACS',
 'Population_Native_ACS',
 'PCT_Black_ACS',
 'PCT_Hisp_ACS',
 'PCT_Native_ACS',
 'UrbanCD_Description',
 'Metro',
 'Date',
 'State',
 'Confirmed',
 'Deaths',
 'Country/Region',
 'Deaths_Previous',
 'Confirmed_Previous',
 'Deaths_New',
 'Deaths_New_7',
 'Deaths_New_14',
 'Deaths_New_21',
 'Deaths_New_28',
 'Confirmed_New',
 'locationcol',
 'Confirmed_New_RollingAvg',
 'Deaths_New_RollingAvg',
 'Deaths_New_7_RollingAvg',
 'Deaths_New_14_RollingAvg',
 'Deaths_New_21_RollingAvg',
 'Deaths_New_28_RollingAvg',
 ]

# %%
combined_dataset_sub = mobility_covid_urban[columns]

# %%
#check to see matching
combined_dataset_sub[['State','StateCD']].sample(frac=.00004)
# Out:
#                  State StateCD
# 415065        Kentucky      KY
# 64361      Connecticut      CT
# 464163            Iowa      IA
# 87528         Oklahoma      OK
# 543164         Georgia      GA
# 451682            Iowa      IA
# 92990         Oklahoma      OK
# 311792            Utah      UT
# 453002       Louisiana      LA
# 367060     Mississippi      MS
# 453350       Louisiana      LA
# 646402     Mississippi      MS
# 55833            Texas      TX
# 407467       Louisiana      LA
# 606187      New Jersey      NJ
# 275660      California      CA
# 33002     South Dakota      SD
# 344883        Michigan      MI
# 367072     Mississippi      MS
# 475384        New York      NY
# 255781           Texas      TX
# 536310  North Carolina      NC
# 423097          Kansas      KS
# 3456         Tennessee      TN
# 308091            Utah      UT
# 556463        Missouri      MO
# 446926            Iowa      IA

# %%
def create_percapita_measures(dataframe):
    list_col = list(dataframe.columns)
    for i in list_col:
        if dataframe[i].dtype == "O":
            continue
        if "percent" in i or "PCT" in i:
            continue
        if "death" in i.lower() or "confirmed" in i.lower() and "previous" not in i.lower() :
            try:
                new_col_name = i+'_PER_100K'
                dataframe[new_col_name] = dataframe[i]/(dataframe['Population_ACS']/100000)
            except:
                print("error occurred for {i}".format(i=i))

# %%
create_percapita_measures(combined_dataset_sub)
# Out:
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
combined_dataset_sub.Deaths_New_7_RollingAvg_PER_100K.isna().value_counts()
# Out:
# False    670260
# Name: Deaths_New_7_RollingAvg_PER_100K, dtype: int64

# %%
combined_dataset_sub.Population_ACS.isna().value_counts()
# Out:
# False    670260
# Name: Population_ACS, dtype: int64

# %%
combined_dataset_sub.Deaths_New_7_RollingAvg_PER_100K.isna().value_counts()
# Out:
# False    670260
# Name: Deaths_New_7_RollingAvg_PER_100K, dtype: int64

# %%
combined_dataset_sub.Metro.isna().value_counts()
# Out:
# False    670260
# Name: Metro, dtype: int64

# %% [markdown]
# ## Export to File

# %%
import os
os.chdir(r'/Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets/')
path = str(os.getcwd())
filename = "hia_covid_combined.csv"
combined_dataset_sub.to_csv(filename)
print("{filename} has been created in {path}".format(filename=filename, path=path))
# Out:
# hia_covid_combined.csv has been created in /Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets

# %%
import os
os.chdir(r'/Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets/')
path = str(os.getcwd())
filename = "hia_covid_combined_sample.csv"
combined_dataset_sub.sample(frac=.10).to_csv(filename)
print("{filename} has been created in {path}".format(filename=filename, path=path))
# Out:
# hia_covid_combined_sample.csv has been created in /Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets

# %%
# ratio to check join 
combined_dataset_sub.shape[0]/mobility_counties.shape[0]
# Out:
# 0.9970056807279186

# %%
import os
os.chdir(r'/Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets/')
path = str(os.getcwd())
filename = "hia_covid_combined_post0601.csv"
combined_dataset_sub[combined_dataset_sub.Date >= '2020-06-01'].to_csv(filename)
print("{filename} has been created in {path}".format(filename=filename, path=path))
# Out:
# hia_covid_combined_post0601.csv has been created in /Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets
