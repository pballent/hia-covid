# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from tqdm import tqdm 
tqdm.pandas()

import statsmodels.formula.api as smf
import numpy as np

from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/tqdm/std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
# ## Import Mobility Data

# %%
combined = pd.read_csv(r"/Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets/hia_covid_combined.csv", dtype={'County_FIPS': 'str'} )

# %%
combined['StateCD'] = combined['State Code']

# %%
combined_samp = combined.sample(frac=.2)

# %%
def regress_two_var(df, X, Y, startdate = "2020-01-01", enddate = "2020-10-01"):
    # Cleaning up the dataframe
    df = df[df.Date >= startdate]
    df = df[df.Date <= enddate]
    df = df[df['{Y}'.format(Y=Y)].isna() == False]
    df = df[df['{X}'.format(X=X)].isna() == False]
    #dataframe["ratio"] = dataframe['{Y}'.format(Y=Y)]/dataframe['{X}'.format(X=X)]
    Xvar =  df['{X}'.format(X=X)].values.reshape(-1, 1) 
    Xvar1 = sm.add_constant(Xvar) # need to do this for statsmodels for some reason
    Yvar = df['{Y}'.format(Y=Y)].values.reshape(-1, 1) 
    mod = sm.OLS(endog=Yvar,exog=Xvar1)
    res = mod.fit()
    print(res.summary())
    # Graph the regression
    linear_regressor = LinearRegression()  # create object for the class
    fitted_model = linear_regressor.fit(X=Xvar,y=Yvar)  # perform linear regression
    Y_pred = fitted_model.predict(Xvar)  # make predictions
    #return fitted_model
    plt.scatter(y=Yvar, x=Xvar)
    plt.plot(Xvar, Y_pred, color='red')
    plt.title("{X} on {Y} Regression".format(X=X,Y=Y))
    plt.show()
    #Scatterplot to show data
    sns.scatterplot(y='{Y}'.format(Y=Y),x='{X}'.format(X=X), hue="Division", data=df)

# %%
combined_oneday = combined[combined['Date']=='2020-10-01']

# %%
combined_oneday
# Out:
#         Unnamed: 0        Date County_FIPS State Code               Name  \
# 253            253  2020-10-01       01001         AL     Autauga County
# 569            569  2020-10-01       01003         AL     Baldwin County
# 885            885  2020-10-01       01005         AL     Barbour County
# 1201          1201  2020-10-01       01007         AL        Bibb County
# 1517          1517  2020-10-01       01009         AL      Blount County
# ...            ...         ...         ...        ...                ...
# 987753      987753  2020-10-01       56037         WY  Sweetwater County
# 988069      988069  2020-10-01       56039         WY       Teton County
# 988385      988385  2020-10-01       56041         WY       Uinta County
# 988701      988701  2020-10-01       56043         WY    Washakie County
# 989017      989017  2020-10-01       56045         WY      Weston County
#
#         retail_and_recreation_PCT_CFB  grocery_and_pharmacy_PCT_CFB  \
# 253                               5.0                          10.0
# 569                              -3.0                          -8.0
# 885                              12.0                           NaN
# 1201                              NaN                           NaN
# 1517                              1.0                           7.0
# ...                               ...                           ...
# 987753                           -8.0                           NaN
# 988069                           13.0                           NaN
# 988385                           14.0                           NaN
# 988701                            NaN                           NaN
# 989017                            NaN                           NaN
#
#         parks_PCT_CFB  transit_stations_PCT_CFB  workplaces_PCT_CFB  ...  \
# 253               NaN                       NaN               -18.0  ...
# 569               4.0                       9.0               -23.0  ...
# 885               NaN                       NaN               -16.0  ...
# 1201              NaN                       NaN               -14.0  ...
# 1517              NaN                       NaN               -21.0  ...
# ...               ...                       ...                 ...  ...
# 987753            NaN                      37.0               -16.0  ...
# 988069            NaN                     -20.0               -22.0  ...
# 988385            NaN                      41.0               -17.0  ...
# 988701            NaN                       NaN               -10.0  ...
# 989017            NaN                       NaN               -14.0  ...
#
#         Confirmed_New_PER_100K  Confirmed_New_RollingAvg_PER_100K  \
# 253                  12.718948                          16.352933
# 569                  13.276947                          41.025065
# 885                  22.899889                          17.447535
# 1201                 13.286094                          15.816778
# 1517                 13.872752                           7.431832
# ...                        ...                                ...
# 987753                6.737485                           4.491657
# 988069               61.074030                          38.638672
# 988385               -4.817420                           6.193825
# 988701                0.000000                           5.192917
# 989017                0.000000                          24.087196
#
#         Deaths_New_RollingAvg_PER_100K  Deaths_New_7_RollingAvg_PER_100K  \
# 253                           0.778711                          0.000000
# 569                           0.210745                          0.772732
# 885                           0.000000                          1.090471
# 1201                          0.000000                          1.265342
# 1517                          0.000000                          0.247728
# ...                                ...                               ...
# 987753                        0.000000                          0.000000
# 988069                        0.000000                          0.000000
# 988385                        0.000000                          0.000000
# 988701                        0.000000                          0.000000
# 989017                        0.000000                          0.000000
#
#         Deaths_New_14_RollingAvg_PER_100K  Deaths_New_21_RollingAvg_PER_100K  \
# 253                              0.000000                           0.519141
# 569                              0.140497                           0.210745
# 885                              0.000000                           0.000000
# 1201                             0.632671                           0.632671
# 1517                             1.734094                           0.495455
# ...                                   ...                                ...
# 987753                           0.000000                           0.000000
# 988069                           0.000000                           0.000000
# 988385                           0.000000                           0.000000
# 988701                           1.730972                           0.000000
# 989017                           0.000000                           0.000000
#
#         Deaths_New_28_RollingAvg_PER_100K  Region            Division  StateCD
# 253                              0.259570   South  East South Central       AL
# 569                              0.000000   South  East South Central       AL
# 885                              0.000000   South  East South Central       AL
# 1201                             0.632671   South  East South Central       AL
# 1517                             0.000000   South  East South Central       AL
# ...                                   ...     ...                 ...      ...
# 987753                           0.000000    West            Mountain       WY
# 988069                           0.000000    West            Mountain       WY
# 988385                           0.688203    West            Mountain       WY
# 988701                           0.000000    West            Mountain       WY
# 989017                           0.000000    West            Mountain       WY
#
# [3130 rows x 69 columns]

# %%
regress_two_var(df=combined_oneday,X="Poverty_PCT_2018",Y="transit_stations_PCT_CFB")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     18.89
# Date:                Sat, 05 Dec 2020   Prob (F-statistic):           1.53e-05
# Time:                        16:16:19   Log-Likelihood:                -4597.0
# No. Observations:                 990   AIC:                             9198.
# Df Residuals:                     988   BIC:                             9208.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -15.2637      2.177     -7.013      0.000     -19.535     -10.993
# x1             0.6205      0.143      4.346      0.000       0.340       0.901
# ==============================================================================
# Omnibus:                        1.509   Durbin-Watson:                   1.726
# Prob(Omnibus):                  0.470   Jarque-Bera (JB):                1.443
# Skew:                          -0.007   Prob(JB):                        0.486
# Kurtosis:                       3.187   Cond. No.                         41.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#mobility_counties[mobility_counties.UrbanCD == 1]

# %%
mobility_counties.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6586f57a6589> in <module>
# ----> 1 mobility_counties.columns
#
# NameError: name 'mobility_counties' is not defined

# %%
def multivariate_ols(input_df, Y, Xlist):
    # Reshape the df to avoid NAs
    dataframe = input_df
    dataframe = dataframe[dataframe['{Y}'.format(Y=Y)].isna() == False]
    # Clean out any rows where one of these is NA -- can lead to data loss
    for i in Xlist:
        dataframe = dataframe[dataframe[i].isna() == False]
    # Check to ensure not too much thrown away
    pct_preserved = dataframe.shape[0]/input_df.shape[0]
    print("{pct} percent of the data preserved as non-NA".format(pct = 100*round(pct_preserved,2)))
    Xvar =  dataframe[Xlist]#.values.reshape(-1, len(Xlist)) 
    Xvar = sm.add_constant(Xvar)
    Yvar = dataframe['{Y}'.format(Y=Y)].values.reshape(-1, 1) 
    mod = sm.OLS(endog=Yvar,exog=Xvar,)
    res = mod.fit()
    print(res.summary())
    return res

# %%
Xlist = ['HS_DIPLOMA_ONLY_2018',"Poverty_PCT_2018","Median_Income_2018","SOME_COLLEGE_2018"]

multivariate_ols(input_df=combined, Y="workplaces_PCT_CFB", Xlist=Xlist)

# %%
combined.columns

# %%
combined['StateCD'] = combined['State Code']

# %%
full_predictors = [
 'C(Metro)',
 'HS_DIPLOMA_ONLY_2018',
 'PCT_Black_ACS',
 'BACHELORS_PLUS_2018',
 'Confirmed_New_RollingAvg_PER_100K',
 'workplaces_PCT_CFB',
 'residential_PCT_CFB_RollingAvg',
 'Poverty_PCT_2018',
 'Median_Income_2018',
 'C(Region)',
 'C(StateCD)',
    
]

Ylist = [#'Deaths_New_7_RollingAvg_PER_100K',
         #'Deaths_New_14_RollingAvg_PER_100K',
         #'Deaths_New_28_RollingAvg_PER_100K',
         'Deaths_PER_100K']

# %%
# https://stackoverflow.com/questions/1482308/how-to-get-all-subsets-of-a-set-powerset
from itertools import chain, combinations

def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return set(chain.from_iterable(combinations(s, r) for r in range(len(s)+1)))

ps = powerset(full_predictors)
ps_list = [list(i) for i in ps]

# %%
#mobility_counties_dummies = pd.get_dummies(mobility_counties, columns=[ 'StateCD','UrbanCD'])

# %%
textlist = []

for i in ps_list:
    text = '|'
    for x in i:
        #text.join('+ '+x)
        #print(x)
        text = text+' + '+x
    textlist.append(text)


textlist = [i.replace('| +','') for i in textlist if len(i) > 3]
    
full_form_list = []
for i in textlist:
    for y in Ylist:
        full_form_list.append(y+" ~ "+i)


full_form_list
samp_list = full_form_list[0:50]

# %%
len(full_form_list)
# Out:
# 2047

# %%
mobility_counties_samp.UrbanCD.value_counts()

# %%
mobility_counties

# %%
mobility_counties = pd.get_dummies(mobility_counties, columns=["UrbanCD"])

# %%
mobility_counties.UrbanCD

# %%
sns.relplot(data=mobility_counties, x="retail_and_recreation_percent_change_from_baseline", y="HS_DIPLOMA_ONLY_2018", hue="UrbanCD_3")

# %%
sns.pairplot(mobility_counties_samp[['HS_DIPLOMA_ONLY_2018',
 'SOME_COLLEGE_2018', 'Median_Income_2018',
 'Poverty_PCT_2018']], kind="hist", height=5)

# %%
sns.pairplot(mobility_counties_samp[['HS_DIPLOMA_ONLY_2018',
 'Poverty_PCT_2018','UrbanCD']],hue="UrbanCD", kind="kde", height=4)

# %%
Xlist = ['HS_DIPLOMA_ONLY_2018',"Poverty_PCT_2018","Median_Income_2018","SOME_COLLEGE_2018"]

multivariate_ols(input_df=mobility_counties, Y="workplaces_percent_change_from_baseline", Xlist=Xlist)

# %% [markdown]
# ## R - Like Formula - Based OLS

# %%
combined.columns

# %%
test = combined[['HS_DIPLOMA_ONLY_2018',"Poverty_PCT_2018", "State Code", "Metro", "Region",
                   "Median_Income_2018","SOME_COLLEGE_2018","workplaces_PCT_CFB"]].dropna()

test['StateCD'] = test['State Code']

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
list_col = ['Deaths_New_14_RollingAvg_PER_100K','HS_DIPLOMA_ONLY_2018',"Poverty_PCT_2018", "State Code", "Metro", "Region",
                   "Median_Income_2018","SOME_COLLEGE_2018","Confirmed_New_RollingAvg_PER_100K", "Population_ACS"]

test = combined[list_col].dropna()

#test = test[test.Metro == "Large_metro"]

pct_null = str(round(100*(test.shape[0]/combined.shape[0]),2))
print(pct_null+' percent of the original data preserved')

test['StateCD'] = test['State Code']

mod = smf.ols(formula='Deaths_New_14_RollingAvg_PER_100K ~ Confirmed_New_RollingAvg_PER_100K + C(Metro) + C(StateCD) + Poverty_PCT_2018 + Poverty_PCT_2018*C(Metro)' , data=test)
res = mod.fit()
print(res.summary())

# %% [markdown]
# ## Define a Function for Formula-Based OLS

# %%
def start_end_mulivariate_ols(formulatxt, startdate="2020-06-01", enddate="2020-11-15", df=combined):
    segmented = df[df.Date > startdate]
    segmented = segmented[segmented.Date < enddate]
    mod = smf.ols(formula=formulatxt , data=segmented, missing='drop')
    res = mod.fit()
    #print(res.summary())
    return res

# %%
combined.columns

# %%
mod1 = start_end_mulivariate_ols(startdate = "2020-07-01", enddate = "2020-10-07", formulatxt="""
Deaths_New_RollingAvg_PER_100K ~  workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Region""")
print(mod1.summary())

# %%
mod1 = start_end_mulivariate_ols(startdate = "2020-10-01", enddate = "2020-10-07", formulatxt="""
Deaths_New_RollingAvg_PER_100K ~ HS_DIPLOMA_ONLY_2018 + residential_PCT_CFB_RollingAvg +
Poverty_PCT_2018 + Median_Income_2018 + C(Region)""")

# %%
#dir(mod1)
#mod1.bic

# %%
every_month = []
for i in range(4,9):
    a = '2020-0{c}-01'.format(c=i)
    b = '2020-0{c}-01'.format(c=i+1)
    every_month.append((a,b))
every_month.append(('2020-09-01','2020-10-01'))
every_month.append(('2020-10-01','2020-11-01'))
for i in range(10,12):
    a = '2020-{c}-01'.format(c=i)
    b = '2020-{c}-01'.format(c=i+1)
every_month.append((a,b))
every_month
# Out:
# [('2020-04-01', '2020-05-01'),
#  ('2020-05-01', '2020-06-01'),
#  ('2020-06-01', '2020-07-01'),
#  ('2020-07-01', '2020-08-01'),
#  ('2020-08-01', '2020-09-01'),
#  ('2020-09-01', '2020-10-01'),
#  ('2020-10-01', '2020-11-01'),
#  ('2020-11-01', '2020-12-01')]

# %%
every_3month =[
 ('2020-04-01', '2020-07-01'),
 ('2020-05-01', '2020-08-01'),
 ('2020-06-01', '2020-09-01'),
 ('2020-07-01', '2020-10-01'),
 ('2020-08-01', '2020-11-01'),
 ('2020-09-01', '2020-12-01')
]

# %%
#dir(mod1)

# %%
formula1 = """
workplaces_PCT_CFB ~ 
HS_DIPLOMA_ONLY_2018 + C(Metro) +  C(Metro)*HS_DIPLOMA_ONLY_2018 + Division"""

def run_timeseries_models(formulatxt, list_dateranges, df):
    list_results = []
    for i in list_dateranges:
        res = start_end_mulivariate_ols(formulatxt = formulatxt, startdate = i[0], enddate = i[1], df=df)
        name = i[0]+"-"+i[1]
        list_results.append({"model":res,"start":i[0], "end":i[1]})
    
    resultslist = [{"bic":i['model'].bic, 
                    "aic":i['model'].aic, 
                    "start":i['start'], 
                    "end":i['end'], 
                    "r2_adj":i["model"].rsquared_adj,
                    "formula":formulatxt} for i in list_results]
    return pd.DataFrame.from_dict(resultslist)

# %%
df = run_timeseries_models(formulatxt=formula1, list_dateranges=every_3month, df=combined)

# %%
df

# %%
def graph_bic_adj2_TS(formulatxt, list_dateranges, df):
    df_graph = run_timeseries_models(formulatxt=formulatxt, list_dateranges=list_dateranges, df=df)
    plt.figure(figsize=(12,6))
    ax = sns.lineplot(x="start", y="bic", label="BIC", data=df_graph)
    plt.legend(loc="upper right")
    ax2 = ax.twinx()
    ax2 = sns.lineplot(x="start", y="r2_adj", label="R2_ADJ", color='red', data=df_graph)
    plt.title("BIC vs R2_ADJ")
    plt.legend(loc="upper left")
    print(formulatxt)
    print()

# %%
formula1 = """Deaths_New_RollingAvg_PER_100K ~  workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Region"""

graph_bic_adj2_TS(formulatxt=formula1, list_dateranges=every_month, df=combined)

# %%
#start_end_mulivariate_ols()

print(len(full_form_list))
# Out:
# 4094

# %%
full_form_list
# Out:
# ['Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + workplaces_PCT_CFB + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + workplaces_PCT_CFB + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018',
#  'Deaths_PER_100K ~  workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB + Poverty_PCT_2018',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB + Poverty_PCT_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + C(StateCD)',
#  'Deaths_PER_100K ~  BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018',
#  'Deaths_PER_100K ~  C(Metro) + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Median_Income_2018',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region)',
#  'Deaths_PER_100K ~  workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + C(StateCD)',
#  'Deaths_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + workplaces_PCT_CFB + Poverty_PCT_2018',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + workplaces_PCT_CFB + Poverty_PCT_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + workplaces_PCT_CFB + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + workplaces_PCT_CFB + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018',
#  'Deaths_PER_100K ~  BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018',
#  'Deaths_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + C(Region)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + residential_PCT_CFB_RollingAvg + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + residential_PCT_CFB_RollingAvg + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Poverty_PCT_2018',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Poverty_PCT_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg',
#  'Deaths_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + workplaces_PCT_CFB',
#  'Deaths_PER_100K ~  PCT_Black_ACS + workplaces_PCT_CFB',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  BACHELORS_PLUS_2018 + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  BACHELORS_PLUS_2018 + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018',
#  'Deaths_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  Poverty_PCT_2018',
#  'Deaths_PER_100K ~  Poverty_PCT_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018',
#  'Deaths_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018',
#  'Deaths_PER_100K ~  PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + C(Region)',
#  'Deaths_PER_100K ~  BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region)',
# ...
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Median_Income_2018',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg',
#  'Deaths_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg',
#  'Deaths_New_7_RollingAvg_PER_100K ~  workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Median_Income_2018',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + C(Region)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Median_Income_2018 + C(Region) + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + HS_DIPLOMA_ONLY_2018 + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_PER_100K ~  PCT_Black_ACS + BACHELORS_PLUS_2018 + Confirmed_New_RollingAvg_PER_100K + Poverty_PCT_2018 + Median_Income_2018 + C(Region)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + C(StateCD)',
#  'Deaths_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + C(StateCD)',
#  'Deaths_New_7_RollingAvg_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  'Deaths_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + workplaces_PCT_CFB + residential_PCT_CFB_RollingAvg + Median_Income_2018',
#  ...]

# %%
list_df_graph = []
for i in tqdm(full_form_list):
    try:
        df_graph = run_timeseries_models(formulatxt=i, list_dateranges=every_3month, df=combined_samp.sample(frac=.5))
        list_df_graph.append(df_graph)
        #print("Finished with "+i)
    except:
        print("Error for "+i)
        continue


bigdf = pd.concat(list_df_graph)
# Out:
# 100%|██████████| 2047/2047 [42:25<00:00,  1.24s/it]

# %%
bigdf['num_var'] = bigdf['formula'].str.count('\+')+1

# %%
list_forms =[i for i in list(bigdf['formula'].unique()) if "Confirmed" not in i and "CFB" not in i]
bigdf[bigdf.formula.isin(list_forms) & (bigdf.num_var == 1)].groupby("formula").mean().sort_values(by="bic",ascending=True).head(10)
# Out:
#                                                    bic            aic  \
# formula
# Deaths_PER_100K ~  C(StateCD)            280389.627075  279976.993752
# Deaths_PER_100K ~  PCT_Black_ACS         282653.023602  282636.521962
# Deaths_PER_100K ~  C(Region)             286034.598818  286001.583987
# Deaths_PER_100K ~  Poverty_PCT_2018      287749.404592  287732.895320
# Deaths_PER_100K ~  C(Metro)              287976.403106  287935.130975
# Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018  288252.665487  288236.162676
# Deaths_PER_100K ~  Median_Income_2018    288673.766871  288657.258389
# Deaths_PER_100K ~  BACHELORS_PLUS_2018   289124.400196  289107.895703
#
#                                            r2_adj  num_var
# formula
# Deaths_PER_100K ~  C(StateCD)            0.267799        1
# Deaths_PER_100K ~  PCT_Black_ACS         0.161676        1
# Deaths_PER_100K ~  C(Region)             0.079988        1
# Deaths_PER_100K ~  Poverty_PCT_2018      0.049811        1
# Deaths_PER_100K ~  C(Metro)              0.034894        1
# Deaths_PER_100K ~  HS_DIPLOMA_ONLY_2018  0.002192        1
# Deaths_PER_100K ~  Median_Income_2018    0.010016        1
# Deaths_PER_100K ~  BACHELORS_PLUS_2018   0.006822        1

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(18,9))
sns.scatterplot(x="r2_adj", y="bic", hue="num_var", data=bigdf)

# %%
bigdf[bigdf.bic <]

# %%
dict(top10.sort_values(by="bic", ascending=True).iloc[0])

# %%
formula1 = """Deaths_PER_100K ~ HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Poverty_PCT_2018 + C(StateCD)
"""
graph_bic_adj2_TS(formulatxt=formula1, list_dateranges=every_month, df=combined)

mod2 = start_end_mulivariate_ols(formulatxt=formula1, startdate='2020-06-01', enddate='2020-11-15', df= combined)
print(mod2.summary())
# Out:
# Deaths_PER_100K ~ HS_DIPLOMA_ONLY_2018 + PCT_Black_ACS + BACHELORS_PLUS_2018 + Poverty_PCT_2018 + C(StateCD)
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Deaths_PER_100K   R-squared:                       0.291
# Model:                            OLS   Adj. R-squared:                  0.291
# Method:                 Least Squares   F-statistic:                     4023.
# Date:                Sun, 06 Dec 2020   Prob (F-statistic):               0.00
# Time:                        12:15:24   Log-Likelihood:            -2.6624e+06
# No. Observations:              519414   AIC:                         5.325e+06
# Df Residuals:                  519360   BIC:                         5.326e+06
# Df Model:                          53
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               23.8981      1.101     21.714      0.000      21.741      26.055
# C(StateCD)[T.AL]        19.5953      0.731     26.822      0.000      18.163      21.027
# C(StateCD)[T.AR]        13.5875      0.707     19.216      0.000      12.202      14.973
# C(StateCD)[T.AZ]        63.6081      1.023     62.200      0.000      61.604      65.612
# C(StateCD)[T.CA]         6.9551      0.745      9.339      0.000       5.495       8.415
# C(StateCD)[T.CO]        14.5591      0.720     20.219      0.000      13.148      15.970
# C(StateCD)[T.CT]        86.3003      1.272     67.870      0.000      83.808      88.793
# C(StateCD)[T.DE]        47.8138      1.925     24.842      0.000      44.042      51.586
# C(StateCD)[T.FL]        27.0758      0.716     37.812      0.000      25.672      28.479
# C(StateCD)[T.GA]        37.5672      0.668     56.240      0.000      36.258      38.876
# C(StateCD)[T.HI]         3.4744      1.691      2.055      0.040       0.161       6.788
# C(StateCD)[T.IA]        28.7426      0.678     42.377      0.000      27.413      30.072
# C(StateCD)[T.ID]         9.9264      0.769     12.908      0.000       8.419      11.434
# C(StateCD)[T.IL]        18.2528      0.677     26.968      0.000      16.926      19.579
# C(StateCD)[T.IN]        35.1234      0.685     51.278      0.000      33.781      36.466
# C(StateCD)[T.KS]        11.3389      0.676     16.775      0.000      10.014      12.664
# C(StateCD)[T.KY]         8.9012      0.667     13.344      0.000       7.594      10.209
# C(StateCD)[T.LA]        57.1044      0.741     77.022      0.000      55.651      58.558
# C(StateCD)[T.MA]        95.5889      1.042     91.713      0.000      93.546      97.632
# C(StateCD)[T.MD]        26.5417      0.900     29.477      0.000      24.777      28.307
# C(StateCD)[T.ME]         6.0665      0.992      6.117      0.000       4.123       8.010
# C(StateCD)[T.MI]        17.0054      0.691     24.601      0.000      15.651      18.360
# C(StateCD)[T.MN]        13.5616      0.690     19.664      0.000      12.210      14.913
# C(StateCD)[T.MO]         9.0033      0.668     13.469      0.000       7.693      10.313
# C(StateCD)[T.MS]        42.2305      0.735     57.467      0.000      40.790      43.671
# C(StateCD)[T.MT]        12.8598      0.732     17.571      0.000      11.425      14.294
# C(StateCD)[T.NC]         3.2499      0.690      4.707      0.000       1.897       4.603
# C(StateCD)[T.ND]        19.5234      0.743     26.272      0.000      18.067      20.980
# C(StateCD)[T.NE]        13.1049      0.684     19.148      0.000      11.763      14.446
# C(StateCD)[T.NH]        15.7968      1.167     13.535      0.000      13.509      18.084
# C(StateCD)[T.NJ]       143.4935      0.921    155.864      0.000     141.689     145.298
# C(StateCD)[T.NM]        16.2575      0.820     19.815      0.000      14.649      17.866
# C(StateCD)[T.NV]         5.7911      0.977      5.927      0.000       3.876       7.706
# C(StateCD)[T.NY]        48.4274      0.721     67.158      0.000      47.014      49.841
# C(StateCD)[T.OH]        24.1684      0.690     35.051      0.000      22.817      25.520
# C(StateCD)[T.OK]        11.0182      0.699     15.772      0.000       9.649      12.387
# C(StateCD)[T.OR]         2.6751      0.804      3.329      0.001       1.100       4.250
# C(StateCD)[T.PA]        30.4115      0.723     42.067      0.000      28.995      31.828
# C(StateCD)[T.RI]        57.2081      1.539     37.172      0.000      54.192      60.224
# C(StateCD)[T.SC]        19.4100      0.785     24.730      0.000      17.872      20.948
# C(StateCD)[T.SD]        15.8306      0.714     22.185      0.000      14.432      17.229
# C(StateCD)[T.TN]        16.3258      0.683     23.892      0.000      14.987      17.665
# C(StateCD)[T.TX]        27.4666      0.638     43.080      0.000      26.217      28.716
# C(StateCD)[T.UT]         3.9292      0.843      4.661      0.000       2.277       5.582
# C(StateCD)[T.VA]        12.9660      0.669     19.378      0.000      11.655      14.277
# C(StateCD)[T.VT]         6.2917      1.038      6.060      0.000       4.257       8.327
# C(StateCD)[T.WA]         9.1812      0.792     11.593      0.000       7.629      10.733
# C(StateCD)[T.WI]        14.0536      0.705     19.924      0.000      12.671      15.436
# C(StateCD)[T.WV]         7.0700      0.743      9.520      0.000       5.614       8.526
# C(StateCD)[T.WY]         3.8088      0.893      4.268      0.000       2.060       5.558
# HS_DIPLOMA_ONLY_2018    -0.6545      0.017    -37.791      0.000      -0.688      -0.621
# PCT_Black_ACS            0.9191      0.006    144.348      0.000       0.907       0.932
# BACHELORS_PLUS_2018     -0.4010      0.013    -30.835      0.000      -0.426      -0.375
# Poverty_PCT_2018         0.7156      0.014     52.777      0.000       0.689       0.742
# ==============================================================================
# Omnibus:                   336858.586   Durbin-Watson:                   0.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7083580.557
# Skew:                           2.801   Prob(JB):                         0.00
# Kurtosis:                      20.202   Cond. No.                     3.38e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.38e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
formula1 = """Deaths_PER_100K ~ C(Metro) + PCT_Black_ACS + Poverty_PCT_2018 + C(StateCD)"""
graph_bic_adj2_TS(formulatxt=formula1, list_dateranges=every_month, df=combined)

mod2 = start_end_mulivariate_ols(formulatxt=formula1, startdate='2020-06-01', enddate='2020-11-15', df= combined)
print(mod2.summary())
# Out:
# Deaths_PER_100K ~ C(Metro) + PCT_Black_ACS + Poverty_PCT_2018 + C(StateCD)
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Deaths_PER_100K   R-squared:                       0.293
# Model:                            OLS   Adj. R-squared:                  0.293
# Method:                 Least Squares   F-statistic:                     3914.
# Date:                Sun, 06 Dec 2020   Prob (F-statistic):               0.00
# Time:                        12:30:39   Log-Likelihood:            -2.6617e+06
# No. Observations:              519414   AIC:                         5.324e+06
# Df Residuals:                  519358   BIC:                         5.324e+06
# Df Model:                          55
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -0.1913      0.643     -0.298      0.766      -1.451       1.068
# C(Metro)[T.Micropolitan]        -8.5575      0.221    -38.790      0.000      -8.990      -8.125
# C(Metro)[T.Noncore_adjacent]    -8.9364      0.212    -42.138      0.000      -9.352      -8.521
# C(Metro)[T.Noncore_remote]     -13.8620      0.281    -49.390      0.000     -14.412     -13.312
# C(Metro)[T.Smaller_metro]       -9.1122      0.205    -44.362      0.000      -9.515      -8.710
# C(StateCD)[T.AL]                17.1523      0.740     23.176      0.000      15.702      18.603
# C(StateCD)[T.AR]                 9.5960      0.720     13.322      0.000       8.184      11.008
# C(StateCD)[T.AZ]                62.7364      1.027     61.113      0.000      60.724      64.748
# C(StateCD)[T.CA]                 7.2591      0.742      9.785      0.000       5.805       8.713
# C(StateCD)[T.CO]                12.9942      0.721     18.027      0.000      11.581      14.407
# C(StateCD)[T.CT]                80.1980      1.277     62.821      0.000      77.696      82.700
# C(StateCD)[T.DE]                42.9094      1.928     22.254      0.000      39.130      46.689
# C(StateCD)[T.FL]                22.9020      0.731     31.344      0.000      21.470      24.334
# C(StateCD)[T.GA]                34.1367      0.680     50.173      0.000      32.803      35.470
# C(StateCD)[T.HI]                 1.7599      1.695      1.038      0.299      -1.562       5.082
# C(StateCD)[T.IA]                26.6058      0.688     38.644      0.000      25.256      27.955
# C(StateCD)[T.ID]                10.0880      0.774     13.029      0.000       8.570      11.606
# C(StateCD)[T.IL]                14.9000      0.689     21.627      0.000      13.550      16.250
# C(StateCD)[T.IN]                28.5748      0.698     40.934      0.000      27.207      29.943
# C(StateCD)[T.KS]                11.6124      0.678     17.138      0.000      10.284      12.940
# C(StateCD)[T.KY]                 3.8429      0.681      5.646      0.000       2.509       5.177
# C(StateCD)[T.LA]                52.2252      0.754     69.283      0.000      50.748      53.703
# C(StateCD)[T.MA]                89.4826      1.045     85.653      0.000      87.435      91.530
# C(StateCD)[T.MD]                20.2151      0.910     22.208      0.000      18.431      21.999
# C(StateCD)[T.ME]                 2.2210      0.996      2.231      0.026       0.270       4.172
# C(StateCD)[T.MI]                14.0093      0.701     19.992      0.000      12.636      15.383
# C(StateCD)[T.MN]                11.5035      0.698     16.480      0.000      10.135      12.872
# C(StateCD)[T.MO]                 3.0502      0.681      4.476      0.000       1.715       4.386
# C(StateCD)[T.MS]                41.6117      0.743     55.968      0.000      40.154      43.069
# C(StateCD)[T.MT]                11.3748      0.733     15.514      0.000       9.938      12.812
# C(StateCD)[T.NC]                 2.8056      0.698      4.021      0.000       1.438       4.173
# C(StateCD)[T.ND]                20.8986      0.743     28.127      0.000      19.442      22.355
# C(StateCD)[T.NE]                13.5823      0.686     19.788      0.000      12.237      14.928
# C(StateCD)[T.NH]                10.9273      1.174      9.305      0.000       8.626      13.229
# C(StateCD)[T.NJ]               134.1285      0.933    143.753      0.000     132.300     135.957
# C(StateCD)[T.NM]                14.1614      0.828     17.106      0.000      12.539      15.784
# C(StateCD)[T.NV]                 5.9140      0.979      6.042      0.000       3.996       7.833
# C(StateCD)[T.NY]                42.6434      0.736     57.934      0.000      41.201      44.086
# C(StateCD)[T.OH]                16.7387      0.702     23.842      0.000      15.363      18.115
# C(StateCD)[T.OK]                 6.4177      0.713      8.995      0.000       5.019       7.816
# C(StateCD)[T.OR]                 2.3574      0.806      2.926      0.003       0.778       3.937
# C(StateCD)[T.PA]                21.0855      0.726     29.026      0.000      19.662      22.509
# C(StateCD)[T.RI]                46.2076      1.549     29.836      0.000      43.172      49.243
# C(StateCD)[T.SC]                17.7480      0.796     22.291      0.000      16.187      19.308
# C(StateCD)[T.SD]                12.6095      0.721     17.480      0.000      11.196      14.023
# C(StateCD)[T.TN]                 9.8783      0.698     14.147      0.000       8.510      11.247
# C(StateCD)[T.TX]                26.4562      0.643     41.150      0.000      25.196      27.716
# C(StateCD)[T.UT]                 4.9355      0.843      5.853      0.000       3.283       6.588
# C(StateCD)[T.VA]                 8.7686      0.682     12.858      0.000       7.432      10.105
# C(StateCD)[T.VT]                 1.7347      1.042      1.664      0.096      -0.308       3.778
# C(StateCD)[T.WA]                 9.4363      0.795     11.874      0.000       7.879      10.994
# C(StateCD)[T.WI]                10.5355      0.715     14.742      0.000       9.135      11.936
# C(StateCD)[T.WV]                -1.2044      0.751     -1.605      0.109      -2.676       0.267
# C(StateCD)[T.WY]                 4.3892      0.895      4.904      0.000       2.635       6.143
# PCT_Black_ACS                    0.8403      0.006    130.213      0.000       0.828       0.853
# Poverty_PCT_2018                 1.0437      0.013     78.445      0.000       1.018       1.070
# ==============================================================================
# Omnibus:                   340426.411   Durbin-Watson:                   0.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7349277.436
# Skew:                           2.835   Prob(JB):                         0.00
# Kurtosis:                      20.534   Cond. No.                     1.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
formula1 = """Deaths_PER_100K ~ C(Region)"""
graph_bic_adj2_TS(formulatxt=formula1, list_dateranges=every_month, df=combined)
mod2 = start_end_mulivariate_ols(formulatxt=formula1, startdate='2020-06-01', enddate='2020-11-15', df= combined)
print(mod2.summary())
# Out:
# Deaths_PER_100K ~ C(Region)
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Deaths_PER_100K   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                 1.285e+04
# Date:                Sun, 06 Dec 2020   Prob (F-statistic):               0.00
# Time:                        12:31:34   Log-Likelihood:            -2.7340e+06
# No. Observations:              519580   AIC:                         5.468e+06
# Df Residuals:                  519576   BIC:                         5.468e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 21.6858      0.112    194.295      0.000      21.467      21.905
# C(Region)[T.Northeast]    30.7755      0.270    113.977      0.000      30.246      31.305
# C(Region)[T.South]        22.2077      0.147    150.636      0.000      21.919      22.497
# C(Region)[T.West]         -5.1554      0.205    -25.195      0.000      -5.556      -4.754
# ==============================================================================
# Omnibus:                   332551.738   Durbin-Watson:                   0.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4977966.944
# Skew:                           2.883   Prob(JB):                         0.00
# Kurtosis:                      17.025   Cond. No.                         5.12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
formula1 = """Deaths_PER_100K ~ C(StateCD) + C(Region)"""
graph_bic_adj2_TS(formulatxt=formula1, list_dateranges=every_month, df=combined)
mod2 = start_end_mulivariate_ols(formulatxt=formula1, startdate='2020-06-01', enddate='2020-11-15', df= combined)
print(mod2.summary())
# Out:
# Deaths_PER_100K ~ C(StateCD) + C(Region)
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Deaths_PER_100K   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.237
# Method:                 Least Squares   F-statistic:                     3098.
# Date:                Sun, 06 Dec 2020   Prob (F-statistic):               0.00
# Time:                        12:33:17   Log-Likelihood:            -2.6824e+06
# No. Observations:              519580   AIC:                         5.365e+06
# Df Residuals:                  519527   BIC:                         5.366e+06
# Df Model:                          52
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept               3.184e+09   2.74e+11      0.012      0.991   -5.33e+11    5.39e+11
# C(StateCD)[T.AL]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.AR]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.AZ]          73.5144      1.053     69.807      0.000      71.450      75.578
# C(StateCD)[T.CA]          14.6856      0.764     19.228      0.000      13.189      16.183
# C(StateCD)[T.CO]          15.8848      0.749     21.219      0.000      14.418      17.352
# C(StateCD)[T.CT]        6.539e+11    7.9e+11      0.828      0.408   -8.94e+11     2.2e+12
# C(StateCD)[T.DE]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.FL]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.GA]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.HI]           1.2215      1.754      0.696      0.486      -2.217       4.660
# C(StateCD)[T.IA]       -3.184e+09   2.74e+11     -0.012      0.991   -5.39e+11    5.33e+11
# C(StateCD)[T.ID]          11.4922      0.794     14.477      0.000       9.936      13.048
# C(StateCD)[T.IL]       -3.184e+09   2.74e+11     -0.012      0.991   -5.39e+11    5.33e+11
# C(StateCD)[T.IN]       -3.184e+09   2.74e+11     -0.012      0.991   -5.39e+11    5.33e+11
# C(StateCD)[T.KS]       -3.184e+09   2.74e+11     -0.012      0.991   -5.39e+11    5.33e+11
# C(StateCD)[T.KY]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.LA]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.MA]        6.539e+11    7.9e+11      0.828      0.408   -8.94e+11     2.2e+12
# C(StateCD)[T.MD]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.ME]        6.539e+11    7.9e+11      0.828      0.408   -8.94e+11     2.2e+12
# C(StateCD)[T.MI]       -3.184e+09   2.74e+11     -0.012      0.991   -5.39e+11    5.33e+11
# C(StateCD)[T.MN]       -3.184e+09   2.74e+11     -0.012      0.991   -5.39e+11    5.33e+11
# C(StateCD)[T.MO]       -3.184e+09   2.74e+11     -0.012      0.991   -5.39e+11    5.33e+11
# C(StateCD)[T.MS]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.MT]          12.4456      0.762     16.339      0.000      10.953      13.939
# C(StateCD)[T.NC]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.ND]       -3.184e+09   2.74e+11     -0.012      0.991   -5.39e+11    5.33e+11
# C(StateCD)[T.NE]       -3.184e+09   2.74e+11     -0.012      0.991   -5.39e+11    5.33e+11
# C(StateCD)[T.NH]        6.539e+11    7.9e+11      0.828      0.408   -8.94e+11     2.2e+12
# C(StateCD)[T.NJ]        6.539e+11    7.9e+11      0.828      0.408   -8.94e+11     2.2e+12
# C(StateCD)[T.NM]          24.6726      0.844     29.248      0.000      23.019      26.326
# C(StateCD)[T.NV]           8.6997      1.009      8.620      0.000       6.722      10.678
# C(StateCD)[T.NY]        6.539e+11    7.9e+11      0.828      0.408   -8.94e+11     2.2e+12
# C(StateCD)[T.OH]       -3.184e+09   2.74e+11     -0.012      0.991   -5.39e+11    5.33e+11
# C(StateCD)[T.OK]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.OR]           6.4277      0.827      7.769      0.000       4.806       8.049
# C(StateCD)[T.PA]        6.539e+11    7.9e+11      0.828      0.408   -8.94e+11     2.2e+12
# C(StateCD)[T.RI]        6.539e+11    7.9e+11      0.828      0.408   -8.94e+11     2.2e+12
# C(StateCD)[T.SC]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.SD]       -3.184e+09   2.74e+11     -0.012      0.991   -5.39e+11    5.33e+11
# C(StateCD)[T.TN]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.TX]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.UT]           3.9981      0.869      4.600      0.000       2.294       5.702
# C(StateCD)[T.VA]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.VT]        6.539e+11    7.9e+11      0.828      0.408   -8.94e+11     2.2e+12
# C(StateCD)[T.WA]          12.8096      0.812     15.767      0.000      11.217      14.402
# C(StateCD)[T.WI]       -3.184e+09   2.74e+11     -0.012      0.991   -5.39e+11    5.33e+11
# C(StateCD)[T.WV]            1e+11   3.27e+11      0.306      0.760   -5.42e+11    7.42e+11
# C(StateCD)[T.WY]           3.2882      0.923      3.563      0.000       1.479       5.097
# C(Region)[T.Northeast] -6.571e+11   8.35e+11     -0.787      0.431   -2.29e+12    9.79e+11
# C(Region)[T.South]     -1.032e+11   3.87e+11     -0.267      0.790   -8.61e+11    6.55e+11
# C(Region)[T.West]      -3.184e+09   2.74e+11     -0.012      0.991   -5.39e+11    5.33e+11
# ==============================================================================
# Omnibus:                   355370.121   Durbin-Watson:                   0.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7716000.538
# Skew:                           3.017   Prob(JB):                         0.00
# Kurtosis:                      20.888   Cond. No.                     4.87e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.86e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
cols_subset = ["Deaths_PER_100K","Metro","PCT_Black_ACS","Poverty_PCT_2018","StateCD"] 
combined_sub2 = combined[cols_subset]

sns.set(rc={'figure.figsize':(11,8)})
corr = combined_sub2.corr()
sns.heatmap(corr, annot=True, fmt='.2f')
plt.show()
