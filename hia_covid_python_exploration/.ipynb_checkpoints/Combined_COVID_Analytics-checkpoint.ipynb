# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from tqdm import tqdm 
tqdm.pandas()

import statsmodels.formula.api as smf
import numpy as np

from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt

pd.options.display.float_format = '{:.2f}'.format
# Out:
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/tqdm/std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
# ## Import Mobility Data

# %%
combined = pd.read_csv(r"/Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets/hia_covid_combined.csv", dtype={'County_FIPS': 'str'} )

# %%
combined['StateCD'] = combined['State Code']

# %%
combined.shape
# Out:
# (1011313, 69)

# %%
combined.County_FIPS.unique().shape
# Out:
# (3131,)

# %% [markdown]
# ## County Population Descriptions

# %%
countylevel = combined.groupby("County_FIPS").max()

# %%
countylevel.Population_ACS.describe()
# Out:
# count       3131.00
# mean      101459.88
# std       327673.58
# min           74.00
# 25%        10948.50
# 50%        25687.00
# 75%        67058.50
# max     10105722.00
# Name: Population_ACS, dtype: float64

# %%
plt.style.use('fivethirtyeight')

# %%
plt.rcParams.update({'font.size': 13})
plt.style.use("dark_background") 
sns.set_style({'axes.grid' : False})
sns.displot(countylevel.Population_ACS, height=4, aspect=1.8, color="#00ffcd", kind="kde")
plt.xticks(rotation=75)
plt.ticklabel_format(useOffset=False, style='plain')

# %% [markdown]
# ## State Level Description of Deaths Per Capita on 2020-12-01

# %%
dec = combined[combined.Date == '2020-12-01']

# %%
statelevel = dec.groupby("StateCD").sum()

# %%
s2 = statelevel[['Deaths','Population_ACS']].reset_index()
s2['Deaths_PER_100K'] = s2['Deaths']/(s2['Population_ACS']/100000)
s2.sort_values(by="Deaths_PER_100K")
# Out:
#    StateCD  Deaths  Population_ACS  Deaths_PER_100K
# 45      VT      72       624636.00            11.53
# 20      ME     214      1330158.00            16.09
# 0       AK     122       737264.00            16.55
# 10      HI     242      1421572.00            17.02
# 43      UT     672      2993941.00            22.45
# 36      OR     936      4025127.00            23.25
# 46      WA    2802      7169967.00            39.08
# 49      WY     230       583200.00            39.44
# 29      NH     527      1331848.00            39.57
# 48      WV     758      1836843.00            41.27
# 16      KY    1943      4424376.00            43.92
# 35      OK    1758      3896251.00            45.12
# 44      VA    3392      6988060.00            48.54
# 4       CA   19304     38982847.00            49.52
# 15      KS    1498      2903820.00            51.59
# 26      NC    5284     10052564.00            52.56
# 23      MO    2746      5075761.00            54.10
# 34      OH    6548     11609756.00            56.40
# 28      NE    1076      1893921.00            56.81
# 5       CO    3109      5436519.00            57.19
# 12      ID     960      1657375.00            57.92
# 47      WI    3611      5763217.00            62.66
# 22      MN    3615      5490726.00            65.84
# 25      MT     698      1029862.00            67.78
# 41      TN    4562      6597381.00            69.15
# 32      NV    2164      2887725.00            74.94
# 1       AL    3638      4850771.00            75.00
# 19      MD    3888      5167442.00            75.24
# 31      NM    1589      2084828.00            76.22
# 11      IA    2449      3118102.00            78.54
# 42      TX   22114     27419612.00            80.65
# 37      PA   10504     12790505.00            82.12
# 7       DE     777       943732.00            82.33
# 2       AR    2512      2977944.00            84.35
# 14      IN    5598      6614418.00            84.63
# 39      SC    4404      4893444.00            90.00
# 9       GA    9251     10201635.00            90.68
# 8       FL   18679     20278447.00            92.11
# 21      MI    9659      9925568.00            97.31
# 3       AZ    6687      6809946.00            98.19
# 13      IL   12992     12743375.00           101.95
# 40      SD     948       855444.00           110.82
# 38      RI    1300      1056138.00           123.09
# 27      ND     954       745475.00           127.97
# 24      MS    3836      2986220.00           128.46
# 17      LA    6435      4648531.00           138.43
# 6       CT    5039      3594478.00           140.19
# 18      MA   10770      6789319.00           158.63
# 33      NY   34501     19798228.00           174.26
# 30      NJ   17083      8960161.00           190.66

# %% [markdown]
# ## Yuma Example

# %%
yuma = combined[combined['locationcol'] == 'Yuma|Arizona']

# %%
yuma.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'County_FIPS', 'State Code', 'Name',
#        'retail_and_recreation_PCT_CFB', 'grocery_and_pharmacy_PCT_CFB',
#        'parks_PCT_CFB', 'transit_stations_PCT_CFB', 'workplaces_PCT_CFB',
#        'residential_PCT_CFB', 'retail_and_recreation_PCT_CFB_RollingAvg',
#        'grocery_and_pharmacy_PCT_CFB_RollingAvg', 'parks_PCT_CFB_RollingAvg',
#        'transit_stations_PCT_CFB_RollingAvg', 'workplaces_PCT_CFB_RollingAvg',
#        'residential_PCT_CFB_RollingAvg', 'HS_DIPLOMA_ONLY_2018',
#        'SOME_COLLEGE_2018', 'BACHELORS_PLUS_2018', 'Poverty_PCT_2018',
#        'UrbanCD', 'Median_Income_2018', 'Population_ACS',
#        'Population_Black_ACS', 'Population_Hisp_ACS', 'Population_Native_ACS',
#        'PCT_Black_ACS', 'PCT_Hisp_ACS', 'PCT_Native_ACS',
#        'UrbanCD_Description', 'Metro', 'State', 'Confirmed', 'Deaths',
#        'Country/Region', 'Deaths_Previous', 'Confirmed_Previous', 'Deaths_New',
#        'Deaths_New_7', 'Deaths_New_14', 'Deaths_New_21', 'Deaths_New_28',
#        'Confirmed_New', 'locationcol', 'Confirmed_New_RollingAvg',
#        'Deaths_New_RollingAvg', 'Deaths_New_7_RollingAvg',
#        'Deaths_New_14_RollingAvg', 'Deaths_New_21_RollingAvg',
#        'Deaths_New_28_RollingAvg', 'Confirmed_PER_100K', 'Deaths_PER_100K',
#        'Deaths_Previous_PER_100K', 'Deaths_New_PER_100K',
#        'Deaths_New_7_PER_100K', 'Deaths_New_14_PER_100K',
#        'Deaths_New_21_PER_100K', 'Deaths_New_28_PER_100K',
#        'Confirmed_New_PER_100K', 'Confirmed_New_RollingAvg_PER_100K',
#        'Deaths_New_RollingAvg_PER_100K', 'Deaths_New_7_RollingAvg_PER_100K',
#        'Deaths_New_14_RollingAvg_PER_100K',
#        'Deaths_New_21_RollingAvg_PER_100K',
#        'Deaths_New_28_RollingAvg_PER_100K', 'Region', 'Division', 'StateCD'],
#       dtype='object')

# %%
sns.set(rc={'figure.figsize':(5,4)})

# %%
yuma1 = yuma[['Date','Deaths_New']]
yuma1.columns = ['Date','Deaths']
yuma1['Type'] = 'Deaths_New'

yuma2 = yuma[['Date','Deaths_New_RollingAvg']]
yuma2.columns = ['Date','Deaths']
yuma2['Type'] = 'Deaths_New_RollingAvg'

yuma3 = pd.concat([yuma1,yuma2])
# Out:
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
yuma3
# Out:
#              Date  Deaths                   Type
# 35207  2020-01-22     nan             Deaths_New
# 35208  2020-01-23    0.00             Deaths_New
# 35209  2020-01-24    0.00             Deaths_New
# 35210  2020-01-25    0.00             Deaths_New
# 35211  2020-01-26    0.00             Deaths_New
# ...           ...     ...                    ...
# 35525  2020-12-05    3.00  Deaths_New_RollingAvg
# 35526  2020-12-06    2.43  Deaths_New_RollingAvg
# 35527  2020-12-07    2.43  Deaths_New_RollingAvg
# 35528  2020-12-08    2.57  Deaths_New_RollingAvg
# 35529  2020-12-09    2.71  Deaths_New_RollingAvg
#
# [646 rows x 3 columns]

# %%
plt.rcParams.update({'font.size': 14})
plt.style.use("dark_background")
sns.set_style({'axes.grid' : False})
g = sns.FacetGrid(yuma3, row="Type",  height=3.5, aspect=2.5)
g.map(sns.lineplot, "Date", "Deaths")

# %%
def regress_two_var(df, X, Y, startdate = "2020-01-01", enddate = "2020-10-01"):
    # Cleaning up the dataframe
    df = df[df.Date >= startdate]
    df = df[df.Date <= enddate]
    df = df[df['{Y}'.format(Y=Y)].isna() == False]
    df = df[df['{X}'.format(X=X)].isna() == False]
    #dataframe["ratio"] = dataframe['{Y}'.format(Y=Y)]/dataframe['{X}'.format(X=X)]
    Xvar =  df['{X}'.format(X=X)].values.reshape(-1, 1) 
    Xvar1 = sm.add_constant(Xvar) # need to do this for statsmodels for some reason
    Yvar = df['{Y}'.format(Y=Y)].values.reshape(-1, 1) 
    mod = sm.OLS(endog=Yvar,exog=Xvar1)
    res = mod.fit()
    print(res.summary())
    # Graph the regression
    linear_regressor = LinearRegression()  # create object for the class
    fitted_model = linear_regressor.fit(X=Xvar,y=Yvar)  # perform linear regression
    Y_pred = fitted_model.predict(Xvar)  # make predictions
    #return fitted_model
    plt.figure(figsize=(7,7))
    plt.scatter(y=Yvar, x=Xvar)
    plt.plot(Xvar, Y_pred, color='red')
    plt.title("{X} on {Y} Regression".format(X=X,Y=Y))
    plt.show()
    #Scatterplot to show data
    #sns.scatterplot(y='{Y}'.format(Y=Y),x='{X}'.format(X=X), hue="Division", data=df)

# %%
combined_oneday = combined[combined['Date']=='2020-10-01']

# %%
combined_oneday.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'County_FIPS', 'State Code', 'Name',
#        'retail_and_recreation_PCT_CFB', 'grocery_and_pharmacy_PCT_CFB',
#        'parks_PCT_CFB', 'transit_stations_PCT_CFB', 'workplaces_PCT_CFB',
#        'residential_PCT_CFB', 'retail_and_recreation_PCT_CFB_RollingAvg',
#        'grocery_and_pharmacy_PCT_CFB_RollingAvg', 'parks_PCT_CFB_RollingAvg',
#        'transit_stations_PCT_CFB_RollingAvg', 'workplaces_PCT_CFB_RollingAvg',
#        'residential_PCT_CFB_RollingAvg', 'HS_DIPLOMA_ONLY_2018',
#        'SOME_COLLEGE_2018', 'BACHELORS_PLUS_2018', 'Poverty_PCT_2018',
#        'UrbanCD', 'Median_Income_2018', 'Population_ACS',
#        'Population_Black_ACS', 'Population_Hisp_ACS', 'Population_Native_ACS',
#        'PCT_Black_ACS', 'PCT_Hisp_ACS', 'PCT_Native_ACS',
#        'UrbanCD_Description', 'Metro', 'State', 'Confirmed', 'Deaths',
#        'Country/Region', 'Deaths_Previous', 'Confirmed_Previous', 'Deaths_New',
#        'Deaths_New_7', 'Deaths_New_14', 'Deaths_New_21', 'Deaths_New_28',
#        'Confirmed_New', 'locationcol', 'Confirmed_New_RollingAvg',
#        'Deaths_New_RollingAvg', 'Deaths_New_7_RollingAvg',
#        'Deaths_New_14_RollingAvg', 'Deaths_New_21_RollingAvg',
#        'Deaths_New_28_RollingAvg', 'Confirmed_PER_100K', 'Deaths_PER_100K',
#        'Deaths_Previous_PER_100K', 'Deaths_New_PER_100K',
#        'Deaths_New_7_PER_100K', 'Deaths_New_14_PER_100K',
#        'Deaths_New_21_PER_100K', 'Deaths_New_28_PER_100K',
#        'Confirmed_New_PER_100K', 'Confirmed_New_RollingAvg_PER_100K',
#        'Deaths_New_RollingAvg_PER_100K', 'Deaths_New_7_RollingAvg_PER_100K',
#        'Deaths_New_14_RollingAvg_PER_100K',
#        'Deaths_New_21_RollingAvg_PER_100K',
#        'Deaths_New_28_RollingAvg_PER_100K', 'Region', 'Division', 'StateCD'],
#       dtype='object')

# %%
regress_two_var(df=combined_oneday,X="Poverty_PCT_2018",Y="Median_Income_2018")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.594
# Model:                            OLS   Adj. R-squared:                  0.594
# Method:                 Least Squares   F-statistic:                     4574.
# Date:                Mon, 14 Dec 2020   Prob (F-statistic):               0.00
# Time:                        10:25:36   Log-Likelihood:                -32886.
# No. Observations:                3131   AIC:                         6.578e+04
# Df Residuals:                    3129   BIC:                         6.579e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.914e+04    420.792    188.083      0.000    7.83e+04       8e+04
# x1         -1739.3686     25.718    -67.632      0.000   -1789.795   -1688.942
# ==============================================================================
# Omnibus:                     1509.945   Durbin-Watson:                   1.563
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10807.420
# Skew:                           2.180   Prob(JB):                         0.00
# Kurtosis:                      10.990   Cond. No.                         43.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
def multivariate_ols(input_df, Y, Xlist):
    # Reshape the df to avoid NAs
    dataframe = input_df
    dataframe = dataframe[dataframe['{Y}'.format(Y=Y)].isna() == False]
    # Clean out any rows where one of these is NA -- can lead to data loss
    for i in Xlist:
        dataframe = dataframe[dataframe[i].isna() == False]
    # Check to ensure not too much thrown away
    pct_preserved = dataframe.shape[0]/input_df.shape[0]
    print("{pct} percent of the data preserved as non-NA".format(pct = 100*round(pct_preserved,2)))
    Xvar =  dataframe[Xlist]#.values.reshape(-1, len(Xlist)) 
    Xvar = sm.add_constant(Xvar)
    Yvar = dataframe['{Y}'.format(Y=Y)].values.reshape(-1, 1) 
    mod = sm.OLS(endog=Yvar,exog=Xvar,)
    res = mod.fit()
    print(res.summary())
    return res

# %%
Xlist = ['BACHELORS_PLUS_2018',"Poverty_PCT_2018", "Metro" ]

multivariate_ols(input_df=combined, Y="residential_PCT_CFB_RollingAvg", Xlist=Xlist)
# Out:
# 23.0 percent of the data preserved as non-NA
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-221-19146d44a06c> in <module>
#       1 Xlist = ['BACHELORS_PLUS_2018',"Poverty_PCT_2018", "Metro" ]
#       2
# ----> 3 multivariate_ols(input_df=combined, Y="residential_PCT_CFB_RollingAvg", Xlist=Xlist)
#
# <ipython-input-46-42598f47b0d1> in multivariate_ols(input_df, Y, Xlist)
#      12     Xvar = sm.add_constant(Xvar)
#      13     Yvar = dataframe['{Y}'.format(Y=Y)].values.reshape(-1, 1)
# ---> 14     mod = sm.OLS(endog=Yvar,exog=Xvar,)
#      15     res = mod.fit()
#      16     print(res.summary())
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     871                  **kwargs):
#     872         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#     875             self._init_keys.remove("weights")
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     702             weights = weights.squeeze()
#     703         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 704                                   weights=weights, hasconst=hasconst, **kwargs)
#     705         nobs = self.exog.shape[0]
#     706         weights = self.weights
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, **kwargs)
#     188     """
#     189     def __init__(self, endog, exog, **kwargs):
# --> 190         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     191         self._data_attr.extend(['pinv_wexog', 'weights'])
#     192
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     235
#     236     def __init__(self, endog, exog=None, **kwargs):
# --> 237         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     238         self.initialize()
#     239
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      76         hasconst = kwargs.pop('hasconst', None)
#      77         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 78                                       **kwargs)
#      79         self.k_constant = self.data.k_constant
#      80         self.exog = self.data.exog
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      99
#     100     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 101         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     102         # kwargs arrays could have changed, easier to just attach here
#     103         for key in kwargs:
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     671     klass = handle_data_class_factory(endog, exog)
#     672     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 673                  **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      81             self.orig_endog = endog
#      82             self.orig_exog = exog
# ---> 83             self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      84
#      85         self.const_idx = None
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/data.py in _convert_endog_exog(self, endog, exog)
#     506         exog = exog if exog is None else np.asarray(exog)
#     507         if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 508             raise ValueError("Pandas data cast to numpy dtype of object. "
#     509                              "Check input data with np.asarray(data).")
#     510         return super(PandasData, self)._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).

# %%
combined.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'County_FIPS', 'State Code', 'Name',
#        'retail_and_recreation_PCT_CFB', 'grocery_and_pharmacy_PCT_CFB',
#        'parks_PCT_CFB', 'transit_stations_PCT_CFB', 'workplaces_PCT_CFB',
#        'residential_PCT_CFB', 'retail_and_recreation_PCT_CFB_RollingAvg',
#        'grocery_and_pharmacy_PCT_CFB_RollingAvg', 'parks_PCT_CFB_RollingAvg',
#        'transit_stations_PCT_CFB_RollingAvg', 'workplaces_PCT_CFB_RollingAvg',
#        'residential_PCT_CFB_RollingAvg', 'HS_DIPLOMA_ONLY_2018',
#        'SOME_COLLEGE_2018', 'BACHELORS_PLUS_2018', 'Poverty_PCT_2018',
#        'UrbanCD', 'Median_Income_2018', 'Population_ACS',
#        'Population_Black_ACS', 'Population_Hisp_ACS', 'Population_Native_ACS',
#        'PCT_Black_ACS', 'PCT_Hisp_ACS', 'PCT_Native_ACS',
#        'UrbanCD_Description', 'Metro', 'State', 'Confirmed', 'Deaths',
#        'Country/Region', 'Deaths_Previous', 'Confirmed_Previous', 'Deaths_New',
#        'Deaths_New_7', 'Deaths_New_14', 'Deaths_New_21', 'Deaths_New_28',
#        'Confirmed_New', 'locationcol', 'Confirmed_New_RollingAvg',
#        'Deaths_New_RollingAvg', 'Deaths_New_7_RollingAvg',
#        'Deaths_New_14_RollingAvg', 'Deaths_New_21_RollingAvg',
#        'Deaths_New_28_RollingAvg', 'Confirmed_PER_100K', 'Deaths_PER_100K',
#        'Deaths_Previous_PER_100K', 'Deaths_New_PER_100K',
#        'Deaths_New_7_PER_100K', 'Deaths_New_14_PER_100K',
#        'Deaths_New_21_PER_100K', 'Deaths_New_28_PER_100K',
#        'Confirmed_New_PER_100K', 'Confirmed_New_RollingAvg_PER_100K',
#        'Deaths_New_RollingAvg_PER_100K', 'Deaths_New_7_RollingAvg_PER_100K',
#        'Deaths_New_14_RollingAvg_PER_100K',
#        'Deaths_New_21_RollingAvg_PER_100K',
#        'Deaths_New_28_RollingAvg_PER_100K', 'Region', 'Division', 'StateCD'],
#       dtype='object')

# %%
combined['StateCD'] = combined['State Code']

# %% [markdown]
# ## Define list of all candidate predictors and then the possible outcomes

# %%
full_predictors = [
 'C(Metro)',
 #'HS_DIPLOMA_ONLY_2018',
 'PCT_Black_ACS',
 'BACHELORS_PLUS_2018',
 'Confirmed_New_RollingAvg_PER_100K',
 #'workplaces_PCT_CFB',
 'residential_PCT_CFB_RollingAvg',
 'Poverty_PCT_2018',
 'Median_Income_2018',
 #'C(Region)',
 'C(StateCD)',
    
]

Ylist = [#'Deaths_New_7_RollingAvg_PER_100K',
         #'Deaths_New_14_RollingAvg_PER_100K',
         #'Deaths_New_28_RollingAvg_PER_100K',
         #'Deaths_PER_100K'
         'Deaths_New_RollingAvg_PER_100K'
            ]

# %% [markdown]
# ## Create list of formulas for all combinations

# %%
# https://stackoverflow.com/questions/1482308/how-to-get-all-subsets-of-a-set-powerset
from itertools import chain, combinations

def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return set(chain.from_iterable(combinations(s, r) for r in range(len(s)+1)))

ps = powerset(full_predictors)
ps_list = [list(i) for i in ps]

# %%
textlist = []

for i in ps_list:
    text = '|'
    for x in i:
        text = text+' + '+x
    textlist.append(text)


textlist = [i.replace('| +','') for i in textlist if len(i) > 3]
    
full_form_list = []
for i in textlist:
    for y in Ylist:
        full_form_list.append(y+" ~ "+i)


full_form_list
samp_list = full_form_list[0:50]

# %%
len(full_form_list) # Number of the possible equations
# Out:
# 255

# %%
combined['Date_2'] = combined['Date'].astype('datetime64[ns]')
combined['Month'] = combined['Date_2'].dt.month

# %%
combined_oneday = combined[combined['Date'] == '2020-12-01']

# %% [markdown]
# ## Define a Function for Formula-Based OLS

# %%
def start_end_mulivariate_ols(formulatxt, startdate="2020-06-01", enddate="2020-12-09", df=combined):
    segmented = df[df.Date > startdate]
    segmented = segmented[segmented.Date < enddate]
    mod = smf.ols(formula=formulatxt , data=segmented, missing='drop')
    res = mod.fit()
    #print(res.summary())
    return res

# %%
mod1 = start_end_mulivariate_ols(startdate = "2020-06-01", enddate = "2020-12-01", formulatxt="""
Deaths_PER_100K ~ residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + C(StateCD) + PCT_Black_ACS + C(Metro)""")
print(mod1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Deaths_PER_100K   R-squared:                       0.417
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     2028.
# Date:                Tue, 15 Dec 2020   Prob (F-statistic):               0.00
# Time:                        22:26:58   Log-Likelihood:            -8.0348e+05
# No. Observations:              161394   AIC:                         1.607e+06
# Df Residuals:                  161336   BIC:                         1.608e+06
# Df Model:                          57
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -9.9360      1.563     -6.356      0.000     -13.000      -6.872
# C(StateCD)[T.AL]                   4.1163      1.622      2.538      0.011       0.938       7.295
# C(StateCD)[T.AR]                   8.7973      1.707      5.153      0.000       5.451      12.143
# C(StateCD)[T.AZ]                  53.4172      1.742     30.671      0.000      50.004      56.831
# C(StateCD)[T.CA]                  -6.2591      1.585     -3.948      0.000      -9.367      -3.152
# C(StateCD)[T.CO]                  14.0558      1.679      8.370      0.000      10.764      17.347
# C(StateCD)[T.CT]                  74.0561      1.778     41.640      0.000      70.570      77.542
# C(StateCD)[T.DC]                  20.9758      3.057      6.861      0.000      14.984      26.968
# C(StateCD)[T.DE]                  40.5685      2.143     18.928      0.000      36.368      44.769
# C(StateCD)[T.FL]                  19.1872      1.575     12.180      0.000      16.100      22.275
# C(StateCD)[T.GA]                  13.4942      1.596      8.456      0.000      10.366      16.622
# C(StateCD)[T.HI]                 -10.8072      2.095     -5.159      0.000     -14.913      -6.702
# C(StateCD)[T.IA]                  24.2286      1.710     14.166      0.000      20.876      27.581
# C(StateCD)[T.ID]                  13.3827      1.802      7.426      0.000       9.851      16.915
# C(StateCD)[T.IL]                  14.9007      1.610      9.258      0.000      11.746      18.055
# C(StateCD)[T.IN]                  25.0011      1.602     15.602      0.000      21.860      28.142
# C(StateCD)[T.KS]                  -1.9402      1.752     -1.108      0.268      -5.374       1.493
# C(StateCD)[T.KY]                  -4.4491      1.671     -2.662      0.008      -7.725      -1.173
# C(StateCD)[T.LA]                  53.0313      1.662     31.917      0.000      49.775      56.288
# C(StateCD)[T.MA]                  96.2428      1.710     56.290      0.000      92.892      99.594
# C(StateCD)[T.MD]                  21.5251      1.681     12.804      0.000      18.230      24.820
# C(StateCD)[T.ME]                  -6.0107      1.834     -3.278      0.001      -9.604      -2.417
# C(StateCD)[T.MI]                  17.0523      1.591     10.721      0.000      13.935      20.170
# C(StateCD)[T.MN]                   7.5335      1.663      4.530      0.000       4.274      10.793
# C(StateCD)[T.MO]                  -1.2031      1.633     -0.737      0.461      -4.403       1.997
# C(StateCD)[T.MS]                  25.3344      1.787     14.180      0.000      21.833      28.836
# C(StateCD)[T.MT]                   1.6201      1.879      0.862      0.389      -2.063       5.303
# C(StateCD)[T.NC]                   2.3581      1.576      1.497      0.134      -0.730       5.446
# C(StateCD)[T.ND]                  32.0598      2.035     15.758      0.000      28.072      36.047
# C(StateCD)[T.NE]                  13.9381      1.947      7.159      0.000      10.122      17.754
# C(StateCD)[T.NH]                   9.4289      1.842      5.119      0.000       5.819      13.039
# C(StateCD)[T.NJ]                 128.8976      1.637     78.746      0.000     125.689     132.106
# C(StateCD)[T.NM]                  12.4132      1.758      7.061      0.000       8.968      15.859
# C(StateCD)[T.NV]                  11.3555      1.991      5.703      0.000       7.453      15.258
# C(StateCD)[T.NY]                  47.8182      1.583     30.209      0.000      44.716      50.921
# C(StateCD)[T.OH]                  12.2719      1.575      7.793      0.000       9.185      15.358
# C(StateCD)[T.OK]                  -1.2111      1.664     -0.728      0.467      -4.472       2.050
# C(StateCD)[T.OR]                 -12.5551      1.648     -7.619      0.000     -15.785      -9.325
# C(StateCD)[T.PA]                  23.4033      1.576     14.845      0.000      20.313      26.493
# C(StateCD)[T.RI]                  47.1534      2.073     22.743      0.000      43.090      51.217
# C(StateCD)[T.SC]                  19.2311      1.633     11.775      0.000      16.030      22.432
# C(StateCD)[T.SD]                  23.7568      2.303     10.317      0.000      19.243      28.270
# C(StateCD)[T.TN]                   4.1357      1.605      2.577      0.010       0.991       7.281
# C(StateCD)[T.TX]                  14.7147      1.566      9.397      0.000      11.646      17.784
# C(StateCD)[T.UT]                  -4.2375      1.781     -2.380      0.017      -7.727      -0.748
# C(StateCD)[T.VA]                  -3.4066      1.611     -2.115      0.034      -6.564      -0.249
# C(StateCD)[T.VT]                   1.8864      2.550      0.740      0.460      -3.112       6.885
# C(StateCD)[T.WA]                   5.7003      1.629      3.500      0.000       2.508       8.892
# C(StateCD)[T.WI]                   9.1557      1.601      5.717      0.000       6.017      12.294
# C(StateCD)[T.WV]                 -12.6108      1.810     -6.967      0.000     -16.159      -9.063
# C(StateCD)[T.WY]                   0.6489      2.131      0.305      0.761      -3.527       4.825
# C(Metro)[T.Micropolitan]         -11.9781      0.332    -36.089      0.000     -12.629     -11.328
# C(Metro)[T.Noncore_adjacent]       2.2195      0.707      3.138      0.002       0.833       3.606
# C(Metro)[T.Noncore_remote]       -19.6774      3.020     -6.515      0.000     -25.597     -13.757
# C(Metro)[T.Smaller_metro]        -16.9371      0.247    -68.512      0.000     -17.422     -16.453
# residential_PCT_CFB_RollingAvg     1.0972      0.034     32.584      0.000       1.031       1.163
# Poverty_PCT_2018                   2.7227      0.026    104.062      0.000       2.671       2.774
# PCT_Black_ACS                      0.3603      0.011     32.654      0.000       0.339       0.382
# ==============================================================================
# Omnibus:                    56901.242   Durbin-Watson:                   0.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           368009.032
# Skew:                           1.550   Prob(JB):                         0.00
# Kurtosis:                       9.716   Cond. No.                     2.58e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.58e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
mod1 = start_end_mulivariate_ols(startdate = "2020-06-01", enddate = "2020-12-01", formulatxt="""
Deaths_PER_100K ~ Poverty_PCT_2018 + C(StateCD) + PCT_Black_ACS + C(UrbanCD) + C(Month)""")
print(mod1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Deaths_PER_100K   R-squared:                       0.390
# Model:                            OLS   Adj. R-squared:                  0.390
# Method:                 Least Squares   F-statistic:                     5358.
# Date:                Tue, 15 Dec 2020   Prob (F-statistic):               0.00
# Time:                        22:05:40   Log-Likelihood:            -2.9155e+06
# No. Observations:              569842   AIC:                         5.831e+06
# Df Residuals:                  569773   BIC:                         5.832e+06
# Df Model:                          68
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept          -22.5553      0.623    -36.220      0.000     -23.776     -21.335
# C(StateCD)[T.AL]    19.1095      0.703     27.187      0.000      17.732      20.487
# C(StateCD)[T.AR]    12.2684      0.684     17.948      0.000      10.929      13.608
# C(StateCD)[T.AZ]    64.5353      0.974     66.238      0.000      62.626      66.445
# C(StateCD)[T.CA]     7.5012      0.704     10.650      0.000       6.121       8.882
# C(StateCD)[T.CO]    14.3546      0.683     21.007      0.000      13.015      15.694
# C(StateCD)[T.CT]    81.0344      1.211     66.924      0.000      78.661      83.408
# C(StateCD)[T.DC]    33.0269      3.061     10.791      0.000      27.028      39.026
# C(StateCD)[T.DE]    44.4906      1.827     24.349      0.000      40.909      48.072
# C(StateCD)[T.FL]    26.0454      0.695     37.488      0.000      24.684      27.407
# C(StateCD)[T.GA]    38.0589      0.646     58.902      0.000      36.793      39.325
# C(StateCD)[T.HI]     1.4200      1.607      0.884      0.377      -1.730       4.570
# C(StateCD)[T.IA]    28.7736      0.654     43.996      0.000      27.492      30.055
# C(StateCD)[T.ID]    11.8398      0.735     16.112      0.000      10.399      13.280
# C(StateCD)[T.IL]    17.7544      0.654     27.130      0.000      16.472      19.037
# C(StateCD)[T.IN]    30.6565      0.664     46.153      0.000      29.355      31.958
# C(StateCD)[T.KS]    15.2504      0.643     23.704      0.000      13.989      16.511
# C(StateCD)[T.KY]     4.3361      0.646      6.717      0.000       3.071       5.601
# C(StateCD)[T.LA]    55.9065      0.715     78.162      0.000      54.505      57.308
# C(StateCD)[T.MA]    90.8937      0.990     91.782      0.000      88.953      92.835
# C(StateCD)[T.MD]    21.5835      0.864     24.981      0.000      19.890      23.277
# C(StateCD)[T.ME]     0.3754      0.946      0.397      0.691      -1.478       2.229
# C(StateCD)[T.MI]    16.3168      0.664     24.571      0.000      15.015      17.618
# C(StateCD)[T.MN]    13.6646      0.663     20.611      0.000      12.365      14.964
# C(StateCD)[T.MO]     5.4739      0.646      8.469      0.000       4.207       6.741
# C(StateCD)[T.MS]    45.8934      0.705     65.078      0.000      44.511      47.276
# C(StateCD)[T.MT]    17.0569      0.696     24.514      0.000      15.693      18.421
# C(StateCD)[T.NC]     5.2028      0.663      7.846      0.000       3.903       6.502
# C(StateCD)[T.ND]    32.2236      0.707     45.596      0.000      30.838      33.609
# C(StateCD)[T.NE]    16.8952      0.651     25.937      0.000      15.618      18.172
# C(StateCD)[T.NH]    10.7213      1.114      9.623      0.000       8.538      12.905
# C(StateCD)[T.NJ]   135.5681      0.885    153.181      0.000     133.834     137.303
# C(StateCD)[T.NM]    14.8335      0.785     18.897      0.000      13.295      16.372
# C(StateCD)[T.NV]     6.8396      0.928      7.371      0.000       5.021       8.658
# C(StateCD)[T.NY]    42.6855      0.699     61.031      0.000      41.315      44.056
# C(StateCD)[T.OH]    17.8670      0.669     26.702      0.000      16.556      19.178
# C(StateCD)[T.OK]     7.1222      0.677     10.517      0.000       5.795       8.449
# C(StateCD)[T.OR]     2.8850      0.764      3.775      0.000       1.387       4.383
# C(StateCD)[T.PA]    22.3649      0.690     32.403      0.000      21.012      23.718
# C(StateCD)[T.RI]    47.7287      1.468     32.513      0.000      44.852      50.606
# C(StateCD)[T.SC]    20.7447      0.757     27.403      0.000      19.261      22.228
# C(StateCD)[T.SD]    22.2121      0.685     32.407      0.000      20.869      23.556
# C(StateCD)[T.TN]    13.6876      0.663     20.654      0.000      12.389      14.986
# C(StateCD)[T.TX]    30.0065      0.611     49.141      0.000      28.810      31.203
# C(StateCD)[T.UT]     4.6493      0.800      5.814      0.000       3.082       6.217
# C(StateCD)[T.VA]    10.2624      0.649     15.823      0.000       8.991      11.534
# C(StateCD)[T.VT]     0.5155      0.989      0.521      0.602      -1.422       2.453
# C(StateCD)[T.WA]     9.7504      0.755     12.915      0.000       8.271      11.230
# C(StateCD)[T.WI]    13.0199      0.680     19.144      0.000      11.687      14.353
# C(StateCD)[T.WV]    -0.4028      0.712     -0.565      0.572      -1.799       0.994
# C(StateCD)[T.WY]     5.3432      0.850      6.286      0.000       3.677       7.009
# C(UrbanCD)[T.2]     -8.8637      0.195    -45.422      0.000      -9.246      -8.481
# C(UrbanCD)[T.3]     -7.9080      0.314    -25.218      0.000      -8.523      -7.293
# C(UrbanCD)[T.4]     -6.7728      0.294    -23.050      0.000      -7.349      -6.197
# C(UrbanCD)[T.5]     -9.0005      0.260    -34.566      0.000      -9.511      -8.490
# C(UrbanCD)[T.6]     -4.6374      0.244    -19.032      0.000      -5.115      -4.160
# C(UrbanCD)[T.7]    -12.3614      0.300    -41.164      0.000     -12.950     -11.773
# C(UrbanCD)[T.8]     -7.0975      0.257    -27.580      0.000      -7.602      -6.593
# C(UrbanCD)[T.9]     -4.5205      0.290    -15.588      0.000      -5.089      -3.952
# C(UrbanCD)[T.10]   -15.2596      0.295    -51.804      0.000     -15.837     -14.682
# C(UrbanCD)[T.11]   -12.1596      0.334    -36.376      0.000     -12.815     -11.504
# C(UrbanCD)[T.12]   -14.4852      0.310    -46.754      0.000     -15.092     -13.878
# C(Month)[T.7]        4.6626      0.186     25.030      0.000       4.297       5.028
# C(Month)[T.8]       13.5336      0.186     72.651      0.000      13.168      13.899
# C(Month)[T.9]       23.3186      0.188    124.182      0.000      22.951      23.687
# C(Month)[T.10]      34.3887      0.186    184.604      0.000      34.024      34.754
# C(Month)[T.11]      52.4813      0.188    279.486      0.000      52.113      52.849
# Poverty_PCT_2018     1.1483      0.013     90.333      0.000       1.123       1.173
# PCT_Black_ACS        0.8159      0.006    132.621      0.000       0.804       0.828
# ==============================================================================
# Omnibus:                   394929.122   Durbin-Watson:                   0.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         10779303.136
# Skew:                           2.988   Prob(JB):                         0.00
# Kurtosis:                      23.452   Cond. No.                     1.70e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.7e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Test Formula for OLS

# %%
mod1 = start_end_mulivariate_ols(startdate = "2020-10-01", enddate = "2020-10-07", formulatxt="""
Deaths_New_RollingAvg_PER_100K ~ HS_DIPLOMA_ONLY_2018 + residential_PCT_CFB_RollingAvg +
Poverty_PCT_2018 + Median_Income_2018 + C(Region)""")

# %%
# Construct monthly daterange tuples

every_month = []
for i in range(4,9):
    a = '2020-0{c}-01'.format(c=i)
    b = '2020-0{c}-01'.format(c=i+1)
    every_month.append((a,b))
every_month.append(('2020-09-01','2020-10-01'))
every_month.append(('2020-10-01','2020-11-01'))
for i in range(10,12):
    a = '2020-{c}-01'.format(c=i)
    b = '2020-{c}-01'.format(c=i+1)
every_month.append((a,b))
every_month
# Out:
# [('2020-04-01', '2020-05-01'),
#  ('2020-05-01', '2020-06-01'),
#  ('2020-06-01', '2020-07-01'),
#  ('2020-07-01', '2020-08-01'),
#  ('2020-08-01', '2020-09-01'),
#  ('2020-09-01', '2020-10-01'),
#  ('2020-10-01', '2020-11-01'),
#  ('2020-11-01', '2020-12-01')]

# %%
every_3month =[
 ('2020-04-01', '2020-07-01'),
 ('2020-05-01', '2020-08-01'),
 ('2020-06-01', '2020-09-01'),
 ('2020-07-01', '2020-10-01'),
 ('2020-08-01', '2020-11-01'),
 ('2020-09-01', '2020-12-01')
]

# %%
dir(mod1)
# Out:
# ['HC0_se',
#  'HC1_se',
#  'HC2_se',
#  'HC3_se',
#  '_HCCM',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abat_diagonal',
#  '_cache',
#  '_data_attr',
#  '_data_in_cache',
#  '_get_robustcov_results',
#  '_is_nested',
#  '_use_t',
#  '_wexog_singular_values',
#  'aic',
#  'bic',
#  'bse',
#  'centered_tss',
#  'compare_f_test',
#  'compare_lm_test',
#  'compare_lr_test',
#  'condition_number',
#  'conf_int',
#  'conf_int_el',
#  'cov_HC0',
#  'cov_HC1',
#  'cov_HC2',
#  'cov_HC3',
#  'cov_kwds',
#  'cov_params',
#  'cov_type',
#  'df_model',
#  'df_resid',
#  'eigenvals',
#  'el_test',
#  'ess',
#  'f_pvalue',
#  'f_test',
#  'fittedvalues',
#  'fvalue',
#  'get_influence',
#  'get_prediction',
#  'get_robustcov_results',
#  'initialize',
#  'k_constant',
#  'llf',
#  'load',
#  'model',
#  'mse_model',
#  'mse_resid',
#  'mse_total',
#  'nobs',
#  'normalized_cov_params',
#  'outlier_test',
#  'params',
#  'predict',
#  'pvalues',
#  'remove_data',
#  'resid',
#  'resid_pearson',
#  'rsquared',
#  'rsquared_adj',
#  'save',
#  'scale',
#  'ssr',
#  'summary',
#  'summary2',
#  't_test',
#  't_test_pairwise',
#  'tvalues',
#  'uncentered_tss',
#  'use_t',
#  'wald_test',
#  'wald_test_terms',
#  'wresid']

# %% [markdown]
# ## Function for running model and then graphing it over the different dateranges

# %%
def run_timeseries_models(formulatxt, list_dateranges, df):
    list_results = []
    for i in list_dateranges:
        res = start_end_mulivariate_ols(formulatxt = formulatxt, startdate = i[0], enddate = i[1], df=df)
        name = i[0]+"-"+i[1]
        list_results.append({"model":res,"start":i[0], "end":i[1]})
    
    resultslist = [{"bic":i['model'].bic, 
                    "aic":i['model'].aic, 
                    "start":i['start'], 
                    "end":i['end'], 
                    "r2_adj":i["model"].rsquared_adj,
                    "formula":formulatxt,
                    "n_obs":i['model'].nobs
                     } for i in list_results]
    return pd.DataFrame.from_dict(resultslist)

# %%
formulatxt = "Deaths_New_21_RollingAvg_PER_100K ~  residential_PCT_CFB_RollingAvg + C(StateCD)"

df = run_timeseries_models(formulatxt=formulatxt, list_dateranges=every_month, df=combined)

# %%
df
# Out:
#        bic      aic       start         end  r2_adj  \
# 0 27672.44 27267.95  2020-04-01  2020-05-01    0.50
# 1 11521.31 11109.64  2020-05-01  2020-06-01    0.27
# 2  9608.55  9194.51  2020-06-01  2020-07-01    0.23
# 3 15090.70 14675.40  2020-07-01  2020-08-01    0.35
# 4 13754.51 13331.99  2020-08-01  2020-09-01    0.22
# 5 14643.36 14219.12  2020-09-01  2020-10-01    0.15
# 6 41450.55 41014.98  2020-10-01  2020-11-01    0.16
# 7 34925.92 34520.35  2020-11-01  2020-12-01    0.23
#
#                                              formula    n_obs
# 0  Deaths_New_21_RollingAvg_PER_100K ~  residenti... 17654.00
# 1  Deaths_New_21_RollingAvg_PER_100K ~  residenti... 20268.00
# 2  Deaths_New_21_RollingAvg_PER_100K ~  residenti... 21212.00
# 3  Deaths_New_21_RollingAvg_PER_100K ~  residenti... 21732.00
# 4  Deaths_New_21_RollingAvg_PER_100K ~  residenti... 24967.00
# 5  Deaths_New_21_RollingAvg_PER_100K ~  residenti... 25808.00
# 6  Deaths_New_21_RollingAvg_PER_100K ~  residenti... 32091.00
# 7  Deaths_New_21_RollingAvg_PER_100K ~  residenti... 18021.00

# %% [markdown]
# ## Run model and return dataframe showing the BIC, AIC, and R Squared

# %%
def graph_bic_adj2_TS(formulatxt, list_dateranges, df):
    df_graph = run_timeseries_models(formulatxt=formulatxt, list_dateranges=list_dateranges, df=df)
    plt.figure(figsize=(12,6))
    ax = sns.lineplot(x="start", y="bic", label="BIC", data=df_graph)
    plt.legend(loc="upper left")
    ax2 = ax.twinx()
    ax2 = sns.lineplot(x="start", y="r2_adj", label="R2_ADJ", color='red', data=df_graph)
    plt.title("BIC vs R2_ADJ")
    plt.legend(loc="upper right")
    print(formulatxt)
    print()

# %%
combined.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'County_FIPS', 'State Code', 'Name',
#        'retail_and_recreation_PCT_CFB', 'grocery_and_pharmacy_PCT_CFB',
#        'parks_PCT_CFB', 'transit_stations_PCT_CFB', 'workplaces_PCT_CFB',
#        'residential_PCT_CFB', 'retail_and_recreation_PCT_CFB_RollingAvg',
#        'grocery_and_pharmacy_PCT_CFB_RollingAvg', 'parks_PCT_CFB_RollingAvg',
#        'transit_stations_PCT_CFB_RollingAvg', 'workplaces_PCT_CFB_RollingAvg',
#        'residential_PCT_CFB_RollingAvg', 'HS_DIPLOMA_ONLY_2018',
#        'SOME_COLLEGE_2018', 'BACHELORS_PLUS_2018', 'Poverty_PCT_2018',
#        'UrbanCD', 'Median_Income_2018', 'Population_ACS',
#        'Population_Black_ACS', 'Population_Hisp_ACS', 'Population_Native_ACS',
#        'PCT_Black_ACS', 'PCT_Hisp_ACS', 'PCT_Native_ACS',
#        'UrbanCD_Description', 'Metro', 'State', 'Confirmed', 'Deaths',
#        'Country/Region', 'Deaths_Previous', 'Confirmed_Previous', 'Deaths_New',
#        'Deaths_New_7', 'Deaths_New_14', 'Deaths_New_21', 'Deaths_New_28',
#        'Confirmed_New', 'locationcol', 'Confirmed_New_RollingAvg',
#        'Deaths_New_RollingAvg', 'Deaths_New_7_RollingAvg',
#        'Deaths_New_14_RollingAvg', 'Deaths_New_21_RollingAvg',
#        'Deaths_New_28_RollingAvg', 'Confirmed_PER_100K', 'Deaths_PER_100K',
#        'Deaths_Previous_PER_100K', 'Deaths_New_PER_100K',
#        'Deaths_New_7_PER_100K', 'Deaths_New_14_PER_100K',
#        'Deaths_New_21_PER_100K', 'Deaths_New_28_PER_100K',
#        'Confirmed_New_PER_100K', 'Confirmed_New_RollingAvg_PER_100K',
#        'Deaths_New_RollingAvg_PER_100K', 'Deaths_New_7_RollingAvg_PER_100K',
#        'Deaths_New_14_RollingAvg_PER_100K',
#        'Deaths_New_21_RollingAvg_PER_100K',
#        'Deaths_New_28_RollingAvg_PER_100K', 'Region', 'Division', 'StateCD',
#        'Date_2', 'Month'],
#       dtype='object')

# %%
plt.rcParams.update({"grid.linewidth":0.5, "grid.alpha":0.5})
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")

# %%
formula1 = """residential_PCT_CFB_RollingAvg ~ Poverty_PCT_2018 + C(StateCD) + C(Metro) + Deaths_PER_100K"""

graph_bic_adj2_TS(formulatxt=formula1, list_dateranges=every_month, df=combined)
# Out:
# residential_PCT_CFB_RollingAvg ~ Poverty_PCT_2018 + C(StateCD) + C(Metro) + Deaths_PER_100K

# %%
mod1 = start_end_mulivariate_ols(startdate = "2020-06-01", enddate = "2020-12-01", formulatxt=formula1)
print(mod1.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     residential_PCT_CFB_RollingAvg   R-squared:                       0.394
# Model:                                        OLS   Adj. R-squared:                  0.394
# Method:                             Least Squares   F-statistic:                     1872.
# Date:                            Mon, 14 Dec 2020   Prob (F-statistic):               0.00
# Time:                                    17:05:19   Log-Likelihood:            -3.8459e+05
# No. Observations:                          161394   AIC:                         7.693e+05
# Df Residuals:                              161337   BIC:                         7.699e+05
# Df Model:                                      56
# Covariance Type:                        nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        8.2166      0.115     71.594      0.000       7.992       8.442
# C(StateCD)[T.AL]                -0.2404      0.121     -1.990      0.047      -0.477      -0.004
# C(StateCD)[T.AR]                 0.1006      0.127      0.790      0.430      -0.149       0.350
# C(StateCD)[T.AZ]                 1.8753      0.130     14.452      0.000       1.621       2.130
# C(StateCD)[T.CA]                 3.5213      0.118     29.899      0.000       3.290       3.752
# C(StateCD)[T.CO]                 2.1102      0.125     16.858      0.000       1.865       2.355
# C(StateCD)[T.CT]                 1.1998      0.133      8.995      0.000       0.938       1.461
# C(StateCD)[T.DC]                 8.0837      0.226     35.724      0.000       7.640       8.527
# C(StateCD)[T.DE]                 0.6821      0.160      4.267      0.000       0.369       0.995
# C(StateCD)[T.FL]                 0.9406      0.118      8.001      0.000       0.710       1.171
# C(StateCD)[T.GA]                 0.6705      0.118      5.664      0.000       0.438       0.903
# C(StateCD)[T.HI]                 6.7715      0.155     43.594      0.000       6.467       7.076
# C(StateCD)[T.IA]                 0.9884      0.128      7.743      0.000       0.738       1.239
# C(StateCD)[T.ID]                -1.4146      0.134    -10.526      0.000      -1.678      -1.151
# C(StateCD)[T.IL]                 0.7948      0.120      6.618      0.000       0.559       1.030
# C(StateCD)[T.IN]                -0.9428      0.120     -7.883      0.000      -1.177      -0.708
# C(StateCD)[T.KS]                 0.6356      0.131      4.863      0.000       0.379       0.892
# C(StateCD)[T.KY]                 0.5677      0.125      4.553      0.000       0.323       0.812
# C(StateCD)[T.LA]                -0.1739      0.124     -1.404      0.160      -0.417       0.069
# C(StateCD)[T.MA]                 2.2961      0.129     17.850      0.000       2.044       2.548
# C(StateCD)[T.MD]                 2.8842      0.125     23.099      0.000       2.639       3.129
# C(StateCD)[T.ME]                 0.5844      0.137      4.273      0.000       0.316       0.852
# C(StateCD)[T.MI]                 0.3629      0.119      3.057      0.002       0.130       0.596
# C(StateCD)[T.MN]                 1.8458      0.124     14.888      0.000       1.603       2.089
# C(StateCD)[T.MO]                -1.0260      0.122     -8.424      0.000      -1.265      -0.787
# C(StateCD)[T.MS]                -0.1594      0.132     -1.204      0.229      -0.419       0.100
# C(StateCD)[T.MT]                -0.6430      0.140     -4.588      0.000      -0.918      -0.368
# C(StateCD)[T.NC]                 0.5662      0.117      4.825      0.000       0.336       0.796
# C(StateCD)[T.ND]                 0.5023      0.152      3.307      0.001       0.205       0.800
# C(StateCD)[T.NE]                 1.3786      0.145      9.491      0.000       1.094       1.663
# C(StateCD)[T.NH]                 1.5519      0.137     11.297      0.000       1.283       1.821
# C(StateCD)[T.NJ]                 1.7134      0.124     13.775      0.000       1.470       1.957
# C(StateCD)[T.NM]                 4.5358      0.130     34.825      0.000       4.281       4.791
# C(StateCD)[T.NV]                 1.3334      0.149      8.978      0.000       1.042       1.624
# C(StateCD)[T.NY]                 1.1487      0.118      9.704      0.000       0.917       1.381
# C(StateCD)[T.OH]                -0.4727      0.118     -4.023      0.000      -0.703      -0.242
# C(StateCD)[T.OK]                -0.0906      0.124     -0.730      0.465      -0.334       0.153
# C(StateCD)[T.OR]                 0.8913      0.123      7.259      0.000       0.651       1.132
# C(StateCD)[T.PA]                 0.3435      0.118      2.919      0.004       0.113       0.574
# C(StateCD)[T.RI]                -0.2011      0.155     -1.299      0.194      -0.504       0.102
# C(StateCD)[T.SC]                 0.5038      0.121      4.153      0.000       0.266       0.742
# C(StateCD)[T.SD]                -0.5432      0.172     -3.161      0.002      -0.880      -0.206
# C(StateCD)[T.TN]                -0.6086      0.120     -5.083      0.000      -0.843      -0.374
# C(StateCD)[T.TX]                 1.6398      0.117     14.045      0.000       1.411       1.869
# C(StateCD)[T.UT]                 0.6880      0.133      5.180      0.000       0.428       0.948
# C(StateCD)[T.VA]                 1.9139      0.120     15.984      0.000       1.679       2.149
# C(StateCD)[T.VT]                 4.1840      0.190     22.023      0.000       3.812       4.556
# C(StateCD)[T.WA]                 1.1135      0.121      9.171      0.000       0.876       1.351
# C(StateCD)[T.WI]                 0.9334      0.119      7.813      0.000       0.699       1.168
# C(StateCD)[T.WV]                 0.8088      0.135      5.993      0.000       0.544       1.073
# C(StateCD)[T.WY]                -1.2198      0.159     -7.675      0.000      -1.531      -0.908
# C(Metro)[T.Micropolitan]        -3.6584      0.022   -164.728      0.000      -3.702      -3.615
# C(Metro)[T.Noncore_adjacent]    -4.4670      0.051    -87.534      0.000      -4.567      -4.367
# C(Metro)[T.Noncore_remote]      -5.4119      0.225    -24.063      0.000      -5.853      -4.971
# C(Metro)[T.Smaller_metro]       -2.1183      0.017   -121.279      0.000      -2.153      -2.084
# Poverty_PCT_2018                -0.0728      0.002    -41.022      0.000      -0.076      -0.069
# Deaths_PER_100K                  0.0071      0.000     38.333      0.000       0.007       0.007
# ==============================================================================
# Omnibus:                    19848.456   Durbin-Watson:                   0.046
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           140050.600
# Skew:                           0.378   Prob(JB):                         0.00
# Kurtosis:                       7.501   Cond. No.                     8.04e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.04e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
formula1 = """Deaths_PER_100K ~ Poverty_PCT_2018 + C(StateCD) + PCT_Black_ACS + residential_PCT_CFB_RollingAvg + C(Metro)"""

graph_bic_adj2_TS(formulatxt=formula1, list_dateranges=every_month, df=combined)
# Out:
# Deaths_PER_100K ~ Poverty_PCT_2018 + C(StateCD) + PCT_Black_ACS + residential_PCT_CFB_RollingAvg + C(Metro)

# %%
mod1 = start_end_mulivariate_ols(startdate = "2020-06-01", enddate = "2020-12-01", formulatxt=formula1)
print(mod1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Deaths_PER_100K   R-squared:                       0.417
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     2028.
# Date:                Mon, 14 Dec 2020   Prob (F-statistic):               0.00
# Time:                        17:43:52   Log-Likelihood:            -8.0348e+05
# No. Observations:              161394   AIC:                         1.607e+06
# Df Residuals:                  161336   BIC:                         1.608e+06
# Df Model:                          57
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -9.9360      1.563     -6.356      0.000     -13.000      -6.872
# C(StateCD)[T.AL]                   4.1163      1.622      2.538      0.011       0.938       7.295
# C(StateCD)[T.AR]                   8.7973      1.707      5.153      0.000       5.451      12.143
# C(StateCD)[T.AZ]                  53.4172      1.742     30.671      0.000      50.004      56.831
# C(StateCD)[T.CA]                  -6.2591      1.585     -3.948      0.000      -9.367      -3.152
# C(StateCD)[T.CO]                  14.0558      1.679      8.370      0.000      10.764      17.347
# C(StateCD)[T.CT]                  74.0561      1.778     41.640      0.000      70.570      77.542
# C(StateCD)[T.DC]                  20.9758      3.057      6.861      0.000      14.984      26.968
# C(StateCD)[T.DE]                  40.5685      2.143     18.928      0.000      36.368      44.769
# C(StateCD)[T.FL]                  19.1872      1.575     12.180      0.000      16.100      22.275
# C(StateCD)[T.GA]                  13.4942      1.596      8.456      0.000      10.366      16.622
# C(StateCD)[T.HI]                 -10.8072      2.095     -5.159      0.000     -14.913      -6.702
# C(StateCD)[T.IA]                  24.2286      1.710     14.166      0.000      20.876      27.581
# C(StateCD)[T.ID]                  13.3827      1.802      7.426      0.000       9.851      16.915
# C(StateCD)[T.IL]                  14.9007      1.610      9.258      0.000      11.746      18.055
# C(StateCD)[T.IN]                  25.0011      1.602     15.602      0.000      21.860      28.142
# C(StateCD)[T.KS]                  -1.9402      1.752     -1.108      0.268      -5.374       1.493
# C(StateCD)[T.KY]                  -4.4491      1.671     -2.662      0.008      -7.725      -1.173
# C(StateCD)[T.LA]                  53.0313      1.662     31.917      0.000      49.775      56.288
# C(StateCD)[T.MA]                  96.2428      1.710     56.290      0.000      92.892      99.594
# C(StateCD)[T.MD]                  21.5251      1.681     12.804      0.000      18.230      24.820
# C(StateCD)[T.ME]                  -6.0107      1.834     -3.278      0.001      -9.604      -2.417
# C(StateCD)[T.MI]                  17.0523      1.591     10.721      0.000      13.935      20.170
# C(StateCD)[T.MN]                   7.5335      1.663      4.530      0.000       4.274      10.793
# C(StateCD)[T.MO]                  -1.2031      1.633     -0.737      0.461      -4.403       1.997
# C(StateCD)[T.MS]                  25.3344      1.787     14.180      0.000      21.833      28.836
# C(StateCD)[T.MT]                   1.6201      1.879      0.862      0.389      -2.063       5.303
# C(StateCD)[T.NC]                   2.3581      1.576      1.497      0.134      -0.730       5.446
# C(StateCD)[T.ND]                  32.0598      2.035     15.758      0.000      28.072      36.047
# C(StateCD)[T.NE]                  13.9381      1.947      7.159      0.000      10.122      17.754
# C(StateCD)[T.NH]                   9.4289      1.842      5.119      0.000       5.819      13.039
# C(StateCD)[T.NJ]                 128.8976      1.637     78.746      0.000     125.689     132.106
# C(StateCD)[T.NM]                  12.4132      1.758      7.061      0.000       8.968      15.859
# C(StateCD)[T.NV]                  11.3555      1.991      5.703      0.000       7.453      15.258
# C(StateCD)[T.NY]                  47.8182      1.583     30.209      0.000      44.716      50.921
# C(StateCD)[T.OH]                  12.2719      1.575      7.793      0.000       9.185      15.358
# C(StateCD)[T.OK]                  -1.2111      1.664     -0.728      0.467      -4.472       2.050
# C(StateCD)[T.OR]                 -12.5551      1.648     -7.619      0.000     -15.785      -9.325
# C(StateCD)[T.PA]                  23.4033      1.576     14.845      0.000      20.313      26.493
# C(StateCD)[T.RI]                  47.1534      2.073     22.743      0.000      43.090      51.217
# C(StateCD)[T.SC]                  19.2311      1.633     11.775      0.000      16.030      22.432
# C(StateCD)[T.SD]                  23.7568      2.303     10.317      0.000      19.243      28.270
# C(StateCD)[T.TN]                   4.1357      1.605      2.577      0.010       0.991       7.281
# C(StateCD)[T.TX]                  14.7147      1.566      9.397      0.000      11.646      17.784
# C(StateCD)[T.UT]                  -4.2375      1.781     -2.380      0.017      -7.727      -0.748
# C(StateCD)[T.VA]                  -3.4066      1.611     -2.115      0.034      -6.564      -0.249
# C(StateCD)[T.VT]                   1.8864      2.550      0.740      0.460      -3.112       6.885
# C(StateCD)[T.WA]                   5.7003      1.629      3.500      0.000       2.508       8.892
# C(StateCD)[T.WI]                   9.1557      1.601      5.717      0.000       6.017      12.294
# C(StateCD)[T.WV]                 -12.6108      1.810     -6.967      0.000     -16.159      -9.063
# C(StateCD)[T.WY]                   0.6489      2.131      0.305      0.761      -3.527       4.825
# C(Metro)[T.Micropolitan]         -11.9781      0.332    -36.089      0.000     -12.629     -11.328
# C(Metro)[T.Noncore_adjacent]       2.2195      0.707      3.138      0.002       0.833       3.606
# C(Metro)[T.Noncore_remote]       -19.6774      3.020     -6.515      0.000     -25.597     -13.757
# C(Metro)[T.Smaller_metro]        -16.9371      0.247    -68.512      0.000     -17.422     -16.453
# Poverty_PCT_2018                   2.7227      0.026    104.062      0.000       2.671       2.774
# PCT_Black_ACS                      0.3603      0.011     32.654      0.000       0.339       0.382
# residential_PCT_CFB_RollingAvg     1.0972      0.034     32.584      0.000       1.031       1.163
# ==============================================================================
# Omnibus:                    56901.242   Durbin-Watson:                   0.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           368009.032
# Skew:                           1.550   Prob(JB):                         0.00
# Kurtosis:                       9.716   Cond. No.                     2.58e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.58e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
formula1 = """Deaths_New_RollingAvg_PER_100K ~ residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + StateCD"""

graph_bic_adj2_TS(formulatxt=formula1, list_dateranges=every_month, df=combined)
# Out:
# Deaths_New_RollingAvg_PER_100K ~ residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + StateCD

# %%
formula1 = """Deaths_New_RollingAvg_PER_100K ~ residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Metro"""

graph_bic_adj2_TS(formulatxt=formula1, list_dateranges=every_month, df=combined)
# Out:
# Deaths_New_RollingAvg_PER_100K ~ residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Metro

# %% [markdown]
# ## List of all possible formulas for OLS

# %%
full_form_list[0:5]
# Out:
# ['Deaths_New_RollingAvg_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + residential_PCT_CFB_RollingAvg',
#  'Deaths_New_RollingAvg_PER_100K ~  C(Metro) + residential_PCT_CFB_RollingAvg + Poverty_PCT_2018 + Median_Income_2018 + C(StateCD)',
#  'Deaths_New_RollingAvg_PER_100K ~  C(Metro) + PCT_Black_ACS + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018',
#  'Deaths_New_RollingAvg_PER_100K ~  Median_Income_2018 + C(StateCD)',
#  'Deaths_New_RollingAvg_PER_100K ~  C(Metro) + Confirmed_New_RollingAvg_PER_100K + Median_Income_2018 + C(StateCD)']

# %%
list_df = []
for i in tqdm(full_form_list):
    try:
        df = run_timeseries_models(formulatxt=i, list_dateranges=every_month, df=combined)
        list_df.append(df)
    except:
        print("Error for {i}".format(i=i))
# Out:
# 100%|██████████| 255/255 [25:03<00:00,  5.90s/it]

# %%
bigdf = pd.concat(list_df)

# %%
bigdf['num_var'] = bigdf['formula'].str.count('\+')+1

# %%
list_forms = list(bigdf.formula.unique())
list_forms =[i for i in list(bigdf['formula'].unique()) if "CFB" not in i]


b = bigdf[bigdf.formula.isin(list_forms)].groupby("formula").mean().sort_values(by="num_var",ascending=False)
b[b.num_var <= 4].sort_values(by="bic",ascending=True)
# Out:
#                                                          bic       aic  \
# formula
# Deaths_New_RollingAvg_PER_100K ~  PCT_Black_ACS... 217134.25 216624.85
# Deaths_New_RollingAvg_PER_100K ~  PCT_Black_ACS... 217198.75 216689.35
# Deaths_New_RollingAvg_PER_100K ~  C(Metro) + PC... 217210.01 216672.31
# Deaths_New_RollingAvg_PER_100K ~  PCT_Black_ACS... 217219.73 216710.33
# Deaths_New_RollingAvg_PER_100K ~  C(Metro) + Co... 217478.56 216940.86
# ...                                                      ...       ...
# Deaths_New_RollingAvg_PER_100K ~  Poverty_PCT_2018 228123.99 228105.12
# Deaths_New_RollingAvg_PER_100K ~  C(Metro)         228527.59 228480.42
# Deaths_New_RollingAvg_PER_100K ~  BACHELORS_PLU... 228555.93 228527.63
# Deaths_New_RollingAvg_PER_100K ~  Median_Income... 228648.14 228629.27
# Deaths_New_RollingAvg_PER_100K ~  BACHELORS_PLU... 228803.50 228784.63
#
#                                                     r2_adj    n_obs  num_var
# formula
# Deaths_New_RollingAvg_PER_100K ~  PCT_Black_ACS...    0.13 92364.50        4
# Deaths_New_RollingAvg_PER_100K ~  PCT_Black_ACS...    0.13 92364.50        4
# Deaths_New_RollingAvg_PER_100K ~  C(Metro) + PC...    0.13 92364.50        4
# Deaths_New_RollingAvg_PER_100K ~  PCT_Black_ACS...    0.13 92364.50        4
# Deaths_New_RollingAvg_PER_100K ~  C(Metro) + Co...    0.13 92364.50        4
# ...                                                    ...      ...      ...
# Deaths_New_RollingAvg_PER_100K ~  Poverty_PCT_2018    0.02 92364.50        1
# Deaths_New_RollingAvg_PER_100K ~  C(Metro)            0.01 92364.50        1
# Deaths_New_RollingAvg_PER_100K ~  BACHELORS_PLU...    0.01 92364.50        2
# Deaths_New_RollingAvg_PER_100K ~  Median_Income...    0.01 92364.50        1
# Deaths_New_RollingAvg_PER_100K ~  BACHELORS_PLU...    0.01 92364.50        1
#
# [98 rows x 5 columns]

# %%
bigdf
# Out:
#          bic       aic       start         end  r2_adj  \
# 0   25078.59  25055.26  2020-04-01  2020-05-01    0.65
# 1   30011.00  29987.25  2020-05-01  2020-06-01    0.34
# 2   15522.32  15498.44  2020-06-01  2020-07-01    0.08
# 3    8731.19   8707.23  2020-07-01  2020-08-01    0.24
# 4   22940.64  22916.26  2020-08-01  2020-09-01    0.21
# ..       ...       ...         ...         ...     ...
# 3  183079.19 183022.48  2020-07-01  2020-08-01    0.01
# 4  243592.35 243535.64  2020-08-01  2020-09-01    0.02
# 5  232625.12 232568.62  2020-09-01  2020-10-01    0.01
# 6  306800.59 306743.89  2020-10-01  2020-11-01    0.01
# 7  344888.97 344832.47  2020-11-01  2020-12-01    0.02
#
#                                               formula    n_obs  num_var
# 0   Deaths_New_RollingAvg_PER_100K ~  Confirmed_Ne... 17654.00        2
# 1   Deaths_New_RollingAvg_PER_100K ~  Confirmed_Ne... 20268.00        2
# 2   Deaths_New_RollingAvg_PER_100K ~  Confirmed_Ne... 21212.00        2
# 3   Deaths_New_RollingAvg_PER_100K ~  Confirmed_Ne... 21732.00        2
# 4   Deaths_New_RollingAvg_PER_100K ~  Confirmed_Ne... 24967.00        2
# ..                                                ...      ...      ...
# 3   Deaths_New_RollingAvg_PER_100K ~  C(Metro) + B... 93930.00        2
# 4   Deaths_New_RollingAvg_PER_100K ~  C(Metro) + B... 93930.00        2
# 5   Deaths_New_RollingAvg_PER_100K ~  C(Metro) + B... 90799.00        2
# 6   Deaths_New_RollingAvg_PER_100K ~  C(Metro) + B... 93930.00        2
# 7   Deaths_New_RollingAvg_PER_100K ~  C(Metro) + B... 90799.00        2
#
# [2040 rows x 8 columns]

# %%
bigdf[bigdf.formula.isin(list_forms)]
# Out:
#          bic       aic       start         end  r2_adj  \
# 0  160066.94 159991.61  2020-04-01  2020-05-01    0.19
# 1  184845.03 184769.43  2020-05-01  2020-06-01    0.09
# 2  139791.16 139715.83  2020-06-01  2020-07-01    0.07
# 3  175194.02 175118.41  2020-07-01  2020-08-01    0.09
# 4  237181.67 237106.07  2020-08-01  2020-09-01    0.08
# ..       ...       ...         ...         ...     ...
# 3  183079.19 183022.48  2020-07-01  2020-08-01    0.01
# 4  243592.35 243535.64  2020-08-01  2020-09-01    0.02
# 5  232625.12 232568.62  2020-09-01  2020-10-01    0.01
# 6  306800.59 306743.89  2020-10-01  2020-11-01    0.01
# 7  344888.97 344832.47  2020-11-01  2020-12-01    0.02
#
#                                               formula    n_obs  num_var
# 0   Deaths_New_RollingAvg_PER_100K ~  C(Metro) + P... 90799.00        4
# 1   Deaths_New_RollingAvg_PER_100K ~  C(Metro) + P... 93930.00        4
# 2   Deaths_New_RollingAvg_PER_100K ~  C(Metro) + P... 90799.00        4
# 3   Deaths_New_RollingAvg_PER_100K ~  C(Metro) + P... 93930.00        4
# 4   Deaths_New_RollingAvg_PER_100K ~  C(Metro) + P... 93930.00        4
# ..                                                ...      ...      ...
# 3   Deaths_New_RollingAvg_PER_100K ~  C(Metro) + B... 93930.00        2
# 4   Deaths_New_RollingAvg_PER_100K ~  C(Metro) + B... 93930.00        2
# 5   Deaths_New_RollingAvg_PER_100K ~  C(Metro) + B... 90799.00        2
# 6   Deaths_New_RollingAvg_PER_100K ~  C(Metro) + B... 93930.00        2
# 7   Deaths_New_RollingAvg_PER_100K ~  C(Metro) + B... 90799.00        2
#
# [1016 rows x 8 columns]

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(18,9))
sns.scatterplot(y="r2_adj", x="start", hue = "num_var", data=bigdf[bigdf.formula.isin(list_forms)])
plt.title("Adjusted R Squared vs Start Date of 1-Month Regression")
plt.legend("Number of Variables")

# %%
formula1 = """
Deaths_New_RollingAvg_PER_100K ~ C(Metro) + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + C(StateCD)
"""
graph_bic_adj2_TS(formulatxt=formula1, list_dateranges=every_month, df=combined)

mod2 = start_end_mulivariate_ols(formulatxt=formula1, startdate='2020-06-01', enddate='2020-11-15', df= combined)
print(mod2.summary())
# Out:
# Deaths_New_RollingAvg_PER_100K ~ C(Metro) + BACHELORS_PLUS_2018 + residential_PCT_CFB_RollingAvg + C(StateCD)
#
#
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     Deaths_New_RollingAvg_PER_100K   R-squared:                       0.137
# Model:                                        OLS   Adj. R-squared:                  0.136
# Method:                             Least Squares   F-statistic:                     407.9
# Date:                            Mon, 14 Dec 2020   Prob (F-statistic):               0.00
# Time:                                    11:17:23   Log-Likelihood:                -60302.
# No. Observations:                          144544   AIC:                         1.207e+05
# Df Residuals:                              144487   BIC:                         1.213e+05
# Df Model:                                      56
# Covariance Type:                        nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.1573      0.017      9.110      0.000       0.123       0.191
# C(Metro)[T.Micropolitan]           0.1364      0.003     39.073      0.000       0.130       0.143
# C(Metro)[T.Noncore_adjacent]       0.1763      0.008     22.516      0.000       0.161       0.192
# C(Metro)[T.Noncore_remote]         0.0941      0.033      2.824      0.005       0.029       0.159
# C(Metro)[T.Smaller_metro]          0.0749      0.003     29.390      0.000       0.070       0.080
# C(StateCD)[T.AL]                   0.1582      0.018      8.938      0.000       0.123       0.193
# C(StateCD)[T.AR]                   0.2995      0.019     16.020      0.000       0.263       0.336
# C(StateCD)[T.AZ]                   0.3134      0.019     16.501      0.000       0.276       0.351
# C(StateCD)[T.CA]                   0.0051      0.017      0.296      0.767      -0.029       0.039
# C(StateCD)[T.CO]                   0.0776      0.018      4.210      0.000       0.041       0.114
# C(StateCD)[T.CT]                   0.0642      0.019      3.298      0.001       0.026       0.102
# C(StateCD)[T.DC]                   0.1453      0.033      4.372      0.000       0.080       0.210
# C(StateCD)[T.DE]                   0.1306      0.023      5.577      0.000       0.085       0.177
# C(StateCD)[T.FL]                   0.2790      0.017     16.179      0.000       0.245       0.313
# C(StateCD)[T.GA]                   0.2760      0.017     15.930      0.000       0.242       0.310
# C(StateCD)[T.HI]                  -0.2306      0.023     -9.964      0.000      -0.276      -0.185
# C(StateCD)[T.IA]                   0.2180      0.019     11.638      0.000       0.181       0.255
# C(StateCD)[T.ID]                   0.1611      0.020      8.154      0.000       0.122       0.200
# C(StateCD)[T.IL]                   0.1958      0.018     11.117      0.000       0.161       0.230
# C(StateCD)[T.IN]                   0.1841      0.018     10.508      0.000       0.150       0.218
# C(StateCD)[T.KS]                   0.1391      0.019      7.242      0.000       0.101       0.177
# C(StateCD)[T.KY]                   0.0728      0.018      3.975      0.000       0.037       0.109
# C(StateCD)[T.LA]                   0.2327      0.018     12.890      0.000       0.197       0.268
# C(StateCD)[T.MA]                   0.2335      0.019     12.470      0.000       0.197       0.270
# C(StateCD)[T.MD]                   0.0358      0.018      1.945      0.052      -0.000       0.072
# C(StateCD)[T.ME]                  -0.0592      0.020     -2.945      0.003      -0.099      -0.020
# C(StateCD)[T.MI]                   0.0302      0.017      1.737      0.082      -0.004       0.064
# C(StateCD)[T.MN]                   0.0867      0.018      4.753      0.000       0.051       0.122
# C(StateCD)[T.MO]                   0.2206      0.018     12.344      0.000       0.186       0.256
# C(StateCD)[T.MS]                   0.2628      0.019     13.498      0.000       0.225       0.301
# C(StateCD)[T.MT]                   0.2104      0.021     10.191      0.000       0.170       0.251
# C(StateCD)[T.NC]                   0.1289      0.017      7.500      0.000       0.095       0.163
# C(StateCD)[T.ND]                   0.5295      0.022     23.582      0.000       0.485       0.573
# C(StateCD)[T.NE]                   0.1407      0.021      6.561      0.000       0.099       0.183
# C(StateCD)[T.NH]                   0.0216      0.020      1.065      0.287      -0.018       0.061
# C(StateCD)[T.NJ]                   0.2290      0.018     12.769      0.000       0.194       0.264
# C(StateCD)[T.NM]                  -0.0476      0.019     -2.477      0.013      -0.085      -0.010
# C(StateCD)[T.NV]                   0.0211      0.022      0.955      0.340      -0.022       0.065
# C(StateCD)[T.NY]                  -0.0158      0.017     -0.915      0.360      -0.050       0.018
# C(StateCD)[T.OH]                   0.0779      0.017      4.519      0.000       0.044       0.112
# C(StateCD)[T.OK]                   0.0819      0.018      4.494      0.000       0.046       0.118
# C(StateCD)[T.OR]                  -0.0389      0.018     -2.159      0.031      -0.074      -0.004
# C(StateCD)[T.PA]                   0.0504      0.017      2.921      0.003       0.017       0.084
# C(StateCD)[T.RI]                   0.2351      0.023     10.344      0.000       0.191       0.280
# C(StateCD)[T.SC]                   0.3104      0.018     17.478      0.000       0.276       0.345
# C(StateCD)[T.SD]                   0.2041      0.025      8.124      0.000       0.155       0.253
# C(StateCD)[T.TN]                   0.2359      0.018     13.431      0.000       0.201       0.270
# C(StateCD)[T.TX]                   0.2454      0.017     14.311      0.000       0.212       0.279
# C(StateCD)[T.UT]                  -0.0030      0.020     -0.156      0.876      -0.041       0.035
# C(StateCD)[T.VA]                   0.0971      0.018      5.523      0.000       0.063       0.132
# C(StateCD)[T.VT]                  -0.0563      0.028     -2.000      0.045      -0.111      -0.001
# C(StateCD)[T.WA]                  -0.0141      0.018     -0.791      0.429      -0.049       0.021
# C(StateCD)[T.WI]                   0.1291      0.018      7.351      0.000       0.095       0.163
# C(StateCD)[T.WV]                   0.0208      0.020      1.048      0.295      -0.018       0.060
# C(StateCD)[T.WY]                   0.0629      0.023      2.677      0.007       0.017       0.109
# BACHELORS_PLUS_2018               -0.0109      0.000    -75.003      0.000      -0.011      -0.011
# residential_PCT_CFB_RollingAvg     0.0322      0.000     64.768      0.000       0.031       0.033
# ==============================================================================
# Omnibus:                   129758.015   Durbin-Watson:                   0.206
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9154774.231
# Skew:                           4.066   Prob(JB):                         0.00
# Kurtosis:                      41.130   Cond. No.                     3.83e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.83e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
formula1 = """Deaths_PER_100K ~ C(Metro) + PCT_Black_ACS + Poverty_PCT_2018 + C(StateCD)"""
graph_bic_adj2_TS(formulatxt=formula1, list_dateranges=every_month, df=combined)

mod2 = start_end_mulivariate_ols(formulatxt=formula1, startdate='2020-06-01', enddate='2020-11-15', df= combined)
print(mod2.summary())
# Out:
# Deaths_PER_100K ~ C(Metro) + PCT_Black_ACS + Poverty_PCT_2018 + C(StateCD)
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Deaths_PER_100K   R-squared:                       0.293
# Model:                            OLS   Adj. R-squared:                  0.293
# Method:                 Least Squares   F-statistic:                     3852.
# Date:                Mon, 14 Dec 2020   Prob (F-statistic):               0.00
# Time:                        11:17:40   Log-Likelihood:            -2.6633e+06
# No. Observations:              519746   AIC:                         5.327e+06
# Df Residuals:                  519689   BIC:                         5.327e+06
# Df Model:                          56
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -0.1905      0.642     -0.297      0.767      -1.450       1.069
# C(Metro)[T.Micropolitan]        -8.5629      0.220    -38.839      0.000      -8.995      -8.131
# C(Metro)[T.Noncore_adjacent]    -8.9372      0.212    -42.154      0.000      -9.353      -8.522
# C(Metro)[T.Noncore_remote]     -13.8637      0.281    -49.411      0.000     -14.414     -13.314
# C(Metro)[T.Smaller_metro]       -9.1127      0.205    -44.377      0.000      -9.515      -8.710
# C(StateCD)[T.AL]                17.1506      0.740     23.180      0.000      15.701      18.601
# C(StateCD)[T.AR]                 9.5951      0.720     13.325      0.000       8.184      11.007
# C(StateCD)[T.AZ]                62.7361      1.026     61.130      0.000      60.725      64.748
# C(StateCD)[T.CA]                 7.2584      0.742      9.787      0.000       5.805       8.712
# C(StateCD)[T.CO]                12.9942      0.721     18.032      0.000      11.582      14.407
# C(StateCD)[T.CT]                80.1973      1.276     62.838      0.000      77.696      82.699
# C(StateCD)[T.DC]                31.6267      3.229      9.793      0.000      25.297      37.956
# C(StateCD)[T.DE]                42.9075      1.928     22.259      0.000      39.129      46.686
# C(StateCD)[T.FL]                22.9006      0.730     31.351      0.000      21.469      24.332
# C(StateCD)[T.GA]                34.1351      0.680     50.184      0.000      32.802      35.468
# C(StateCD)[T.HI]                 1.7613      1.695      1.039      0.299      -1.560       5.083
# C(StateCD)[T.IA]                26.6058      0.688     38.655      0.000      25.257      27.955
# C(StateCD)[T.ID]                10.0887      0.774     13.034      0.000       8.572      11.606
# C(StateCD)[T.IL]                14.8998      0.689     21.633      0.000      13.550      16.250
# C(StateCD)[T.IN]                28.5748      0.698     40.945      0.000      27.207      29.943
# C(StateCD)[T.KS]                11.6125      0.677     17.143      0.000      10.285      12.940
# C(StateCD)[T.KY]                 3.8425      0.680      5.647      0.000       2.509       5.176
# C(StateCD)[T.LA]                52.2232      0.754     69.300      0.000      50.746      53.700
# C(StateCD)[T.MA]                89.4820      1.044     85.677      0.000      87.435      91.529
# C(StateCD)[T.MD]                20.2137      0.910     22.213      0.000      18.430      21.997
# C(StateCD)[T.ME]                 2.2204      0.995      2.231      0.026       0.270       4.171
# C(StateCD)[T.MI]                14.0096      0.701     19.998      0.000      12.637      15.383
# C(StateCD)[T.MN]                11.5036      0.698     16.485      0.000      10.136      12.871
# C(StateCD)[T.MO]                 3.0499      0.681      4.477      0.000       1.715       4.385
# C(StateCD)[T.MS]                41.6103      0.743     55.982      0.000      40.153      43.067
# C(StateCD)[T.MT]                11.3746      0.733     15.518      0.000       9.938      12.811
# C(StateCD)[T.NC]                 2.8050      0.698      4.021      0.000       1.438       4.172
# C(StateCD)[T.ND]                20.8987      0.743     28.135      0.000      19.443      22.355
# C(StateCD)[T.NE]                13.5826      0.686     19.793      0.000      12.238      14.928
# C(StateCD)[T.NH]                10.9292      1.174      9.309      0.000       8.628      13.230
# C(StateCD)[T.NJ]               134.1268      0.933    143.791      0.000     132.299     135.955
# C(StateCD)[T.NM]                14.1620      0.828     17.112      0.000      12.540      15.784
# C(StateCD)[T.NV]                 5.9150      0.979      6.045      0.000       3.997       7.833
# C(StateCD)[T.NY]                42.6430      0.736     57.950      0.000      41.201      44.085
# C(StateCD)[T.OH]                16.7336      0.702     23.841      0.000      15.358      18.109
# C(StateCD)[T.OK]                 6.4174      0.713      8.997      0.000       5.019       7.815
# C(StateCD)[T.OR]                 2.3581      0.805      2.928      0.003       0.779       3.937
# C(StateCD)[T.PA]                21.0853      0.726     29.034      0.000      19.662      22.509
# C(StateCD)[T.RI]                46.2061      1.548     29.843      0.000      43.171      49.241
# C(StateCD)[T.SC]                17.7462      0.796     22.296      0.000      16.186      19.306
# C(StateCD)[T.SD]                12.6095      0.721     17.485      0.000      11.196      14.023
# C(StateCD)[T.TN]                 9.8469      0.697     14.123      0.000       8.480      11.214
# C(StateCD)[T.TX]                26.4557      0.643     41.161      0.000      25.196      27.715
# C(StateCD)[T.UT]                 4.9356      0.843      5.855      0.000       3.283       6.588
# C(StateCD)[T.VA]                 8.7670      0.682     12.859      0.000       7.431      10.103
# C(StateCD)[T.VT]                 1.7359      1.042      1.666      0.096      -0.307       3.778
# C(StateCD)[T.WA]                 9.4363      0.794     11.877      0.000       7.879      10.993
# C(StateCD)[T.WI]                10.5356      0.714     14.746      0.000       9.135      11.936
# C(StateCD)[T.WV]                -1.2051      0.750     -1.606      0.108      -2.676       0.266
# C(StateCD)[T.WY]                 4.3900      0.895      4.906      0.000       2.636       6.144
# PCT_Black_ACS                    0.8404      0.006    130.256      0.000       0.828       0.853
# Poverty_PCT_2018                 1.0437      0.013     78.472      0.000       1.018       1.070
# ==============================================================================
# Omnibus:                   340719.841   Durbin-Watson:                   0.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7361789.415
# Skew:                           2.836   Prob(JB):                         0.00
# Kurtosis:                      20.544   Cond. No.                     1.70e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.7e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
combined.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'County_FIPS', 'State Code', 'Name',
#        'retail_and_recreation_PCT_CFB', 'grocery_and_pharmacy_PCT_CFB',
#        'parks_PCT_CFB', 'transit_stations_PCT_CFB', 'workplaces_PCT_CFB',
#        'residential_PCT_CFB', 'retail_and_recreation_PCT_CFB_RollingAvg',
#        'grocery_and_pharmacy_PCT_CFB_RollingAvg', 'parks_PCT_CFB_RollingAvg',
#        'transit_stations_PCT_CFB_RollingAvg', 'workplaces_PCT_CFB_RollingAvg',
#        'residential_PCT_CFB_RollingAvg', 'HS_DIPLOMA_ONLY_2018',
#        'SOME_COLLEGE_2018', 'BACHELORS_PLUS_2018', 'Poverty_PCT_2018',
#        'UrbanCD', 'Median_Income_2018', 'Population_ACS',
#        'Population_Black_ACS', 'Population_Hisp_ACS', 'Population_Native_ACS',
#        'PCT_Black_ACS', 'PCT_Hisp_ACS', 'PCT_Native_ACS',
#        'UrbanCD_Description', 'Metro', 'State', 'Confirmed', 'Deaths',
#        'Country/Region', 'Deaths_Previous', 'Confirmed_Previous', 'Deaths_New',
#        'Deaths_New_7', 'Deaths_New_14', 'Deaths_New_21', 'Deaths_New_28',
#        'Confirmed_New', 'locationcol', 'Confirmed_New_RollingAvg',
#        'Deaths_New_RollingAvg', 'Deaths_New_7_RollingAvg',
#        'Deaths_New_14_RollingAvg', 'Deaths_New_21_RollingAvg',
#        'Deaths_New_28_RollingAvg', 'Confirmed_PER_100K', 'Deaths_PER_100K',
#        'Deaths_Previous_PER_100K', 'Deaths_New_PER_100K',
#        'Deaths_New_7_PER_100K', 'Deaths_New_14_PER_100K',
#        'Deaths_New_21_PER_100K', 'Deaths_New_28_PER_100K',
#        'Confirmed_New_PER_100K', 'Confirmed_New_RollingAvg_PER_100K',
#        'Deaths_New_RollingAvg_PER_100K', 'Deaths_New_7_RollingAvg_PER_100K',
#        'Deaths_New_14_RollingAvg_PER_100K',
#        'Deaths_New_21_RollingAvg_PER_100K',
#        'Deaths_New_28_RollingAvg_PER_100K', 'Region', 'Division', 'StateCD'],
#       dtype='object')

# %% [markdown]
# ## Detecting and managing Multicolinearity & VIF

# %%
#Sources: https://etav.github.io/python/vif_factor_python.html
        # https://www.sigmamagic.com/blogs/what-is-variance-inflation-factor/

# %%
#https://etav.github.io/python/vif_factor_python.html

combined_1day = combined[combined.Date == "2020-10-08"]


cols_subset = ["Metro","PCT_Black_ACS",'PCT_Native_ACS',"PCT_Hisp_ACS", 
               "BACHELORS_PLUS_2018","HS_DIPLOMA_ONLY_2018", "Median_Income_2018",
               "Poverty_PCT_2018","Deaths_PER_100K", "StateCD", "Region", "residential_PCT_CFB_RollingAvg"
              ] 
combined_sub2 = combined[cols_subset]

sns.set(rc={'figure.figsize':(11,8)})
corr = combined_sub2.corr()
sns.heatmap(corr, annot=True, fmt='.2f')
plt.show()

# %%
from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
#combined_sub2_long = pd.get_dummies(combined_sub2, columns=["Metro","StateCD"])
()

list_col = list(cols_subset)
#list_col = [i for i in list_col if "Death" not in i and "RollingAvg" not in i]
#list_col.remove("State Code")
list_col.remove("Deaths_PER_100K")

features = "+".join(list_col)


y, X = dmatrices("Deaths_PER_100K ~"+features, combined_sub2, return_type='dataframe')

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
# Out:
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# /Users/philip.ballentine/anaconda3/lib/python3.7/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
vifs = vif.round(1).sort_values(by="VIF Factor", ascending=False)

# %%
vifs[(vifs["features"].str.contains("State") == False) & (vifs["VIF Factor"] != np.inf)]
# Out:
#     VIF Factor                        features
# 62       13.00            HS_DIPLOMA_ONLY_2018
# 61       12.70             BACHELORS_PLUS_2018
# 63        8.80              Median_Income_2018
# 64        5.40                Poverty_PCT_2018
# 60        3.10                    PCT_Hisp_ACS
# 58        2.70                   PCT_Black_ACS
# 4         2.10          Metro[T.Smaller_metro]
# 1         2.10           Metro[T.Micropolitan]
# 59        1.60                  PCT_Native_ACS
# 65        1.40  residential_PCT_CFB_RollingAvg
# 2         1.20       Metro[T.Noncore_adjacent]
# 3         1.10         Metro[T.Noncore_remote]
# 0         0.00                       Intercept

# %% [markdown]
# ## All subsets for county-level regressions

# %%
full_predictors = [
 'C(Metro)',
 'PCT_Black_ACS',
 'BACHELORS_PLUS_2018',
 'Confirmed_New_RollingAvg_PER_100K',
 'PCT_Hispanic_ACS',
 'PCT_Native_ACS',
 'Poverty_PCT_2018',
 'C(StateCD)',
    
]

Ylist = [#'Deaths_New_7_RollingAvg_PER_100K',
         #'Deaths_New_14_RollingAvg_PER_100K',
         #'Deaths_New_28_RollingAvg_PER_100K',
         'Deaths_PER_100K'
         #'Deaths_New_RollingAvg_PER_100K'
            ]

# %%
textlist = []

for i in ps_list:
    text = '|'
    for x in i:
        text = text+' + '+x
    textlist.append(text)


textlist = [i.replace('| +','') for i in textlist if len(i) > 3]
    
full_form_list = []
for i in textlist:
    for y in Ylist:
        full_form_list.append(y+" ~ "+i)


full_form_list
samp_list = full_form_list[0:50]

# %%
list_df = []
for i in tqdm(full_form_list):
    try:
        df = run_timeseries_models(formulatxt=i, list_dateranges=every_month, df=combined)
        list_df.append(df)
    except:
        print("Error for {i}".format(i=i))
# Out:
#   5%|▌         | 13/255 [01:25<25:42,  6.37s/it]

# %%
bigdf_county = pd.concat(list_df)
bigdf_county['num_var'] = bigdf_county['formula'].str.count('\+')+1

# %%
list_forms = list(bigdf_county.formula.unique())
list_forms =[i for i in list(bigdf_county['formula'].unique()) if "Confirmed" not in i and "CFB" not in i and "StateCD" not in i]


bigdf_county[bigdf_county.formula.isin(list_forms)].groupby("formula").mean().sort_values(by="r2_adj",ascending=False).head(30)

# %%
bigdf_county[bigdf_county.formula.isin(list_forms)].groupby("formula").mean().sort_values(by="bic",ascending=True).head(30)

# %%
full_predictors = [
 'C(Metro)',
 'PCT_Black_ACS',
 'BACHELORS_PLUS_2018',
 'Confirmed_New_RollingAvg_PER_100K',
 'PCT_Hispanic_ACS',
 'PCT_Native_ACS',
 'Poverty_PCT_2018',
 'C(StateCD)',
    
]

Ylist = [#'Deaths_New_7_RollingAvg_PER_100K',
         'Deaths_New_14_RollingAvg_PER_100K',
         #'Deaths_New_28_RollingAvg_PER_100K',
         #'Deaths_PER_100K'
         #'Deaths_New_RollingAvg_PER_100K'
            ]

textlist = []

for i in ps_list:
    text = '|'
    for x in i:
        text = text+' + '+x
    textlist.append(text)


textlist = [i.replace('| +','') for i in textlist if len(i) > 3]
    
full_form_list = []
for i in textlist:
    for y in Ylist:
        full_form_list.append(y+" ~ "+i)


list_df = []
for i in tqdm(full_form_list):
    try:
        df = run_timeseries_models(formulatxt=i, list_dateranges=[('2020-06-01','2020-12-01')], df=combined)
        list_df.append(df)
    except:
        print("Error for {i}".format(i=i))
# Out:
# 100%|██████████| 255/255 [12:01<00:00,  2.83s/it]

# %%
bigdf_newdeath = pd.concat(list_df)
bigdf_newdeath['num_var'] = bigdf_newdeath['formula'].str.count('\+')+1

# %%
list_forms = list(bigdf_newdeath.formula.unique())
list_form = [i for i in list_forms if "CFB" not in i]
list_form = [i for i in list_forms if "CFB" not in i and "Confirmed" in i]
list_form

bigdf_newdeath[bigdf_newdeath.formula.isin(list_form) == True].groupby("formula").mean().sort_values(by="r2_adj",ascending=False).head(50)
# Out:
#                                                           bic        aic  \
# formula
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1660020.85 1659347.34
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1660011.07 1659348.78
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1660012.08 1659349.79
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1660006.61 1659355.55
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1660151.13 1659488.84
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1660141.21 1659490.15
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1660204.89 1659553.83
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1660192.77 1659552.93
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1660218.11 1659555.82
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1660205.91 1659554.85
# Deaths_New_14_RollingAvg_PER_100K ~  BACHELORS_... 1660190.20 1659572.81
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_... 1660202.61 1659574.00
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_... 1660194.95 1659577.56
# Deaths_New_14_RollingAvg_PER_100K ~  BACHELORS_... 1660185.33 1659579.16
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1660292.83 1659641.77
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1660346.19 1659706.35
# Deaths_New_14_RollingAvg_PER_100K ~  BACHELORS_... 1660410.12 1659803.96
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_... 1660423.01 1659805.62
# Deaths_New_14_RollingAvg_PER_100K ~  Confirmed_... 1660470.76 1659875.83
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_... 1660483.71 1659877.55
# Deaths_New_14_RollingAvg_PER_100K ~  Confirmed_... 1660483.98 1659877.81
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_... 1660496.93 1659879.54
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1660737.19 1660097.35
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1660749.80 1660098.73
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_... 1660708.42 1660102.25
# Deaths_New_14_RollingAvg_PER_100K ~  BACHELORS_... 1660746.01 1660151.07
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1661199.65 1660559.81
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1661276.23 1660647.61
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_... 1661491.60 1660885.43
# Deaths_New_14_RollingAvg_PER_100K ~  Confirmed_... 1661518.91 1660923.97
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_... 1662795.68 1662200.74
# Deaths_New_14_RollingAvg_PER_100K ~  Confirmed_... 1662845.47 1662261.76
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1665661.36 1665549.11
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1665690.99 1665589.96
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1665698.18 1665597.15
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1665896.60 1665806.80
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_... 1665907.28 1665839.93
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_... 1665936.51 1665880.39
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1665988.41 1665887.38
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1665996.61 1665906.81
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_... 1666008.04 1665951.91
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1666151.78 1666050.75
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1666181.28 1666091.48
# Deaths_New_14_RollingAvg_PER_100K ~  BACHELORS_... 1666305.50 1666249.38
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_... 1666334.81 1666278.68
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_... 1666335.39 1666290.49
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_... 1666340.54 1666295.64
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1666393.18 1666303.38
# Deaths_New_14_RollingAvg_PER_100K ~  BACHELORS_... 1666357.51 1666312.61
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +... 1666431.15 1666341.34
#
#                                                     r2_adj  num_var
# formula
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        7
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        6
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        6
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        5
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        6
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        5
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        5
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        4
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        6
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        5
# Deaths_New_14_RollingAvg_PER_100K ~  BACHELORS_...    0.14        5
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_...    0.14        6
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_...    0.14        5
# Deaths_New_14_RollingAvg_PER_100K ~  BACHELORS_...    0.14        4
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        5
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        4
# Deaths_New_14_RollingAvg_PER_100K ~  BACHELORS_...    0.14        4
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_...    0.14        5
# Deaths_New_14_RollingAvg_PER_100K ~  Confirmed_...    0.14        3
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_...    0.14        4
# Deaths_New_14_RollingAvg_PER_100K ~  Confirmed_...    0.14        4
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_...    0.14        5
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        4
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        5
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_...    0.14        4
# Deaths_New_14_RollingAvg_PER_100K ~  BACHELORS_...    0.14        3
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        4
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.14        3
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_...    0.14        4
# Deaths_New_14_RollingAvg_PER_100K ~  Confirmed_...    0.14        3
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_...    0.14        3
# Deaths_New_14_RollingAvg_PER_100K ~  Confirmed_...    0.14        2
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.13        6
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.13        5
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.13        5
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.13        4
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_...    0.13        5
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_...    0.13        4
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.13        5
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.13        4
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_...    0.13        4
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.13        5
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.13        4
# Deaths_New_14_RollingAvg_PER_100K ~  BACHELORS_...    0.13        4
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_...    0.13        4
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_...    0.13        3
# Deaths_New_14_RollingAvg_PER_100K ~  PCT_Black_...    0.13        3
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.13        4
# Deaths_New_14_RollingAvg_PER_100K ~  BACHELORS_...    0.13        3
# Deaths_New_14_RollingAvg_PER_100K ~  C(Metro) +...    0.13        4

# %%
mod1 = start_end_mulivariate_ols(startdate = "2020-06-01", enddate = "2020-07-01", formulatxt="""
Deaths_New_21_RollingAvg_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + StateCD + Metro""")
print(mod1.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     Deaths_New_21_RollingAvg_PER_100K   R-squared:                       0.112
# Model:                                           OLS   Adj. R-squared:                  0.111
# Method:                                Least Squares   F-statistic:                     250.1
# Date:                               Mon, 14 Dec 2020   Prob (F-statistic):               0.00
# Time:                                       17:19:50   Log-Likelihood:                -85111.
# No. Observations:                             109585   AIC:                         1.703e+05
# Df Residuals:                                 109529   BIC:                         1.709e+05
# Df Model:                                         55
# Covariance Type:                           nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -0.0269      0.018     -1.499      0.134      -0.062       0.008
# StateCD[T.AL]                         0.3625      0.020     17.750      0.000       0.322       0.402
# StateCD[T.AR]                         0.1059      0.020      5.261      0.000       0.066       0.145
# StateCD[T.AZ]                         0.7774      0.029     26.862      0.000       0.721       0.834
# StateCD[T.CA]                         0.0941      0.021      4.510      0.000       0.053       0.135
# StateCD[T.CO]                         0.0389      0.020      1.914      0.056      -0.001       0.079
# StateCD[T.CT]                         0.1115      0.036      3.100      0.002       0.041       0.182
# StateCD[T.DC]                         0.1918      0.091      2.114      0.035       0.014       0.370
# StateCD[T.DE]                         0.2924      0.054      5.390      0.000       0.186       0.399
# StateCD[T.FL]                         0.1824      0.020      8.900      0.000       0.142       0.223
# StateCD[T.GA]                         0.1988      0.019     10.643      0.000       0.162       0.235
# StateCD[T.HI]                         0.0319      0.048      0.669      0.504      -0.062       0.126
# StateCD[T.IA]                         0.0593      0.019      3.055      0.002       0.021       0.097
# StateCD[T.ID]                         0.0308      0.022      1.412      0.158      -0.012       0.074
# StateCD[T.IL]                         0.0708      0.019      3.650      0.000       0.033       0.109
# StateCD[T.IN]                         0.1242      0.020      6.317      0.000       0.086       0.163
# StateCD[T.KS]                         0.0491      0.019      2.571      0.010       0.012       0.086
# StateCD[T.KY]                         0.0852      0.019      4.485      0.000       0.048       0.122
# StateCD[T.LA]                         0.2851      0.021     13.800      0.000       0.245       0.326
# StateCD[T.MA]                         0.2498      0.029      8.488      0.000       0.192       0.307
# StateCD[T.MD]                         0.1046      0.025      4.106      0.000       0.055       0.155
# StateCD[T.ME]                         0.0153      0.028      0.546      0.585      -0.040       0.070
# StateCD[T.MI]                         0.0554      0.020      2.807      0.005       0.017       0.094
# StateCD[T.MN]                         0.0461      0.020      2.347      0.019       0.008       0.085
# StateCD[T.MO]                         0.0379      0.019      1.976      0.048       0.000       0.075
# StateCD[T.MS]                         0.5187      0.020     25.990      0.000       0.480       0.558
# StateCD[T.MT]                         0.0315      0.021      1.524      0.127      -0.009       0.072
# StateCD[T.NC]                         0.1107      0.019      5.696      0.000       0.073       0.149
# StateCD[T.ND]                         0.0282      0.021      1.346      0.178      -0.013       0.069
# StateCD[T.NE]                         0.0291      0.019      1.508      0.132      -0.009       0.067
# StateCD[T.NH]                         0.0854      0.033      2.582      0.010       0.021       0.150
# StateCD[T.NJ]                         0.8320      0.026     31.695      0.000       0.781       0.883
# StateCD[T.NM]                         0.1277      0.023      5.526      0.000       0.082       0.173
# StateCD[T.NV]                         0.0764      0.028      2.771      0.006       0.022       0.130
# StateCD[T.NY]                         0.0771      0.021      3.723      0.000       0.037       0.118
# StateCD[T.OH]                         0.1018      0.020      5.151      0.000       0.063       0.141
# StateCD[T.OK]                         0.0498      0.020      2.484      0.013       0.011       0.089
# StateCD[T.OR]                         0.0693      0.023      3.055      0.002       0.025       0.114
# StateCD[T.PA]                         0.1086      0.020      5.305      0.000       0.068       0.149
# StateCD[T.RI]                         0.1644      0.044      3.767      0.000       0.079       0.250
# StateCD[T.SC]                         0.3675      0.022     16.880      0.000       0.325       0.410
# StateCD[T.SD]                         0.0952      0.020      4.692      0.000       0.055       0.135
# StateCD[T.TN]                         0.0949      0.020      4.847      0.000       0.057       0.133
# StateCD[T.TX]                         0.1937      0.018     10.722      0.000       0.158       0.229
# StateCD[T.UT]                         0.0887      0.024      3.735      0.000       0.042       0.135
# StateCD[T.VA]                         0.1701      0.019      8.935      0.000       0.133       0.207
# StateCD[T.VT]                         0.0125      0.029      0.427      0.669      -0.045       0.070
# StateCD[T.WA]                         0.0672      0.022      3.004      0.003       0.023       0.111
# StateCD[T.WI]                         0.0336      0.020      1.671      0.095      -0.006       0.073
# StateCD[T.WV]                         0.0256      0.021      1.215      0.224      -0.016       0.067
# StateCD[T.WY]                        -0.0126      0.025     -0.499      0.618      -0.062       0.037
# Metro[T.Micropolitan]                -0.0008      0.006     -0.143      0.886      -0.012       0.011
# Metro[T.Noncore_adjacent]             0.0364      0.005      6.653      0.000       0.026       0.047
# Metro[T.Noncore_remote]               0.0196      0.007      2.673      0.008       0.005       0.034
# Metro[T.Smaller_metro]               -0.0052      0.006     -0.931      0.352      -0.016       0.006
# Confirmed_New_RollingAvg_PER_100K     0.0074      0.000     67.085      0.000       0.007       0.008
# ==============================================================================
# Omnibus:                   165661.896   Durbin-Watson:                   0.343
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        295398087.306
# Skew:                           8.886   Prob(JB):                         0.00
# Kurtosis:                     256.730   Cond. No.                     1.31e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
mod1 = start_end_mulivariate_ols(startdate = "2020-04-01", enddate = "2020-06-01", formulatxt="""
Deaths_New_21_RollingAvg_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + StateCD""")
print(mod1.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     Deaths_New_21_RollingAvg_PER_100K   R-squared:                       0.129
# Model:                                           OLS   Adj. R-squared:                  0.128
# Method:                                Least Squares   F-statistic:                     543.5
# Date:                               Mon, 14 Dec 2020   Prob (F-statistic):               0.00
# Time:                                       17:23:06   Log-Likelihood:            -1.7072e+05
# No. Observations:                             187860   AIC:                         3.416e+05
# Df Residuals:                                 187808   BIC:                         3.421e+05
# Df Model:                                         51
# Covariance Type:                           nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.0193      0.015      1.321      0.187      -0.009       0.048
# StateCD[T.AL]                         0.2886      0.017     16.533      0.000       0.254       0.323
# StateCD[T.AR]                         0.0487      0.017      2.838      0.005       0.015       0.082
# StateCD[T.AZ]                         0.3383      0.025     13.638      0.000       0.290       0.387
# StateCD[T.CA]                         0.0280      0.018      1.569      0.117      -0.007       0.063
# StateCD[T.CO]                         0.1173      0.018      6.678      0.000       0.083       0.152
# StateCD[T.CT]                         0.9104      0.031     29.278      0.000       0.849       0.971
# StateCD[T.DC]                         0.9056      0.079     11.477      0.000       0.751       1.060
# StateCD[T.DE]                         0.5789      0.047     12.288      0.000       0.487       0.671
# StateCD[T.FL]                         0.1065      0.017      6.104      0.000       0.072       0.141
# StateCD[T.GA]                         0.3398      0.016     21.373      0.000       0.309       0.371
# StateCD[T.HI]                        -0.0154      0.041     -0.371      0.711      -0.097       0.066
# StateCD[T.IA]                         0.1498      0.017      9.021      0.000       0.117       0.182
# StateCD[T.ID]                        -0.0097      0.019     -0.516      0.606      -0.046       0.027
# StateCD[T.IL]                         0.1233      0.017      7.449      0.000       0.091       0.156
# StateCD[T.IN]                         0.2381      0.017     14.227      0.000       0.205       0.271
# StateCD[T.KS]                         0.0027      0.016      0.164      0.870      -0.030       0.035
# StateCD[T.KY]                         0.0889      0.016      5.464      0.000       0.057       0.121
# StateCD[T.LA]                         0.4863      0.018     27.586      0.000       0.452       0.521
# StateCD[T.MA]                         0.9923      0.025     39.070      0.000       0.943       1.042
# StateCD[T.MD]                         0.4405      0.022     20.182      0.000       0.398       0.483
# StateCD[T.ME]                         0.0262      0.024      1.080      0.280      -0.021       0.074
# StateCD[T.MI]                         0.1350      0.017      7.968      0.000       0.102       0.168
# StateCD[T.MN]                         0.0474      0.017      2.811      0.005       0.014       0.080
# StateCD[T.MO]                         0.0274      0.016      1.673      0.094      -0.005       0.059
# StateCD[T.MS]                         0.4796      0.017     28.239      0.000       0.446       0.513
# StateCD[T.MT]                        -0.0052      0.018     -0.288      0.773      -0.040       0.030
# StateCD[T.NC]                         0.1195      0.017      7.209      0.000       0.087       0.152
# StateCD[T.ND]                        -0.0143      0.018     -0.790      0.429      -0.050       0.021
# StateCD[T.NE]                         0.0629      0.017      3.762      0.000       0.030       0.096
# StateCD[T.NH]                         0.1443      0.029      5.053      0.000       0.088       0.200
# StateCD[T.NJ]                         1.2880      0.022     57.385      0.000       1.244       1.332
# StateCD[T.NM]                         0.1890      0.020      9.486      0.000       0.150       0.228
# StateCD[T.NV]                         0.0268      0.024      1.125      0.261      -0.020       0.074
# StateCD[T.NY]                         0.4281      0.018     24.230      0.000       0.393       0.463
# StateCD[T.OH]                         0.1786      0.017     10.616      0.000       0.146       0.212
# StateCD[T.OK]                         0.0436      0.017      2.548      0.011       0.010       0.077
# StateCD[T.OR]                        -0.0015      0.020     -0.078      0.937      -0.040       0.037
# StateCD[T.PA]                         0.2634      0.017     15.096      0.000       0.229       0.298
# StateCD[T.RI]                         0.6776      0.038     17.999      0.000       0.604       0.751
# StateCD[T.SC]                         0.1993      0.019     10.722      0.000       0.163       0.236
# StateCD[T.SD]                        -0.0010      0.017     -0.056      0.955      -0.035       0.033
# StateCD[T.TN]                        -0.0151      0.017     -0.905      0.366      -0.048       0.018
# StateCD[T.TX]                         0.0650      0.015      4.212      0.000       0.035       0.095
# StateCD[T.UT]                        -0.0076      0.021     -0.371      0.711      -0.048       0.033
# StateCD[T.VA]                         0.1941      0.016     11.999      0.000       0.162       0.226
# StateCD[T.VT]                        -0.0127      0.025     -0.501      0.616      -0.062       0.037
# StateCD[T.WA]                         0.0382      0.019      1.989      0.047       0.001       0.076
# StateCD[T.WI]                         0.0353      0.017      2.043      0.041       0.001       0.069
# StateCD[T.WV]                         0.0281      0.018      1.559      0.119      -0.007       0.063
# StateCD[T.WY]                        -0.0329      0.022     -1.507      0.132      -0.076       0.010
# Confirmed_New_RollingAvg_PER_100K     0.0065   7.59e-05     85.488      0.000       0.006       0.007
# ==============================================================================
# Omnibus:                   275993.630   Durbin-Watson:                   0.212
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        308489732.371
# Skew:                           8.552   Prob(JB):                         0.00
# Kurtosis:                     200.784   Cond. No.                     1.48e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.48e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
mod1 = start_end_mulivariate_ols(startdate = "2020-06-01", enddate = "2020-09-01", formulatxt="""
Deaths_New_21_RollingAvg_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + StateCD""")
print(mod1.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     Deaths_New_21_RollingAvg_PER_100K   R-squared:                       0.112
# Model:                                           OLS   Adj. R-squared:                  0.112
# Method:                                Least Squares   F-statistic:                     706.8
# Date:                               Mon, 14 Dec 2020   Prob (F-statistic):               0.00
# Time:                                       17:22:48   Log-Likelihood:            -3.1652e+05
# No. Observations:                             284921   AIC:                         6.331e+05
# Df Residuals:                                 284869   BIC:                         6.337e+05
# Df Model:                                         51
# Covariance Type:                           nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -0.0411      0.015     -2.820      0.005      -0.070      -0.013
# StateCD[T.AL]                         0.2816      0.017     16.190      0.000       0.248       0.316
# StateCD[T.AR]                         0.3000      0.017     17.553      0.000       0.267       0.334
# StateCD[T.AZ]                         0.5687      0.025     23.025      0.000       0.520       0.617
# StateCD[T.CA]                         0.1319      0.018      7.438      0.000       0.097       0.167
# StateCD[T.CO]                         0.0513      0.017      2.939      0.003       0.017       0.086
# StateCD[T.CT]                         0.0776      0.031      2.511      0.012       0.017       0.138
# StateCD[T.DC]                         0.1123      0.078      1.432      0.152      -0.041       0.266
# StateCD[T.DE]                         0.1794      0.047      3.833      0.000       0.088       0.271
# StateCD[T.FL]                         0.2806      0.017     16.081      0.000       0.246       0.315
# StateCD[T.GA]                         0.3996      0.016     25.228      0.000       0.369       0.431
# StateCD[T.HI]                         0.0593      0.041      1.439      0.150      -0.021       0.140
# StateCD[T.IA]                         0.1385      0.016      8.392      0.000       0.106       0.171
# StateCD[T.ID]                         0.0885      0.019      4.750      0.000       0.052       0.125
# StateCD[T.IL]                         0.1299      0.016      7.893      0.000       0.098       0.162
# StateCD[T.IN]                         0.1445      0.017      8.692      0.000       0.112       0.177
# StateCD[T.KS]                         0.1163      0.016      7.098      0.000       0.084       0.148
# StateCD[T.KY]                         0.1201      0.016      7.428      0.000       0.088       0.152
# StateCD[T.LA]                         0.4413      0.018     25.108      0.000       0.407       0.476
# StateCD[T.MA]                         0.2134      0.025      8.462      0.000       0.164       0.263
# StateCD[T.MD]                         0.0820      0.022      3.783      0.000       0.040       0.125
# StateCD[T.ME]                         0.0546      0.024      2.262      0.024       0.007       0.102
# StateCD[T.MI]                         0.0694      0.017      4.124      0.000       0.036       0.102
# StateCD[T.MN]                         0.0754      0.017      4.507      0.000       0.043       0.108
# StateCD[T.MO]                         0.0700      0.016      4.310      0.000       0.038       0.102
# StateCD[T.MS]                         0.6405      0.017     37.805      0.000       0.607       0.674
# StateCD[T.MT]                         0.1031      0.018      5.782      0.000       0.068       0.138
# StateCD[T.NC]                         0.1630      0.016      9.886      0.000       0.131       0.195
# StateCD[T.ND]                         0.1032      0.018      5.733      0.000       0.068       0.138
# StateCD[T.NE]                         0.1002      0.017      6.033      0.000       0.068       0.133
# StateCD[T.NH]                         0.0710      0.028      2.502      0.012       0.015       0.127
# StateCD[T.NJ]                         0.3714      0.022     16.699      0.000       0.328       0.415
# StateCD[T.NM]                         0.1629      0.020      8.231      0.000       0.124       0.202
# StateCD[T.NV]                         0.0833      0.024      3.517      0.000       0.037       0.130
# StateCD[T.NY]                         0.0671      0.018      3.825      0.000       0.033       0.102
# StateCD[T.OH]                         0.1471      0.017      8.800      0.000       0.114       0.180
# StateCD[T.OK]                         0.1002      0.017      5.893      0.000       0.067       0.134
# StateCD[T.OR]                         0.0801      0.019      4.125      0.000       0.042       0.118
# StateCD[T.PA]                         0.1035      0.017      5.968      0.000       0.069       0.137
# StateCD[T.RI]                         0.1129      0.037      3.018      0.003       0.040       0.186
# StateCD[T.SC]                         0.5190      0.019     28.038      0.000       0.483       0.555
# StateCD[T.SD]                         0.1005      0.017      5.784      0.000       0.066       0.135
# StateCD[T.TN]                         0.1861      0.017     11.215      0.000       0.154       0.219
# StateCD[T.TX]                         0.4244      0.015     27.625      0.000       0.394       0.455
# StateCD[T.UT]                         0.0800      0.020      3.917      0.000       0.040       0.120
# StateCD[T.VA]                         0.2286      0.016     14.219      0.000       0.197       0.260
# StateCD[T.VT]                         0.0376      0.025      1.490      0.136      -0.012       0.087
# StateCD[T.WA]                         0.0780      0.019      4.090      0.000       0.041       0.115
# StateCD[T.WI]                         0.0435      0.017      2.538      0.011       0.010       0.077
# StateCD[T.WV]                         0.1251      0.018      6.996      0.000       0.090       0.160
# StateCD[T.WY]                         0.0977      0.022      4.508      0.000       0.055       0.140
# Confirmed_New_RollingAvg_PER_100K     0.0089    7.7e-05    115.633      0.000       0.009       0.009
# ==============================================================================
# Omnibus:                   408313.693   Durbin-Watson:                   0.243
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        566382635.589
# Skew:                           8.025   Prob(JB):                         0.00
# Kurtosis:                     220.833   Cond. No.                     1.76e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.76e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
mod1 = start_end_mulivariate_ols(startdate = "2020-10-01", enddate = "2020-12-01", formulatxt="""
Deaths_New_14_RollingAvg_PER_100K ~  Confirmed_New_RollingAvg_PER_100K + StateCD""")
print(mod1.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     Deaths_New_14_RollingAvg_PER_100K   R-squared:                       0.132
# Model:                                           OLS   Adj. R-squared:                  0.132
# Method:                                Least Squares   F-statistic:                     512.6
# Date:                               Mon, 14 Dec 2020   Prob (F-statistic):               0.00
# Time:                                       17:23:58   Log-Likelihood:            -3.2102e+05
# No. Observations:                             172205   AIC:                         6.421e+05
# Df Residuals:                                 172153   BIC:                         6.427e+05
# Df Model:                                         51
# Covariance Type:                           nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -0.1314      0.040     -3.297      0.001      -0.210      -0.053
# StateCD[T.AL]                         0.3613      0.047      7.627      0.000       0.268       0.454
# StateCD[T.AR]                         0.3948      0.047      8.468      0.000       0.303       0.486
# StateCD[T.AZ]                         0.3438      0.067      5.105      0.000       0.212       0.476
# StateCD[T.CA]                         0.1169      0.048      2.413      0.016       0.022       0.212
# StateCD[T.CO]                         0.2751      0.048      5.768      0.000       0.182       0.369
# StateCD[T.CT]                         0.2122      0.084      2.515      0.012       0.047       0.378
# StateCD[T.DC]                         0.1593      0.214      0.744      0.457      -0.261       0.579
# StateCD[T.DE]                         0.1891      0.128      1.479      0.139      -0.062       0.440
# StateCD[T.FL]                         0.4007      0.047      8.459      0.000       0.308       0.494
# StateCD[T.GA]                         0.5229      0.043     12.121      0.000       0.438       0.607
# StateCD[T.HI]                         0.1831      0.113      1.627      0.104      -0.037       0.404
# StateCD[T.IA]                         0.2817      0.045      6.222      0.000       0.193       0.370
# StateCD[T.ID]                         0.1642      0.051      3.223      0.001       0.064       0.264
# StateCD[T.IL]                         0.6889      0.045     15.292      0.000       0.601       0.777
# StateCD[T.IN]                         0.4527      0.045      9.957      0.000       0.364       0.542
# StateCD[T.KS]                         0.4334      0.045      9.648      0.000       0.345       0.521
# StateCD[T.KY]                         0.1473      0.044      3.333      0.001       0.061       0.234
# StateCD[T.LA]                         0.4969      0.048     10.393      0.000       0.403       0.591
# StateCD[T.MA]                         0.2848      0.069      4.133      0.000       0.150       0.420
# StateCD[T.MD]                         0.2383      0.059      4.022      0.000       0.122       0.354
# StateCD[T.ME]                         0.1940      0.066      2.940      0.003       0.065       0.323
# StateCD[T.MI]                         0.6480      0.046     14.085      0.000       0.558       0.738
# StateCD[T.MN]                         0.3743      0.046      8.163      0.000       0.284       0.464
# StateCD[T.MO]                         0.3121      0.044      7.023      0.000       0.225       0.399
# StateCD[T.MS]                         0.4673      0.046     10.143      0.000       0.377       0.558
# StateCD[T.MT]                         1.0259      0.049     20.964      0.000       0.930       1.122
# StateCD[T.NC]                         0.2919      0.045      6.485      0.000       0.204       0.380
# StateCD[T.ND]                         1.2536      0.050     25.147      0.000       1.156       1.351
# StateCD[T.NE]                         0.2786      0.046      6.121      0.000       0.189       0.368
# StateCD[T.NH]                         0.1986      0.078      2.560      0.010       0.047       0.351
# StateCD[T.NJ]                         0.1674      0.061      2.755      0.006       0.048       0.287
# StateCD[T.NM]                         0.4663      0.054      8.621      0.000       0.360       0.572
# StateCD[T.NV]                         0.3683      0.065      5.691      0.000       0.241       0.495
# StateCD[T.NY]                         0.2026      0.048      4.225      0.000       0.109       0.297
# StateCD[T.OH]                         0.2817      0.046      6.168      0.000       0.192       0.371
# StateCD[T.OK]                         0.1106      0.046      2.379      0.017       0.019       0.202
# StateCD[T.OR]                         0.2026      0.053      3.819      0.000       0.099       0.307
# StateCD[T.PA]                         0.4783      0.047     10.096      0.000       0.385       0.571
# StateCD[T.RI]                         0.3356      0.102      3.284      0.001       0.135       0.536
# StateCD[T.SC]                         0.3735      0.050      7.402      0.000       0.275       0.472
# StateCD[T.SD]                         1.3989      0.048     29.066      0.000       1.305       1.493
# StateCD[T.TN]                         0.5805      0.045     12.817      0.000       0.492       0.669
# StateCD[T.TX]                         0.6714      0.042     16.018      0.000       0.589       0.754
# StateCD[T.UT]                         0.0438      0.056      0.785      0.433      -0.066       0.153
# StateCD[T.VA]                         0.2292      0.044      5.217      0.000       0.143       0.315
# StateCD[T.VT]                         0.1304      0.069      1.891      0.059      -0.005       0.265
# StateCD[T.WA]                         0.2136      0.052      4.095      0.000       0.111       0.316
# StateCD[T.WI]                         0.2854      0.047      6.047      0.000       0.193       0.378
# StateCD[T.WV]                         0.3065      0.049      6.272      0.000       0.211       0.402
# StateCD[T.WY]                         0.1752      0.059      2.953      0.003       0.059       0.291
# Confirmed_New_RollingAvg_PER_100K     0.0104   9.49e-05    109.865      0.000       0.010       0.011
# ==============================================================================
# Omnibus:                   228361.936   Durbin-Watson:                   0.271
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         90509480.966
# Skew:                           7.326   Prob(JB):                         0.00
# Kurtosis:                     114.353   Cond. No.                     4.75e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.75e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
mod1 = start_end_mulivariate_ols(startdate = "2020-10-01", enddate = "2020-12-01", formulatxt="""
Deaths_New_14_RollingAvg_PER_100K ~  Confirmed_New_RollingAvg_PER_100K """)
print(mod1.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     Deaths_New_14_RollingAvg_PER_100K   R-squared:                       0.109
# Model:                                           OLS   Adj. R-squared:                  0.109
# Method:                                Least Squares   F-statistic:                 2.103e+04
# Date:                               Mon, 14 Dec 2020   Prob (F-statistic):               0.00
# Time:                                       17:27:35   Log-Likelihood:            -3.2327e+05
# No. Observations:                             172205   AIC:                         6.465e+05
# Df Residuals:                                 172203   BIC:                         6.466e+05
# Df Model:                                          1
# Covariance Type:                           nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.2292      0.005     45.217      0.000       0.219       0.239
# Confirmed_New_RollingAvg_PER_100K     0.0119   8.23e-05    145.009      0.000       0.012       0.012
# ==============================================================================
# Omnibus:                   230034.770   Durbin-Watson:                   0.266
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         90679634.475
# Skew:                           7.438   Prob(JB):                         0.00
# Kurtosis:                     114.430   Cond. No.                         81.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
