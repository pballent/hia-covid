# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Mobility Data

# %%
# keep FIPS as string to preserve leading zeroes

# %%
combined = pd.read_csv(r"/Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets/hia_covid_combined.csv", dtype={'County_FIPS': 'str'} )

# %%
combined['date'] = combined['date'].astype("datetime64")

# %%
combined_sub = combined.drop(columns=['Unnamed: 0','Date','locationcol','Country/Region'])

# %%
#list(combined_sub.columns)
# Out:
# ['date',
#  'County_FIPS',
#  'StateCD',
#  'Name',
#  'retail_and_recreation_PCT_CFB',
#  'grocery_and_pharmacy_PCT_CFB',
#  'parks_PCT_CFB',
#  'transit_stations_PCT_CFB',
#  'workplaces_PCT_CFB',
#  'residential_PCT_CFB',
#  'retail_and_recreation_PCT_CFB_RollingAvg',
#  'grocery_and_pharmacy_PCT_CFB_RollingAvg',
#  'parks_PCT_CFB_RollingAvg',
#  'transit_stations_PCT_CFB_RollingAvg',
#  'workplaces_PCT_CFB_RollingAvg',
#  'residential_PCT_CFB_RollingAvg',
#  'HS_DIPLOMA_ONLY_2018',
#  'SOME_COLLEGE_2018',
#  'BACHELORS_PLUS_2018',
#  'Poverty_PCT_2018',
#  'UrbanCD',
#  'Median_Income_2018',
#  'Population_ACS',
#  'Population_Black_ACS',
#  'Population_Hisp_ACS',
#  'Population_Native_ACS',
#  'PCT_Black_ACS',
#  'PCT_Hisp_ACS',
#  'PCT_Native_ACS',
#  'UrbanCD_Description',
#  'Metro',
#  'State',
#  'Confirmed',
#  'Deaths',
#  'Deaths_Previous',
#  'Confirmed_Previous',
#  'Deaths_New',
#  'Deaths_New_7',
#  'Deaths_New_14',
#  'Deaths_New_21',
#  'Deaths_New_28',
#  'Confirmed_New',
#  'Confirmed_New_RollingAvg',
#  'Deaths_New_RollingAvg',
#  'Deaths_New_7_RollingAvg',
#  'Deaths_New_14_RollingAvg',
#  'Deaths_New_21_RollingAvg',
#  'Deaths_New_28_RollingAvg',
#  'Confirmed_PER_100K',
#  'Deaths_PER_100K',
#  'Deaths_Previous_PER_100K',
#  'Deaths_New_PER_100K',
#  'Deaths_New_7_PER_100K',
#  'Deaths_New_14_PER_100K',
#  'Deaths_New_21_PER_100K',
#  'Deaths_New_28_PER_100K',
#  'Confirmed_New_PER_100K',
#  'Confirmed_New_RollingAvg_PER_100K',
#  'Deaths_New_RollingAvg_PER_100K',
#  'Deaths_New_7_RollingAvg_PER_100K',
#  'Deaths_New_14_RollingAvg_PER_100K',
#  'Deaths_New_21_RollingAvg_PER_100K',
#  'Deaths_New_28_RollingAvg_PER_100K',
#  'Region',
#  'Division']

# %% [markdown]
# ## Examine per-county distributions

# %%
list_cols = list(combined_sub.columns)

list_cols = [i for i in list_cols if i not in ["Name","State","County_FIPS","Region","Division"]]

# %%
county = combined_sub.groupby(["Name","State","County_FIPS","Region","Division"])[list_cols].max()
county = pd.DataFrame(county) 
county.reset_index(inplace=True)

# %%
county
# Out:
#                   Name           State County_FIPS   Region  \
# 0     Abbeville County  South Carolina       45001    South
# 1        Acadia Parish       Louisiana       22001    South
# 2      Accomack County        Virginia       51001    South
# 3           Ada County           Idaho       16001     West
# 4         Adair County            Iowa       19001  Midwest
# ...                ...             ...         ...      ...
# 2818       Yuba County      California       06115     West
# 2819       Yuma County         Arizona       04027     West
# 2820       Yuma County        Colorado       08125     West
# 2821     Zapata County           Texas       48505    South
# 2822     Zavala County           Texas       48507    South
#
#                 Division       date StateCD  retail_and_recreation_PCT_CFB  \
# 0         South Atlantic 2020-11-21      SC                           31.0
# 1     West South Central 2020-11-21      LA                           29.0
# 2         South Atlantic 2020-11-21      VA                           65.0
# 3               Mountain 2020-11-21      ID                           19.0
# 4     West North Central 2020-11-20      IA                           47.0
# ...                  ...        ...     ...                            ...
# 2818             Pacific 2020-11-21      CA                           45.0
# 2819            Mountain 2020-11-21      AZ                           11.0
# 2820            Mountain 2020-11-20      CO                           21.0
# 2821  West South Central 2020-11-20      TX                           53.0
# 2822  West South Central 2020-11-20      TX                           18.0
#
#       grocery_and_pharmacy_PCT_CFB  parks_PCT_CFB  ...  \
# 0                             31.0            NaN  ...
# 1                             47.0            NaN  ...
# 2                             57.0            NaN  ...
# 3                             39.0          240.0  ...
# 4                             41.0            NaN  ...
# ...                            ...            ...  ...
# 2818                          37.0          127.0  ...
# 2819                          23.0           41.0  ...
# 2820                          14.0            NaN  ...
# 2821                          44.0            NaN  ...
# 2822                          33.0            NaN  ...
#
#       Deaths_New_14_PER_100K  Deaths_New_21_PER_100K  Deaths_New_28_PER_100K  \
# 0                  12.102630               12.102630               12.102630
# 1                   9.583593                9.583593                9.583593
# 2                   6.090134                6.090134                6.090134
# 3                   2.298232                2.298232                2.298232
# 4                  13.904338               13.904338               13.904338
# ...                      ...                     ...                     ...
# 2818                2.679385                2.679385                2.679385
# 2819                8.811392                8.811392                8.811392
# 2820                0.000000                0.000000                0.000000
# 2821               13.874436               13.874436               13.874436
# 2822               24.687294               24.687294               24.687294
#
#       Confirmed_New_PER_100K  Confirmed_New_RollingAvg_PER_100K  \
# 0                 209.778925                          48.986837
# 1                 236.395291                         116.372199
# 2                 167.478685                         100.052201
# 3                 119.737910                          76.071493
# 4                 264.182425                         145.002384
# ...                      ...                                ...
# 2818               92.438776                          38.851080
# 2819              215.879108                         120.772018
# 2820              158.274805                          60.766220
# 2821              180.367673                          47.569496
# 2822              419.684003                          77.588639
#
#       Deaths_New_RollingAvg_PER_100K  Deaths_New_7_RollingAvg_PER_100K  \
# 0                           2.881579                          2.881579
# 1                           3.194531                          3.194531
# 2                           1.740038                          1.740038
# 3                           0.689470                          0.689470
# 4                           3.972668                          3.972668
# ...                              ...                               ...
# 2818                        0.382769                          0.382769
# 2819                        3.496584                          3.496584
# 2820                        1.413168                          1.413168
# 2821                        2.973094                          2.973094
# 2822                        5.877927                          5.877927
#
#       Deaths_New_14_RollingAvg_PER_100K  Deaths_New_21_RollingAvg_PER_100K  \
# 0                              2.881579                           2.881579
# 1                              3.194531                           3.194531
# 2                              1.740038                           1.740038
# 3                              0.689470                           0.689470
# 4                              3.972668                           3.972668
# ...                                 ...                                ...
# 2818                           0.382769                           0.382769
# 2819                           3.496584                           3.496584
# 2820                           1.413168                           0.000000
# 2821                           2.973094                           2.973094
# 2822                           5.877927                           5.877927
#
#       Deaths_New_28_RollingAvg_PER_100K
# 0                              2.881579
# 1                              3.194531
# 2                              1.740038
# 3                              0.689470
# 4                              3.972668
# ...                                 ...
# 2818                           0.382769
# 2819                           3.496584
# 2820                           0.000000
# 2821                           2.973094
# 2822                           5.877927
#
# [2823 rows x 65 columns]

# %%
county_samp = county.sample(frac=.1)

# %%
county.PCT_Hisp_ACS.describe()
# Out:
# count    2823.000000
# mean        9.147540
# std        13.683896
# min         0.000000
# 25%         2.104021
# 50%         4.065384
# 75%         9.320412
# max        99.184800
# Name: PCT_Hisp_ACS, dtype: float64

# %%
county[county.Name.str.contains("Fairfax")]
# Out:
#              Name     State County_FIPS Region        Division       date  \
# 799  Fairfax city  Virginia       51600  South  South Atlantic 2020-11-21
#
#     StateCD  retail_and_recreation_PCT_CFB  grocery_and_pharmacy_PCT_CFB  \
# 799      VA                           14.0                          27.0
#
#      parks_PCT_CFB  ...  Deaths_New_14_PER_100K  Deaths_New_21_PER_100K  \
# 799          -26.0  ...                8.481764                8.481764
#
#      Deaths_New_28_PER_100K  Confirmed_New_PER_100K  \
# 799                8.481764               42.408821
#
#      Confirmed_New_RollingAvg_PER_100K  Deaths_New_RollingAvg_PER_100K  \
# 799                          15.751848                        1.817521
#
#      Deaths_New_7_RollingAvg_PER_100K  Deaths_New_14_RollingAvg_PER_100K  \
# 799                          1.817521                           1.817521
#
#      Deaths_New_21_RollingAvg_PER_100K  Deaths_New_28_RollingAvg_PER_100K
# 799                           1.817521                           1.817521
#
# [1 rows x 65 columns]

# %%
county.Deaths_PER_100K.describe()
# Out:
# count    2823.000000
# mean       70.593889
# std        61.713967
# min         0.000000
# 25%        27.738401
# 50%        55.007323
# 75%        95.858208
# max       519.210800
# Name: Deaths_PER_100K, dtype: float64

# %%
county[(county.Deaths_PER_100K >= county.Deaths_PER_100K.max()/2)]
# Out:
#                              Name         State County_FIPS     Region  \
# 44                   Allen Parish     Louisiana       22003      South
# 66                  Apache County       Arizona       04001       West
# 183              Bienville Parish     Louisiana       22013      South
# 184               Big Horn County       Montana       30003       West
# 219              Bottineau County  North Dakota       38009    Midwest
# 248                  Bronx County      New York       36005  Northeast
# 252                 Brooks County         Texas       48047      South
# 331                Cameron County         Texas       48061      South
# 339                Candler County       Georgia       13043      South
# 480                 Clarke County   Mississippi       28023      South
# 750                  Early County       Georgia       13099      South
# 752         East Feliciana Parish     Louisiana       22037      South
# 782                  Emporia city      Virginia       51595      South
# 790                  Essex County    New Jersey       34013  Northeast
# 870               Franklin Parish     Louisiana       22041      South
# 895                    Galax city      Virginia       51640      South
# 1039               Hancock County       Georgia       13141      South
# 1128                Holmes County   Mississippi       28051      South
# 1187                  Iron County      Michigan       26071    Midwest
# 1262               Jenkins County       Georgia       13165      South
# 1271               Johnson County       Georgia       13167      South
# 1334                 Kings County      New York       36047  Northeast
# 1390                  Lamb County         Texas       48279      South
# 1445               Leflore County   Mississippi       28083      South
# 1496          Little River County      Arkansas       05081      South
# 1523               Lowndes County       Alabama       01085      South
# 1638              Maverick County         Texas       48323      South
# 1657              McKinley County    New Mexico       35031       West
# 1831               Neshoba County   Mississippi       28099      South
# 1845                Newton County      Arkansas       05101      South
# 2000                 Perry County     Tennessee       47135      South
# 2119                Queens County      New York       36081  Northeast
# 2132              Randolph County       Georgia       13243      South
# 2148             Red River Parish     Louisiana       22081      South
# 2199             Roosevelt County       Montana       30085       West
# 2378  St. John the Baptist Parish     Louisiana       22095      South
# 2399                 Starr County         Texas       48427      South
# 2484               Terrell County       Georgia       13273      South
# 2536                Turner County       Georgia       13287      South
# 2537                Turner County  South Dakota       46125    Midwest
# 2551                 Union County       Florida       12125      South
# 2570                 Upson County       Georgia       13293      South
# 2574             Val Verde County         Texas       48465      South
# 2739                Wilcox County       Georgia       13315      South
# 2746               Willacy County         Texas       48489      South
#
#                 Division       date StateCD  retail_and_recreation_PCT_CFB  \
# 44    West South Central 2020-11-21      LA                           38.0
# 66              Mountain 2020-11-21      AZ                           34.0
# 183   West South Central 2020-11-20      LA                           25.0
# 184             Mountain 2020-11-21      MT                           -8.0
# 219   West North Central 2020-11-13      ND                           36.0
# 248      Middle Atlantic 2020-11-21      NY                           15.0
# 252   West South Central 2020-11-21      TX                           26.0
# 331   West South Central 2020-11-21      TX                           24.0
# 339       South Atlantic 2020-11-20      GA                           35.0
# 480   East South Central 2020-11-20      MS                           25.0
# 750       South Atlantic 2020-11-20      GA                           31.0
# 752   West South Central 2020-11-20      LA                           25.0
# 782       South Atlantic 2020-11-21      VA                           27.0
# 790      Middle Atlantic 2020-11-21      NJ                           11.0
# 870   West South Central 2020-11-21      LA                           32.0
# 895       South Atlantic 2020-11-21      VA                           28.0
# 1039      South Atlantic 2020-11-20      GA                            NaN
# 1128  East South Central 2020-11-20      MS                           27.0
# 1187  East North Central 2020-11-20      MI                           23.0
# 1262      South Atlantic 2020-11-20      GA                           31.0
# 1271      South Atlantic 2020-11-20      GA                            NaN
# 1334     Middle Atlantic 2020-11-21      NY                           11.0
# 1390  West South Central 2020-11-21      TX                           38.0
# 1445  East South Central 2020-11-21      MS                           46.0
# 1496  West South Central 2020-11-20      AR                           25.0
# 1523  East South Central 2020-11-21      AL                            NaN
# 1638  West South Central 2020-11-21      TX                           18.0
# 1657            Mountain 2020-11-21      NM                           30.0
# 1831  East South Central 2020-11-21      MS                           36.0
# 1845  West South Central 2020-11-19      AR                            NaN
# 2000  East South Central 2020-11-20      TN                          -59.0
# 2119     Middle Atlantic 2020-11-21      NY                            8.0
# 2132      South Atlantic 2020-11-20      GA                          -33.0
# 2148  West South Central 2020-11-20      LA                           18.0
# 2199            Mountain 2020-11-20      MT                           29.0
# 2378  West South Central 2020-11-21      LA                           66.0
# 2399  West South Central 2020-11-21      TX                           25.0
# 2484      South Atlantic 2020-11-20      GA                           26.0
# 2536      South Atlantic 2020-11-20      GA                           31.0
# 2537  West North Central 2020-11-20      SD                            NaN
# 2551      South Atlantic 2020-11-20      FL                           35.0
# 2570      South Atlantic 2020-11-21      GA                           20.0
# 2574  West South Central 2020-11-21      TX                           18.0
# 2739      South Atlantic 2020-11-20      GA                            NaN
# 2746  West South Central 2020-11-21      TX                           36.0
#
#       grocery_and_pharmacy_PCT_CFB  parks_PCT_CFB  ...  \
# 44                            40.0            NaN  ...
# 66                            46.0          180.0  ...
# 183                           26.0            NaN  ...
# 184                            9.0            NaN  ...
# 219                            NaN            NaN  ...
# 248                           29.0          105.0  ...
# 252                           33.0            NaN  ...
# 331                           27.0           30.0  ...
# 339                           19.0            NaN  ...
# 480                           34.0            NaN  ...
# 750                           37.0            NaN  ...
# 752                           32.0            NaN  ...
# 782                           28.0            NaN  ...
# 790                           29.0          160.0  ...
# 870                           39.0            NaN  ...
# 895                           59.0            NaN  ...
# 1039                           9.0            NaN  ...
# 1128                          26.0            NaN  ...
# 1187                          -9.0            NaN  ...
# 1262                          20.0            NaN  ...
# 1271                          46.0            NaN  ...
# 1334                          32.0          149.0  ...
# 1390                          41.0            NaN  ...
# 1445                          29.0            NaN  ...
# 1496                          37.0            NaN  ...
# 1523                           NaN            NaN  ...
# 1638                          24.0           68.0  ...
# 1657                          63.0            NaN  ...
# 1831                          43.0            NaN  ...
# 1845                           NaN            NaN  ...
# 2000                           NaN            NaN  ...
# 2119                          36.0          247.0  ...
# 2132                           NaN            NaN  ...
# 2148                           NaN            NaN  ...
# 2199                         -20.0            NaN  ...
# 2378                          52.0          -21.0  ...
# 2399                          26.0           54.0  ...
# 2484                          25.0            NaN  ...
# 2536                          66.0            NaN  ...
# 2537                           NaN            NaN  ...
# 2551                          16.0            NaN  ...
# 2570                          38.0            NaN  ...
# 2574                          25.0          138.0  ...
# 2739                          17.0            NaN  ...
# 2746                          41.0            NaN  ...
#
#       Deaths_New_14_PER_100K  Deaths_New_21_PER_100K  Deaths_New_28_PER_100K  \
# 44                 15.584213               15.584213               15.584213
# 66                 15.362699               15.362699               15.362699
# 183                28.972910               28.972910               28.972910
# 184                30.097818               30.097818               30.097818
# 219                 0.000000                0.000000                0.000000
# 248                61.201528               61.201528               61.201528
# 252                55.164805               55.164805               55.164805
# 331                22.608228               22.608228               22.608228
# 339                18.358730               18.358730               18.358730
# 480                18.646280               18.646280               18.646280
# 750                57.664584               57.664584               57.664584
# 752                15.342914               15.342914               15.342914
# 782                72.793449               72.793449               72.793449
# 790                30.859532               30.859532               30.859532
# 870                 9.809692                9.809692                9.809692
# 895                73.659399               73.659399               73.659399
# 1039              103.842160              103.842160              103.842160
# 1128               21.897411               21.897411               21.897411
# 1187               44.283057               44.283057               44.283057
# 1262               33.598387               33.598387               33.598387
# 1271               20.408163               20.408163               40.816327
# 1334               58.934675               58.934675               58.934675
# 1390               22.441652               22.441652               22.441652
# 1445                9.962475                9.962475                9.962475
# 1496               56.026893               56.026893               56.026893
# 1523               19.301293               19.301293               19.301293
# 1638               17.400080               17.400080               17.400080
# 1657                8.236215                8.236215                8.236215
# 1831               20.382512               20.382512               20.382512
# 1845               50.645733               50.645733               50.645733
# 2000               38.061406               38.061406               38.061406
# 2119               51.297835               51.297835               51.297835
# 2132               69.386622               69.386622               69.386622
# 2148               22.927892               22.927892               22.927892
# 2199              106.970940              106.970940              106.970940
# 2378               22.954206               22.954206               22.954206
# 2399               18.921476               18.921476               18.921476
# 2484               66.830029               66.830029               66.830029
# 2536               24.888004               24.888004               24.888004
# 2537               60.664887               60.664887               60.664887
# 2551               78.431373               78.431373               78.431373
# 2570               26.675813               26.675813               26.675813
# 2574               59.212676               59.212676               59.212676
# 2739               22.482014               22.482014               22.482014
# 2746               54.947571               54.947571               54.947571
#
#       Confirmed_New_PER_100K  Confirmed_New_RollingAvg_PER_100K  \
# 44                385.709277                         199.255297
# 66                202.508310                         104.147131
# 183               217.296827                          58.980567
# 184               797.592175                         236.482855
# 219               330.777327                         152.501235
# 248               101.796481                          80.090889
# 252               303.406427                          94.568237
# 331               605.662528                         230.739915
# 339               257.022214                          74.746256
# 480               161.601094                          59.490513
# 750               403.652090                          87.869843
# 752               869.431801                         168.772055
# 782               400.363967                          67.593917
# 790                86.081851                          62.700714
# 870               515.008829                         130.328765
# 895               324.101355                         122.064147
# 1039              496.134764                         118.676754
# 1128              191.602343                         103.230650
# 1187              247.985121                         126.523021
# 1262              279.986561                          81.596083
# 1271              561.224490                          88.921283
# 1334              101.057978                          54.901247
# 1390              388.988630                         183.807814
# 1445              116.228871                          51.709988
# 1496              256.122939                          84.612042
# 1523              308.820691                         140.623708
# 1638              622.922865                         164.555043
# 1657              291.012917                         148.644064
# 1831              122.295071                          81.530047
# 1845              113.952899                         130.231885
# 2000              570.921086                         219.306195
# 2119               86.436852                          70.131469
# 2132              791.007494                         184.370168
# 2148              275.134701                         104.813220
# 2199              534.854698                         306.904719
# 2378              358.085619                         102.966011
# 2399              561.337118                          93.481101
# 2484              423.256850                          84.333132
# 2536              572.424092                         111.996018
# 2537              570.249939                         183.727944
# 2551              418.300654                         197.945845
# 2570             1760.603636                         268.391340
# 2574              387.945116                         126.009241
# 2739              730.665468                         112.410072
# 2746              265.579926                         134.752376
#
#       Deaths_New_RollingAvg_PER_100K  Deaths_New_7_RollingAvg_PER_100K  \
# 44                          5.565790                          5.565790
# 66                          3.790796                          3.790796
# 183                         8.277974                          8.277974
# 184                         8.599377                          8.599377
# 219                         2.147905                          2.147905
# 248                         9.802842                          9.802842
# 252                         7.880686                         17.731544
# 331                         6.017528                          6.017528
# 339                         3.934013                          6.556689
# 480                         7.103345                          7.103345
# 750                        16.475596                         16.475596
# 752                        10.228609                          6.575535
# 782                        23.397894                         23.397894
# 790                         6.050539                          6.050539
# 870                         3.503461                          3.503461
# 895                        18.940988                         18.940988
# 1039                       28.020900                         28.020900
# 1128                        8.602554                          8.602554
# 1187                       10.121842                         10.121842
# 1262                        7.999616                          7.999616
# 1271                       10.204082                          8.746356
# 1334                        9.281222                          9.281222
# 1390                        6.411900                          7.480551
# 1445                        4.744036                          4.744036
# 1496                       10.290654                         11.434060
# 1523                        6.893319                          6.893319
# 1638                        5.220024                          5.220024
# 1657                        6.471311                          6.471311
# 1831                        5.338277                          5.338277
# 1845                       12.661433                         12.661433
# 2000                       12.687135                         12.687135
# 2119                        8.213761                          8.213761
# 2132                       21.807224                         21.807224
# 2148                        4.913120                          8.188533
# 2199                       17.828490                         17.828490
# 2378                        7.214179                          7.214179
# 2399                        6.532414                          6.532414
# 2484                       12.729529                         12.729529
# 2536                        8.888573                          8.888573
# 2537                       22.532672                         22.532672
# 2551                       14.005602                         14.005602
# 2570                        4.899639                          4.899639
# 2574                       10.792458                         10.792458
# 2739                        9.635149                          9.635149
# 2746                        9.157928                          9.157928
#
#       Deaths_New_14_RollingAvg_PER_100K  Deaths_New_21_RollingAvg_PER_100K  \
# 44                             5.565790                           5.565790
# 66                             3.790796                           3.790796
# 183                            8.277974                           8.277974
# 184                            8.599377                           8.599377
# 219                            0.000000                           2.147905
# 248                            9.802842                           9.802842
# 252                           17.731544                          17.731544
# 331                            6.017528                           6.017528
# 339                            6.556689                           6.556689
# 480                            7.103345                           6.215427
# 750                           16.475596                          16.475596
# 752                            4.383690                           4.383690
# 782                           23.397894                          23.397894
# 790                            6.050539                           6.050539
# 870                            3.503461                           3.503461
# 895                           18.940988                          18.940988
# 1039                          28.020900                          28.020900
# 1128                           8.602554                           8.602554
# 1187                          10.121842                          10.121842
# 1262                           7.999616                           7.999616
# 1271                           8.746356                           8.746356
# 1334                           9.281222                           9.281222
# 1390                           7.480551                           7.480551
# 1445                           4.744036                           4.744036
# 1496                          11.434060                          11.434060
# 1523                           6.893319                           6.893319
# 1638                           5.220024                           5.220024
# 1657                           6.471311                           6.471311
# 1831                           5.338277                           5.338277
# 1845                          12.661433                          12.661433
# 2000                          12.687135                          12.687135
# 2119                           8.213761                           8.213761
# 2132                          21.807224                          21.807224
# 2148                           8.188533                           8.188533
# 2199                          17.828490                          17.828490
# 2378                           7.214179                           7.214179
# 2399                           6.532414                           6.532414
# 2484                          12.729529                          12.729529
# 2536                           8.888573                           8.888573
# 2537                          22.532672                          22.532672
# 2551                          14.005602                          14.005602
# 2570                           4.899639                           4.899639
# 2574                          10.792458                          10.792458
# 2739                           9.635149                           9.635149
# 2746                           9.157928                           9.157928
#
#       Deaths_New_28_RollingAvg_PER_100K
# 44                             5.565790
# 66                             3.790796
# 183                            8.277974
# 184                            8.599377
# 219                            2.147905
# 248                            9.802842
# 252                           17.731544
# 331                            6.017528
# 339                            6.556689
# 480                            6.215427
# 750                           16.475596
# 752                            8.036765
# 782                           23.397894
# 790                            6.050539
# 870                            3.503461
# 895                           18.940988
# 1039                          28.020900
# 1128                           8.602554
# 1187                          10.121842
# 1262                           7.999616
# 1271                           8.746356
# 1334                           9.281222
# 1390                           7.480551
# 1445                           4.744036
# 1496                          11.434060
# 1523                           6.893319
# 1638                           5.220024
# 1657                           6.471311
# 1831                           5.338277
# 1845                          12.661433
# 2000                          12.687135
# 2119                           8.213761
# 2132                          21.807224
# 2148                           8.188533
# 2199                          17.828490
# 2378                           7.214179
# 2399                           6.532414
# 2484                          12.729529
# 2536                           8.888573
# 2537                          22.532672
# 2551                          14.005602
# 2570                           4.899639
# 2574                          10.792458
# 2739                           9.635149
# 2746                           9.157928
#
# [45 rows x 65 columns]

# %%
county[county.Metro.isna() == True]
# Out:
# Empty DataFrame
# Columns: [Name, State, County_FIPS, Region, Division, date, StateCD, retail_and_recreation_PCT_CFB, grocery_and_pharmacy_PCT_CFB, parks_PCT_CFB, transit_stations_PCT_CFB, workplaces_PCT_CFB, residential_PCT_CFB, retail_and_recreation_PCT_CFB_RollingAvg, grocery_and_pharmacy_PCT_CFB_RollingAvg, parks_PCT_CFB_RollingAvg, transit_stations_PCT_CFB_RollingAvg, workplaces_PCT_CFB_RollingAvg, residential_PCT_CFB_RollingAvg, HS_DIPLOMA_ONLY_2018, SOME_COLLEGE_2018, BACHELORS_PLUS_2018, Poverty_PCT_2018, UrbanCD, Median_Income_2018, Population_ACS, Population_Black_ACS, Population_Hisp_ACS, Population_Native_ACS, PCT_Black_ACS, PCT_Hisp_ACS, PCT_Native_ACS, UrbanCD_Description, Metro, Confirmed, Deaths, Deaths_Previous, Confirmed_Previous, Deaths_New, Deaths_New_7, Deaths_New_14, Deaths_New_21, Deaths_New_28, Confirmed_New, Confirmed_New_RollingAvg, Deaths_New_RollingAvg, Deaths_New_7_RollingAvg, Deaths_New_14_RollingAvg, Deaths_New_21_RollingAvg, Deaths_New_28_RollingAvg, Confirmed_PER_100K, Deaths_PER_100K, Deaths_Previous_PER_100K, Deaths_New_PER_100K, Deaths_New_7_PER_100K, Deaths_New_14_PER_100K, Deaths_New_21_PER_100K, Deaths_New_28_PER_100K, Confirmed_New_PER_100K, Confirmed_New_RollingAvg_PER_100K, Deaths_New_RollingAvg_PER_100K, Deaths_New_7_RollingAvg_PER_100K, Deaths_New_14_RollingAvg_PER_100K, Deaths_New_21_RollingAvg_PER_100K, Deaths_New_28_RollingAvg_PER_100K]
# Index: []
#
# [0 rows x 65 columns]

# %% [markdown]
# ## Longitudinal graphs by county

# %%
import random 


u_FIPS = list(combined_sub.County_FIPS.unique())

random_FIPS =  random.choice(u_FIPS)

# %%
bigh = combined_sub[combined_sub.County_FIPS == "04001"]
bigh
# Out:
#              date County_FIPS StateCD           Name  \
# 169071 2020-02-15       04001      AZ  Apache County
# 169072 2020-02-16       04001      AZ  Apache County
# 169073 2020-02-17       04001      AZ  Apache County
# 169074 2020-02-18       04001      AZ  Apache County
# 169075 2020-02-19       04001      AZ  Apache County
# ...           ...         ...     ...            ...
# 169341 2020-11-17       04001      AZ  Apache County
# 169342 2020-11-18       04001      AZ  Apache County
# 169343 2020-11-19       04001      AZ  Apache County
# 169344 2020-11-20       04001      AZ  Apache County
# 169345 2020-11-21       04001      AZ  Apache County
#
#         retail_and_recreation_PCT_CFB  grocery_and_pharmacy_PCT_CFB  \
# 169071                           16.0                           3.0
# 169072                           17.0                           5.0
# 169073                           -2.0                           3.0
# 169074                           -3.0                          -4.0
# 169075                            2.0                           1.0
# ...                               ...                           ...
# 169341                          -29.0                         -15.0
# 169342                          -20.0                         -14.0
# 169343                          -24.0                         -17.0
# 169344                          -19.0                         -15.0
# 169345                          -36.0                         -23.0
#
#         parks_PCT_CFB  transit_stations_PCT_CFB  workplaces_PCT_CFB  \
# 169071           26.0                      96.0                -2.0
# 169072           42.0                      18.0                -7.0
# 169073           32.0                       3.0               -48.0
# 169074           21.0                      10.0                 3.0
# 169075           10.0                      27.0                 2.0
# ...               ...                       ...                 ...
# 169341          -10.0                     -23.0               -31.0
# 169342          -16.0                     -12.0               -32.0
# 169343          -26.0                     -22.0               -35.0
# 169344          -20.0                     -12.0               -33.0
# 169345          -18.0                       4.0               -13.0
#
#         residential_PCT_CFB  ...  Deaths_New_28_PER_100K  \
# 169071                  NaN  ...                     0.0
# 169072                  NaN  ...                     0.0
# 169073                  5.0  ...                     0.0
# 169074                  1.0  ...                     0.0
# 169075                  0.0  ...                     0.0
# ...                     ...  ...                     ...
# 169341                 13.0  ...                     NaN
# 169342                 13.0  ...                     NaN
# 169343                 14.0  ...                     NaN
# 169344                 12.0  ...                     NaN
# 169345                 13.0  ...                     NaN
#
#         Confirmed_New_PER_100K  Confirmed_New_RollingAvg_PER_100K  \
# 169071                0.000000                           0.000000
# 169072                0.000000                           0.000000
# 169073                0.000000                           0.000000
# 169074                0.000000                           0.000000
# 169075                0.000000                           0.000000
# ...                        ...                                ...
# 169341              132.677858                          54.068721
# 169342              106.142287                          64.443531
# 169343               81.003324                          70.229483
# 169344              166.196475                          89.382978
# 169345              202.508310                         104.147131
#
#         Deaths_New_RollingAvg_PER_100K  Deaths_New_7_RollingAvg_PER_100K  \
# 169071                        0.000000                               0.0
# 169072                        0.000000                               0.0
# 169073                        0.000000                               0.0
# 169074                        0.000000                               0.0
# 169075                        0.000000                               0.0
# ...                                ...                               ...
# 169341                        0.598547                               NaN
# 169342                        0.399031                               NaN
# 169343                        0.399031                               NaN
# 169344                        0.997578                               NaN
# 169345                        0.798062                               NaN
#
#         Deaths_New_14_RollingAvg_PER_100K  Deaths_New_21_RollingAvg_PER_100K  \
# 169071                                0.0                                0.0
# 169072                                0.0                                0.0
# 169073                                0.0                                0.0
# 169074                                0.0                                0.0
# 169075                                0.0                                0.0
# ...                                   ...                                ...
# 169341                                NaN                                NaN
# 169342                                NaN                                NaN
# 169343                                NaN                                NaN
# 169344                                NaN                                NaN
# 169345                                NaN                                NaN
#
#         Deaths_New_28_RollingAvg_PER_100K  Region  Division
# 169071                                0.0    West  Mountain
# 169072                                0.0    West  Mountain
# 169073                                0.0    West  Mountain
# 169074                                0.0    West  Mountain
# 169075                                0.0    West  Mountain
# ...                                   ...     ...       ...
# 169341                                NaN    West  Mountain
# 169342                                NaN    West  Mountain
# 169343                                NaN    West  Mountain
# 169344                                NaN    West  Mountain
# 169345                                NaN    West  Mountain
#
# [275 rows x 65 columns]

# %%
plt.figure(figsize=(10,5)) 
sns.lineplot(x="date", y="Confirmed_New_RollingAvg_PER_100K", label="Deaths_PER_100K", data=bigh)
sns.lineplot(x="date", y="Deaths_New_RollingAvg_PER_100K", label="Deaths_PER_100K", data=bigh)
plt.legend(loc="upper left")
plt.show()

# %%
import random as random

list_counties = list(county[county.Population_ACS >= 1000000].County_FIPS.unique())
list_random = random.choices(list_counties, k=4)

# %%
for i in list_random:
    bigh = combined_sub[combined_sub.County_FIPS == i]
    bigh = bigh[bigh.date <= '2020-10-20']
    bigh = bigh[bigh.date >= '2020-06-01']
    name_county = bigh.Name.iloc[0]+' '+bigh.StateCD.iloc[0]
    plt.figure(figsize=(12,3)) 
    ax = sns.lineplot(x="date", y="Confirmed_New_RollingAvg_PER_100K", label="Confirmed", data=bigh)
    ax2 = ax.twinx()
    ax2 = sns.lineplot(x="date", y="Deaths_New_7_RollingAvg_PER_100K", label="Deaths", color='red', data=bigh)
    #ax2 = sns.lineplot(x="date", y="Deaths_New_7_RollingAvg_PER_100K", label="Deaths", color='orange', data=bigh)
    #ax2 = sns.lineplot(x="date", y="Deaths_New_21_RollingAvg_PER_100K", label="Deaths", color='green', data=bigh)
    plt.title("{x} - 2020-06 to 2020-10".format(x=name_county))
    fig.legend(loc="upper right")
    plt.show()

# %%
for i in list(combined_sub.Metro.unique()):
    dataframe = combined_sub[(combined_sub.date >= '2020-08-01') & (combined_sub.Metro == i)]
    dataframe = dataframe[dataframe.Deaths_New_14_RollingAvg_PER_100K > 0]
    dataframe = dataframe[dataframe.Confirmed_New_RollingAvg_PER_100K > 0]
    dataframe = dataframe.sample(frac=.1)
    #dataframe = dataframe.Confirmed_New_RollingAvg_PER_100K > 0
    sns.scatterplot(x="Deaths_New_14_RollingAvg_PER_100K",y="Confirmed_New_RollingAvg_PER_100K",label="{x}".format(x=i),data=dataframe)
    plt.show()

# %%
bigh[(bigh.date >= "2020-06-01") &(bigh.date <= "2020-07-01")][['date','Deaths','Deaths_New','Deaths_New_7','Deaths_New_7_RollingAvg','Deaths_New_7_RollingAvg_PER_100K']]

# %%
list_tup = []
for i in range(4,9):
    a = '2020-0{c}-01'.format(c=i)
    b = '2020-0{c}-01'.format(c=i+1)
    list_tup.append((a,b))

for i in range(10,11):
    a = '2020-{c}-01'.format(c=i)
    b = '2020-{c}-01'.format(c=i+1)
    list_tup.append((a,b))

# %% [markdown]
# ## Make the county level dataframe population - weighted

# %%
list_frame = []

from tqdm import tqdm

for i in tqdm(list(county.County_FIPS.unique())):
    frame = county[county.County_FIPS == i]
    frame['pop_1k'] = frame['Population_ACS']/1000 # Each row will represent 1k people
    frame['key'] = 'key'
    joinframe = pd.DataFrame(pd.Series(list(range(0,int(frame.pop_1k.max())))))
    joinframe['key'] = 'key'
    joinframe.columns = ['val','key']
    cartesian = frame.merge(joinframe, on="key")
    #frame_weighted = cartesian[cartesian.Deaths <= cartesian.val]
    list_frame.append(cartesian)

# %%
frame_concat = pd.concat(list_frame)

# %%
frame_concat

# %%
plt.figure(figsize=(16,9)) 
frame = frame_concat.sample(frac=.05)
frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro","Noncore_adjacent"])]
frame.sort_values(by="Metro", inplace=True)
#frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro"])]
frame = frame.sort_values(by="Metro")
#sns.violinplot(x="Metro", y="Deaths_PER_100K", label="work", data=frame, scale="count")
sns.boxplot(x="Metro", y="Deaths_PER_100K", data=frame,  boxprops={'facecolor':'None'}, fliersize=0)
sns.stripplot(x="Metro", y="Deaths_PER_100K", label="work", data=frame, size=2, alpha=.8, dodge=True, palette="viridis")
plt.show()

# %%
plt.figure(figsize=(18,9)) 
frame = frame_concat #.sample(frac=.25)
frame.sort_values(by="Division", inplace=True)
frame = frame.sort_values(by="Region")
sns.violinplot(x="Division", y="Deaths_PER_100K", label="work", data=frame)
#sns.boxplot(x="Division", y="Deaths_PER_100K", data=frame,  boxprops={'facecolor':'None'}, fliersize=0)
sns.swarmplot(x="Division", y="Deaths_PER_100K", label="work", data=frame, size=.5, alpha=.6, dodge=True, palette="viridis")
plt.show()

# %%
plt.figure(figsize=(18,9)) 
frame = frame_concat[frame_concat.Division == "New England"] #.sample(frac=.25)
frame.sort_values(by="Metro", inplace=True)
ax = sns.violinplot(x="Metro", y="Deaths_PER_100K", label="work", palette="viridis", alpha=.2, scale="count", data=frame)
#sns.boxplot(x="Metro", y="Deaths_PER_100K", data=frame,  boxprops={'facecolor':'None'}, fliersize=0)
ax = sns.swarmplot(x="Metro", y="Deaths_PER_100K", label="work", data=frame, size=2, dodge=True, palette="viridis")
plt.setp(ax.collections, alpha=.3)
plt.show()

# %%
import numpy as np
from matplotlib.patches import PathPatch

def adjust_box_widths(g, fac):
    """
    Adjust the widths of a seaborn-generated boxplot.
    """

    # iterating through Axes instances
    for ax in g.axes:

        # iterating through axes artists:
        for c in ax.get_children():

            # searching for PathPatches
            if isinstance(c, PathPatch):
                # getting current width of box:
                p = c.get_path()
                verts = p.vertices
                verts_sub = verts[:-1]
                xmin = np.min(verts_sub[:, 0])
                xmax = np.max(verts_sub[:, 0])
                xmid = 0.5*(xmin+xmax)
                xhalf = 0.5*(xmax - xmin)

                # setting new width of box
                xmin_new = xmid-fac*xhalf
                xmax_new = xmid+fac*xhalf
                verts_sub[verts_sub[:, 0] == xmin, 0] = xmin_new
                verts_sub[verts_sub[:, 0] == xmax, 0] = xmax_new

                # setting new width of median line
                for l in ax.lines:
                    if np.all(l.get_xdata() == [xmin, xmax]):
                        l.set_xdata([xmin_new, xmax_new])

# %%
def boxplot_with_violins(df, Yvar = "Deaths_PER_100K", group="Region"):
    frame = df
    frame = frame.sort_values(by=group)
    #frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro","Noncore_adjacent"])]

    fig = plt.figure(figsize=(9,6))

    ax = sns.boxplot(x=group, y=Yvar, data=frame, boxprops={'facecolor':'None'}, fliersize=0)
    ax = sns.violinplot(x=group, y=Yvar, scale="count", data=frame, inner="quart", despine=True)

    plt.setp(ax.collections, alpha=.4)
    plt.ylim(-10,frame["{Yvar}".format(Yvar=Yvar)].max()*.95)

    adjust_box_widths(fig, 0.9)
    
    fig.show()

# %%
def upper_limit(series):
    from scipy.stats import iqr
    import numpy as np
    Q3 = np.percentile(series, 75, interpolation = 'midpoint') 
    return int(Q3+(4*iqr(series)))

# %%
def boxplot_with_violins_grp(df, Yvar = "Deaths_PER_100K",  group="Region"):
    frame = df
    frame = frame.sort_values(by=group)
    #frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro","Noncore_adjacent"])]

    fig = plt.figure(figsize=(24,12))
    
    ax = sns.boxplot(x=group, y=Yvar, hue="Metro", data=frame, boxprops={'facecolor':'None'}, fliersize=0)
    ax = sns.violinplot(x=group, y=Yvar, hue="Metro", scale="count", data=frame, inner="quart", despine=True)

    #Make legend distinct 
    handles, labels = ax.get_legend_handles_labels()
    num_legend = len(df["{x}".format(x=group)].unique())
    plt.legend(handles[0:num_legend], labels[0:num_legend], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    plt.setp(ax.collections, alpha=.4)
    
    #plt.ylim(-10,frame["{Yvar}".format(Yvar=Yvar)].max()*.75)
   
    upper_limit_number = upper_limit(frame["{Yvar}".format(Yvar=Yvar)])
    plt.ylim(-10,upper_limit_number)
    adjust_box_widths(fig, 0.8)
    #plt.legend()
    fig.show()

# %%
boxplot_with_violins_grp(frame_concat,Yvar = "Confirmed_PER_100K")

# %%
frame = frame_concat.sample(frac=.1)
#frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro","Noncore_adjacent"])]
#plt.figure(figsize=(22,9)) 

fig = plt.figure(figsize=(22, 9))

ax = sns.boxplot(x="Region", y="Deaths_PER_100K", data=frame, boxprops={'facecolor':'None'}, fliersize=0)
ax = sns.swarmplot(x="Region", y="Deaths_PER_100K",  alpha=.95, data=frame, size=.75, dodge=True)
#plt.setp(ax.collections, alpha=.9)
plt.ylim(-10,frame.Deaths_PER_100K.max()*1.1)

adjust_box_widths(fig, 0.9)

# %%
frame_concat.columns

# %%
frame = frame_concat
frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro","Noncore_adjacent"])]
#plt.figure(figsize=(22,9)) 

fig = plt.figure(figsize=(22, 9))

#ax = sns.boxplot(x="Division", y="Confirmed_New_RollingAvg_PER_100K", hue="Metro", data=frame, fliersize=0)
ax = sns.violinplot(x="Division", y="Confirmed_New_RollingAvg_PER_100K",  hue="Metro", scale="count", data=frame, inner="quart", size=2, dodge=True, despine=True)
plt.setp(ax.collections, alpha=.4)
plt.ylim(-10,150)

adjust_box_widths(fig, 0.9)

# %%
pop = pd.DataFrame(frame.groupby(["Division"])["Population_ACS"].sum())

# %%
pop['pop'] = pop.Population_ACS/1000000

# %%
1.553625e+04

# %%
frame = frame_concat.sample(frac=.1)
frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro"])]
#plt.figure(figsize=(22,9)) 

fig = plt.figure(figsize=(22, 9))

ax = sns.boxplot(x="Region", y="Deaths_New_7_RollingAvg_PER_100K", hue="Metro", data=frame, boxprops={'facecolor':'None'}, fliersize=0)
ax = sns.violinplot(x="Region", y="Deaths_New_7_RollingAvg_PER_100K",  hue="Metro", scale="count", data=frame, inner="quart", size=2, dodge=True, despine=True)
plt.setp(ax.collections, alpha=.4)
plt.ylim(-1,2.5)

adjust_box_widths(fig, 0.9)

# %%
sns.distplot(frame.Deaths_New_7_RollingAvg_PER_100K)

# %%
combined_sub['week_of_yr'] = combined_sub.date.dt.week

# %%
cols = list(combined_sub.columns)

list_df = [] 

for i in tqdm(range(12,combined_sub.week_of_yr.max())):
    county = combined_sub[(combined_sub.week_of_yr == i)]
    date = county.date.max()
    county = county.groupby(["County_FIPS","Metro","Division","StateCD"])[cols].mean()
    county = pd.DataFrame(county)
    county['date'] = date
    county.reset_index(inplace=True)
    list_df.append(county)

# %%
list_df[2] #.Metro

# %%
def explode_df_pop_weight(df):
    list_frame  = []
    for i in tqdm(list(df.County_FIPS.unique())):
        frame = df[df.County_FIPS == i]
        frame['pop_1k'] = frame['Population_ACS']/1000 # Each row will represent 1k people
        frame['key'] = 'key'
        joinframe = pd.DataFrame(pd.Series(list(range(0,int(frame.pop_1k.max())))))
        joinframe['key'] = 'key'
        joinframe.columns = ['val','key']
        cartesian = frame.merge(joinframe, on="key")
        list_frame.append(cartesian)
    exploded_frame = pd.concat(list_frame)
    return exploded_frame

# %%
exp = explode_df_pop_weight(list_df[2])

# %%
list_exploded_df = [explode_df_dateweight(i) for i in list_df]

# %%
colslist = list(list_exploded_df[2].columns)
Yvarlist = [i for i in colslist if "RollingAvg" in i]

# %%
colslist

# %%
Yvar_list = [
 #'retail_and_recreation_PCT_CFB_RollingAvg',
 #'grocery_and_pharmacy_PCT_CFB_RollingAvg',
 #'parks_PCT_CFB_RollingAvg',
 #'transit_stations_PCT_CFB_RollingAvg',
 'workplaces_PCT_CFB_RollingAvg',
 'residential_PCT_CFB_RollingAvg',
 'Confirmed_New_RollingAvg_PER_100K',
 'Deaths_New_RollingAvg_PER_100K']

# %%
grouplist = ['Metro','Region']

# %%
import os
os.getcwd()
os.chdir("/Users/philip.ballentine/Documents/grphimg")

# %%
#conda install -c conda-forge imageio

# %%
def gif_from_images(animated_filename="movie.gif"):
    """ goes into the working directory (set earlier) and combined all images into an animated gif"""
    import imageio
    image_list = sorted(os.listdir(os.getcwd()))
    image_list_sub = [i for i in image_list if '2020' in i]
    images = []
    for filename in image_list_sub:
        images.append(imageio.imread(filename))
    imageio.mimsave(animated_filename+'.gif', images, duration=.5)

# %%
combined_sub.columns

# %%
combined_sub['retail_and_recreation_PCT_CFB'].quantile(.10)

# %%
combined_sub['retail_and_recreation_PCT_CFB'].quantile(.9)

# %%
def loop_for_gif_by_metro(Yvar="Deaths_PER_100K", group="Metro"):
    
    ## Creating file structure
    import os 
    foldername = "{Yvar}_by_{group}".format(Yvar=Yvar, group=group)
    try:
        os.chdir("/Users/philip.ballentine/Documents/grphimg/{foldername}".format(foldername=foldername))
    except:
        os.mkdir("/Users/philip.ballentine/Documents/grphimg/{foldername}".format(foldername=foldername))
        os.chdir("/Users/philip.ballentine/Documents/grphimg/{foldername}".format(foldername=foldername))
    
    ## Iterating through dataframes and creating the plots
    for i in tqdm(random.choices(list_exploded_df, k= 3)):
    #for i in tqdm(list_exploded_df): 
        frame = i
        frame = frame.sort_values(by='{group}'.format(group=group))
        fig = plt.figure(figsize=(9, 6))
        #frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro"])]
        ax = sns.boxplot(x=group, y=Yvar, data=frame, boxprops={'facecolor':'None'}, fliersize=0)
        ax = sns.violinplot(x=group, y=Yvar, scale="count", data=frame, inner="quart", dodge=True, despine=True)

        plt.setp(ax.collections, alpha=.4)
        ## Setting the Y-Lims
        #if "PCT" in Yvar:
            #plt.ylim(combined_sub['{Yvar}'.format(Yvar=Yvar)].min(),combined_sub['{Yvar}'.format(Yvar=Yvar)].max())
            #quant10 = combined_sub['{Yvar}'.format(Yvar=Yvar)].quantile(.1)
            #quant90 = combined_sub['{Yvar}'.format(Yvar=Yvar)].quantile(.9)
            #plt.ylim(quant10,quant90)
        #if "Confirmed" in Yvar: 
            #stdev = combined_sub['{Yvar}'.format(Yvar=Yvar)].std()
            #mean = combined_sub['{Yvar}'.format(Yvar=Yvar)].mean()
            #limits = ((mean-(stdev*3)),(mean+(stdev*3)))
            #quant10 = combined_sub['{Yvar}'.format(Yvar=Yvar)].quantile(.1)
            #quant90 = combined_sub['{Yvar}'.format(Yvar=Yvar)].quantile(.9)
            #plt.ylim(quant10,quant90)
       # else: 
            #stdev = combined_sub['{Yvar}'.format(Yvar=Yvar)].std()
            #plt.ylim(-1,combined_sub['{Yvar}'.format(Yvar=Yvar)].mean()+(5*stdev))
        
        ## Titles and file saving
        datestr = str(i.date.max())[0:11]
        plt.title("{datestr} - {Yvar} by {group}, Population Weighted".format(datestr=datestr, Yvar=Yvar, group=group))
        plt.tight_layout()
        plt.savefig("{datestr}.png".format(datestr=datestr), dpi=300)
        #print("{datestr}.png has been created in {foldername}".format(datestr=datestr, foldername=foldername))

## Animated GIF creation
    gif_from_images(animated_filename=foldername)

# %%
loop_for_gif_by_metro("retail_and_recreation_PCT_CFB", group="Metro")

# %%
all_combo_list = []
for i in Yvar_list:
    for x in grouplist:
        all_combo_list.append((i,x))

# %%
all_combo_list

# %%
for i in all_combo_list:
    try:
        loop_for_gif_by_metro(Yvar=i[0], group=i[1])
    except:
        print("failure for {x}".format(x=str(i)))
        continue
