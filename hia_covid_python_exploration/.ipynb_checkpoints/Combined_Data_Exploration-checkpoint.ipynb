# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Mobility Data

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
# keep FIPS as string to preserve leading zeroes

# %%
combined = pd.read_csv(r"/Users/philip.ballentine/Documents/hia_covid_repo/hia_covid_data_assets/hia_covid_combined.csv", dtype={'County_FIPS': 'str'} )

# %%
combined.Name = combined.locationcol

# %%
colsub = [i for i in combined.columns if "Death" in i]

# %%
combined[(combined.Date > '2020-11-15') & (combined.Name.str.contains("Garfield")) & (combined.Name.str.contains("Nebrask"))][colsub]
# Out:
#         Deaths  Deaths_Previous  Deaths_New  Deaths_New_7  Deaths_New_14  \
# 531811       0          0.00000     0.00000       1.00000        0.00000
# 531812       0          0.00000     0.00000       0.00000        1.00000
# 531813       0          0.00000     0.00000       0.00000        0.00000
# 531814       0          0.00000     0.00000       2.00000            nan
# 531815       0          0.00000     0.00000       0.00000            nan
# 531816       0          0.00000     0.00000       0.00000            nan
# 531817       0          0.00000     0.00000       0.00000            nan
# 531818       1          0.00000     1.00000       0.00000            nan
# 531819       1          1.00000     0.00000       1.00000            nan
# 531820       1          1.00000     0.00000       0.00000            nan
# 531821       3          1.00000     2.00000           nan            nan
# 531822       3          3.00000     0.00000           nan            nan
# 531823       3          3.00000     0.00000           nan            nan
# 531824       3          3.00000     0.00000           nan            nan
# 531825       3          3.00000     0.00000           nan            nan
# 531826       4          3.00000     1.00000           nan            nan
# 531827       4          4.00000     0.00000           nan            nan
#
#         Deaths_New_21  Deaths_New_28  Deaths_New_RollingAvg  \
# 531811            nan            nan                0.00000
# 531812            nan            nan                0.00000
# 531813            nan            nan                0.00000
# 531814            nan            nan                0.00000
# 531815            nan            nan                0.00000
# 531816            nan            nan                0.00000
# 531817            nan            nan                0.00000
# 531818            nan            nan                0.14286
# 531819            nan            nan                0.14286
# 531820            nan            nan                0.14286
# 531821            nan            nan                0.42857
# 531822            nan            nan                0.42857
# 531823            nan            nan                0.42857
# 531824            nan            nan                0.42857
# 531825            nan            nan                0.28571
# 531826            nan            nan                0.42857
# 531827            nan            nan                0.42857
#
#         Deaths_New_7_RollingAvg  Deaths_New_14_RollingAvg  ...  \
# 531811                  0.14286                   0.28571  ...
# 531812                  0.14286                   0.42857  ...
# 531813                  0.14286                   0.42857  ...
# 531814                  0.42857                       nan  ...
# 531815                  0.42857                       nan  ...
# 531816                  0.42857                       nan  ...
# 531817                  0.42857                       nan  ...
# 531818                  0.28571                       nan  ...
# 531819                  0.42857                       nan  ...
# 531820                  0.42857                       nan  ...
# 531821                      nan                       nan  ...
# 531822                      nan                       nan  ...
# 531823                      nan                       nan  ...
# 531824                      nan                       nan  ...
# 531825                      nan                       nan  ...
# 531826                      nan                       nan  ...
# 531827                      nan                       nan  ...
#
#         Deaths_New_PER_100K  Deaths_New_7_PER_100K  Deaths_New_14_PER_100K  \
# 531811              0.00000               51.07252                 0.00000
# 531812              0.00000                0.00000                51.07252
# 531813              0.00000                0.00000                 0.00000
# 531814              0.00000              102.14505                     nan
# 531815              0.00000                0.00000                     nan
# 531816              0.00000                0.00000                     nan
# 531817              0.00000                0.00000                     nan
# 531818             51.07252                0.00000                     nan
# 531819              0.00000               51.07252                     nan
# 531820              0.00000                0.00000                     nan
# 531821            102.14505                    nan                     nan
# 531822              0.00000                    nan                     nan
# 531823              0.00000                    nan                     nan
# 531824              0.00000                    nan                     nan
# 531825              0.00000                    nan                     nan
# 531826             51.07252                    nan                     nan
# 531827              0.00000                    nan                     nan
#
#         Deaths_New_21_PER_100K  Deaths_New_28_PER_100K  \
# 531811                     nan                     nan
# 531812                     nan                     nan
# 531813                     nan                     nan
# 531814                     nan                     nan
# 531815                     nan                     nan
# 531816                     nan                     nan
# 531817                     nan                     nan
# 531818                     nan                     nan
# 531819                     nan                     nan
# 531820                     nan                     nan
# 531821                     nan                     nan
# 531822                     nan                     nan
# 531823                     nan                     nan
# 531824                     nan                     nan
# 531825                     nan                     nan
# 531826                     nan                     nan
# 531827                     nan                     nan
#
#         Deaths_New_RollingAvg_PER_100K  Deaths_New_7_RollingAvg_PER_100K  \
# 531811                         0.00000                           7.29607
# 531812                         0.00000                           7.29607
# 531813                         0.00000                           7.29607
# 531814                         0.00000                          21.88822
# 531815                         0.00000                          21.88822
# 531816                         0.00000                          21.88822
# 531817                         0.00000                          21.88822
# 531818                         7.29607                          14.59215
# 531819                         7.29607                          21.88822
# 531820                         7.29607                          21.88822
# 531821                        21.88822                               nan
# 531822                        21.88822                               nan
# 531823                        21.88822                               nan
# 531824                        21.88822                               nan
# 531825                        14.59215                               nan
# 531826                        21.88822                               nan
# 531827                        21.88822                               nan
#
#         Deaths_New_14_RollingAvg_PER_100K  Deaths_New_21_RollingAvg_PER_100K  \
# 531811                           14.59215                                nan
# 531812                           21.88822                                nan
# 531813                           21.88822                                nan
# 531814                                nan                                nan
# 531815                                nan                                nan
# 531816                                nan                                nan
# 531817                                nan                                nan
# 531818                                nan                                nan
# 531819                                nan                                nan
# 531820                                nan                                nan
# 531821                                nan                                nan
# 531822                                nan                                nan
# 531823                                nan                                nan
# 531824                                nan                                nan
# 531825                                nan                                nan
# 531826                                nan                                nan
# 531827                                nan                                nan
#
#         Deaths_New_28_RollingAvg_PER_100K
# 531811                                nan
# 531812                                nan
# 531813                                nan
# 531814                                nan
# 531815                                nan
# 531816                                nan
# 531817                                nan
# 531818                                nan
# 531819                                nan
# 531820                                nan
# 531821                                nan
# 531822                                nan
# 531823                                nan
# 531824                                nan
# 531825                                nan
# 531826                                nan
# 531827                                nan
#
# [17 rows x 24 columns]

# %%
sns.displot(combined.Date, height=4, aspect=2.6)

# %%
cols_subset = [i for i in combined.columns if ("PER_100K" in i and "Rolling" in i) 
               or ("ACS" in i and "PCT" in i) or i == "Deaths_PER_100K"]
combined_sub2 = combined[cols_subset]

sns.set(rc={'figure.figsize':(11,8)})
corr = combined_sub2.corr()
sns.heatmap(corr, annot=True, fmt='.2f')
plt.show()

# %%
cols_subset = [i for i in combined.columns if ("CFB" in i and "Rolling" in i)
                          or i == "Deaths_PER_100K"]

combined_sub2 = combined[cols_subset]

sns.set(rc={'figure.figsize':(11,8)})
corr = combined_sub2.corr()
sns.heatmap(corr, annot=True, fmt='.2f')
plt.show()

# %%
combined.Deaths.isna().value_counts()
# Out:
# False    989080
# Name: Deaths, dtype: int64

# %%
combined['Date'] = combined['Date'].astype("datetime64")

# %%
combined_sub = combined.drop(columns=['Unnamed: 0','Country/Region'])

# %%
combined_sub.Name.isna().value_counts()
# Out:
# False    989080
# Name: Name, dtype: int64

# %%
combined_sub.locationcol.isna().value_counts()
# Out:
# False    989080
# Name: locationcol, dtype: int64

# %%
combined_sub['Date'].isna().value_counts()
# Out:
# False    989080
# Name: Date, dtype: int64

# %%
combined_sub['State Code'].isna().value_counts()
# Out:
# False    989080
# Name: State Code, dtype: int64

# %% [markdown]
# ## Examine per-county distributions

# %%
list_cols = list(combined_sub.columns)

list_cols = [i for i in list_cols if i not in ["Date","locationcol","State","State Code","Name","County_FIPS","Region","Division","Metro"]]
list_cols
# Out:
# ['retail_and_recreation_PCT_CFB',
#  'grocery_and_pharmacy_PCT_CFB',
#  'parks_PCT_CFB',
#  'transit_stations_PCT_CFB',
#  'workplaces_PCT_CFB',
#  'residential_PCT_CFB',
#  'retail_and_recreation_PCT_CFB_RollingAvg',
#  'grocery_and_pharmacy_PCT_CFB_RollingAvg',
#  'parks_PCT_CFB_RollingAvg',
#  'transit_stations_PCT_CFB_RollingAvg',
#  'workplaces_PCT_CFB_RollingAvg',
#  'residential_PCT_CFB_RollingAvg',
#  'HS_DIPLOMA_ONLY_2018',
#  'SOME_COLLEGE_2018',
#  'BACHELORS_PLUS_2018',
#  'Poverty_PCT_2018',
#  'UrbanCD',
#  'Median_Income_2018',
#  'Population_ACS',
#  'Population_Black_ACS',
#  'Population_Hisp_ACS',
#  'Population_Native_ACS',
#  'PCT_Black_ACS',
#  'PCT_Hisp_ACS',
#  'PCT_Native_ACS',
#  'UrbanCD_Description',
#  'Confirmed',
#  'Deaths',
#  'Deaths_Previous',
#  'Confirmed_Previous',
#  'Deaths_New',
#  'Deaths_New_7',
#  'Deaths_New_14',
#  'Deaths_New_21',
#  'Deaths_New_28',
#  'Confirmed_New',
#  'Confirmed_New_RollingAvg',
#  'Deaths_New_RollingAvg',
#  'Deaths_New_7_RollingAvg',
#  'Deaths_New_14_RollingAvg',
#  'Deaths_New_21_RollingAvg',
#  'Deaths_New_28_RollingAvg',
#  'Confirmed_PER_100K',
#  'Deaths_PER_100K',
#  'Deaths_Previous_PER_100K',
#  'Deaths_New_PER_100K',
#  'Deaths_New_7_PER_100K',
#  'Deaths_New_14_PER_100K',
#  'Deaths_New_21_PER_100K',
#  'Deaths_New_28_PER_100K',
#  'Confirmed_New_PER_100K',
#  'Confirmed_New_RollingAvg_PER_100K',
#  'Deaths_New_RollingAvg_PER_100K',
#  'Deaths_New_7_RollingAvg_PER_100K',
#  'Deaths_New_14_RollingAvg_PER_100K',
#  'Deaths_New_21_RollingAvg_PER_100K',
#  'Deaths_New_28_RollingAvg_PER_100K']

# %%
#county_desc = combined_sub[["locationcol","County_FIPS","State Code","Region","Division","Metro"]].drop_duplicates()
#county = pd.DataFrame(county) 
#county.reset_index(inplace=True)

county = combined_sub.groupby(["Name","County_FIPS","State Code","Region","Division","Metro"])[list_cols].mean()

# %%
county.reset_index(inplace=True)

# %%
county_samp = county.sample(frac=.1)

# %%
county.PCT_Hisp_ACS.describe()
# Out:
# count   3130.00000
# mean       9.13399
# std       13.73332
# min        0.00000
# 25%        2.04563
# 50%        3.97820
# 75%        9.28364
# max       99.18480
# Name: PCT_Hisp_ACS, dtype: float64

# %%
county[county.Name.str.contains("Fairfax")]
# Out:
#                       Name County_FIPS State Code Region        Division  \
# 893  Fairfax City|Virginia       51600         VA  South  South Atlantic
#
#            Metro  retail_and_recreation_PCT_CFB  grocery_and_pharmacy_PCT_CFB  \
# 893  Large_metro                      -32.48921                      -9.32576
#
#      parks_PCT_CFB  transit_stations_PCT_CFB  ...  Deaths_New_14_PER_100K  \
# 893      -39.83333                       nan  ...                 0.12638
#
#      Deaths_New_21_PER_100K  Deaths_New_28_PER_100K  Confirmed_New_PER_100K  \
# 893                 0.12938                 0.13253                 2.85418
#
#      Confirmed_New_RollingAvg_PER_100K  Deaths_New_RollingAvg_PER_100K  \
# 893                            2.89784                         0.12352
#
#      Deaths_New_7_RollingAvg_PER_100K  Deaths_New_14_RollingAvg_PER_100K  \
# 893                           0.12597                            0.12895
#
#      Deaths_New_21_RollingAvg_PER_100K  Deaths_New_28_RollingAvg_PER_100K
# 893                            0.13207                            0.13535
#
# [1 rows x 62 columns]

# %%
county.Deaths_PER_100K.describe()
# Out:
# count   3130.00000
# mean      22.94342
# std       27.26631
# min        0.00000
# 25%        6.11656
# 50%       14.08615
# 75%       29.42596
# max      268.80660
# Name: Deaths_PER_100K, dtype: float64

# %%
county[(county.Deaths_PER_100K >= county.Deaths_PER_100K.mean()*10)]
# Out:
#                   Name County_FIPS State Code     Region         Division  \
# 274     Bronx|New York       36005         NY  Northeast  Middle Atlantic
# 1168   Hancock|Georgia       13141         GA      South   South Atlantic
# 2371  Randolph|Georgia       13243         GA      South   South Atlantic
# 2764   Terrell|Georgia       13273         GA      South   South Atlantic
#
#                  Metro  retail_and_recreation_PCT_CFB  \
# 274        Large_metro                      -25.73702
# 1168      Micropolitan                            nan
# 2371  Noncore_adjacent                      -43.33333
# 2764     Smaller_metro                       -9.29412
#
#       grocery_and_pharmacy_PCT_CFB  parks_PCT_CFB  transit_stations_PCT_CFB  \
# 274                       -7.05536       -4.73702                 -31.77509
# 1168                       0.57143            nan                       nan
# 2371                           nan            nan                       nan
# 2764                      -1.07843            nan                       nan
#
#       ...  Deaths_New_14_PER_100K  Deaths_New_21_PER_100K  \
# 274   ...                 1.14269                 1.16980
# 1168  ...                 1.75745                 1.79915
# 2371  ...                 1.37854                 1.41125
# 2764  ...                 1.21710                 1.24598
#
#       Deaths_New_28_PER_100K  Confirmed_New_PER_100K  \
# 274                  1.19823                14.17493
# 1168                 1.84288                19.52306
# 2371                 1.44555                16.30035
# 2764                 1.27627                14.39144
#
#       Confirmed_New_RollingAvg_PER_100K  Deaths_New_RollingAvg_PER_100K  \
# 274                            14.14232                         1.11718
# 1168                           18.80862                         1.71763
# 2371                           16.55912                         1.36014
# 2764                           14.35162                         1.18953
#
#       Deaths_New_7_RollingAvg_PER_100K  Deaths_New_14_RollingAvg_PER_100K  \
# 274                            1.13930                            1.16625
# 1168                           1.75165                            1.79307
# 2371                           1.38708                            1.41988
# 2764                           1.21309                            1.24177
#
#       Deaths_New_21_RollingAvg_PER_100K  Deaths_New_28_RollingAvg_PER_100K
# 274                             1.19450                            1.22415
# 1168                            1.83650                            1.88209
# 2371                            1.45427                            1.49037
# 2764                            1.27185                            1.30342
#
# [4 rows x 62 columns]

# %%
county[county.Metro.isna() == True]
# Out:
# Empty DataFrame
# Columns: [Name, County_FIPS, State Code, Region, Division, Metro, retail_and_recreation_PCT_CFB, grocery_and_pharmacy_PCT_CFB, parks_PCT_CFB, transit_stations_PCT_CFB, workplaces_PCT_CFB, residential_PCT_CFB, retail_and_recreation_PCT_CFB_RollingAvg, grocery_and_pharmacy_PCT_CFB_RollingAvg, parks_PCT_CFB_RollingAvg, transit_stations_PCT_CFB_RollingAvg, workplaces_PCT_CFB_RollingAvg, residential_PCT_CFB_RollingAvg, HS_DIPLOMA_ONLY_2018, SOME_COLLEGE_2018, BACHELORS_PLUS_2018, Poverty_PCT_2018, UrbanCD, Median_Income_2018, Population_ACS, Population_Black_ACS, Population_Hisp_ACS, Population_Native_ACS, PCT_Black_ACS, PCT_Hisp_ACS, PCT_Native_ACS, Confirmed, Deaths, Deaths_Previous, Confirmed_Previous, Deaths_New, Deaths_New_7, Deaths_New_14, Deaths_New_21, Deaths_New_28, Confirmed_New, Confirmed_New_RollingAvg, Deaths_New_RollingAvg, Deaths_New_7_RollingAvg, Deaths_New_14_RollingAvg, Deaths_New_21_RollingAvg, Deaths_New_28_RollingAvg, Confirmed_PER_100K, Deaths_PER_100K, Deaths_Previous_PER_100K, Deaths_New_PER_100K, Deaths_New_7_PER_100K, Deaths_New_14_PER_100K, Deaths_New_21_PER_100K, Deaths_New_28_PER_100K, Confirmed_New_PER_100K, Confirmed_New_RollingAvg_PER_100K, Deaths_New_RollingAvg_PER_100K, Deaths_New_7_RollingAvg_PER_100K, Deaths_New_14_RollingAvg_PER_100K, Deaths_New_21_RollingAvg_PER_100K, Deaths_New_28_RollingAvg_PER_100K]
# Index: []
#
# [0 rows x 62 columns]

# %% [markdown]
# ## Longitudinal graphs by county

# %%
import random

# %%
bigh = combined_sub[combined_sub.County_FIPS == "04001"]
bigh.head(40)
# Out:
#             Date County_FIPS State Code            Name  \
# 30020 2020-01-22       04001         AZ  Apache|Arizona
# 30021 2020-01-23       04001         AZ  Apache|Arizona
# 30022 2020-01-24       04001         AZ  Apache|Arizona
# 30023 2020-01-25       04001         AZ  Apache|Arizona
# 30024 2020-01-26       04001         AZ  Apache|Arizona
# 30025 2020-01-27       04001         AZ  Apache|Arizona
# 30026 2020-01-28       04001         AZ  Apache|Arizona
# 30027 2020-01-29       04001         AZ  Apache|Arizona
# 30028 2020-01-30       04001         AZ  Apache|Arizona
# 30029 2020-01-31       04001         AZ  Apache|Arizona
# 30030 2020-02-01       04001         AZ  Apache|Arizona
# 30031 2020-02-02       04001         AZ  Apache|Arizona
# 30032 2020-02-03       04001         AZ  Apache|Arizona
# 30033 2020-02-04       04001         AZ  Apache|Arizona
# 30034 2020-02-05       04001         AZ  Apache|Arizona
# 30035 2020-02-06       04001         AZ  Apache|Arizona
# 30036 2020-02-07       04001         AZ  Apache|Arizona
# 30037 2020-02-08       04001         AZ  Apache|Arizona
# 30038 2020-02-09       04001         AZ  Apache|Arizona
# 30039 2020-02-10       04001         AZ  Apache|Arizona
# 30040 2020-02-11       04001         AZ  Apache|Arizona
# 30041 2020-02-12       04001         AZ  Apache|Arizona
# 30042 2020-02-13       04001         AZ  Apache|Arizona
# 30043 2020-02-14       04001         AZ  Apache|Arizona
# 30044 2020-02-15       04001         AZ  Apache|Arizona
# 30045 2020-02-16       04001         AZ  Apache|Arizona
# 30046 2020-02-17       04001         AZ  Apache|Arizona
# 30047 2020-02-18       04001         AZ  Apache|Arizona
# 30048 2020-02-19       04001         AZ  Apache|Arizona
# 30049 2020-02-20       04001         AZ  Apache|Arizona
# 30050 2020-02-21       04001         AZ  Apache|Arizona
# 30051 2020-02-22       04001         AZ  Apache|Arizona
# 30052 2020-02-23       04001         AZ  Apache|Arizona
# 30053 2020-02-24       04001         AZ  Apache|Arizona
# 30054 2020-02-25       04001         AZ  Apache|Arizona
# 30055 2020-02-26       04001         AZ  Apache|Arizona
# 30056 2020-02-27       04001         AZ  Apache|Arizona
# 30057 2020-02-28       04001         AZ  Apache|Arizona
# 30058 2020-02-29       04001         AZ  Apache|Arizona
# 30059 2020-03-01       04001         AZ  Apache|Arizona
#
#        retail_and_recreation_PCT_CFB  grocery_and_pharmacy_PCT_CFB  \
# 30020                            nan                           nan
# 30021                            nan                           nan
# 30022                            nan                           nan
# 30023                            nan                           nan
# 30024                            nan                           nan
# 30025                            nan                           nan
# 30026                            nan                           nan
# 30027                            nan                           nan
# 30028                            nan                           nan
# 30029                            nan                           nan
# 30030                            nan                           nan
# 30031                            nan                           nan
# 30032                            nan                           nan
# 30033                            nan                           nan
# 30034                            nan                           nan
# 30035                            nan                           nan
# 30036                            nan                           nan
# 30037                            nan                           nan
# 30038                            nan                           nan
# 30039                            nan                           nan
# 30040                            nan                           nan
# 30041                            nan                           nan
# 30042                            nan                           nan
# 30043                            nan                           nan
# 30044                       16.00000                       3.00000
# 30045                       17.00000                       5.00000
# 30046                       -2.00000                       3.00000
# 30047                       -3.00000                      -4.00000
# 30048                        2.00000                       1.00000
# 30049                        8.00000                       5.00000
# 30050                       15.00000                       1.00000
# 30051                      -20.00000                      -6.00000
# 30052                       -9.00000                      -5.00000
# 30053                        6.00000                       7.00000
# 30054                       -5.00000                       5.00000
# 30055                       18.00000                       9.00000
# 30056                       18.00000                      16.00000
# 30057                       15.00000                      14.00000
# 30058                        2.00000                       9.00000
# 30059                       22.00000                      13.00000
#
#        parks_PCT_CFB  transit_stations_PCT_CFB  workplaces_PCT_CFB  \
# 30020            nan                       nan                 nan
# 30021            nan                       nan                 nan
# 30022            nan                       nan                 nan
# 30023            nan                       nan                 nan
# 30024            nan                       nan                 nan
# 30025            nan                       nan                 nan
# 30026            nan                       nan                 nan
# 30027            nan                       nan                 nan
# 30028            nan                       nan                 nan
# 30029            nan                       nan                 nan
# 30030            nan                       nan                 nan
# 30031            nan                       nan                 nan
# 30032            nan                       nan                 nan
# 30033            nan                       nan                 nan
# 30034            nan                       nan                 nan
# 30035            nan                       nan                 nan
# 30036            nan                       nan                 nan
# 30037            nan                       nan                 nan
# 30038            nan                       nan                 nan
# 30039            nan                       nan                 nan
# 30040            nan                       nan                 nan
# 30041            nan                       nan                 nan
# 30042            nan                       nan                 nan
# 30043            nan                       nan                 nan
# 30044       26.00000                  96.00000            -2.00000
# 30045       42.00000                  18.00000            -7.00000
# 30046       32.00000                   3.00000           -48.00000
# 30047       21.00000                  10.00000             3.00000
# 30048       10.00000                  27.00000             2.00000
# 30049       11.00000                   2.00000             2.00000
# 30050       16.00000                  36.00000             0.00000
# 30051      -42.00000                  -4.00000           -10.00000
# 30052      -17.00000                   3.00000            -1.00000
# 30053        2.00000                  16.00000             2.00000
# 30054        0.00000                  13.00000             3.00000
# 30055        5.00000                   7.00000             3.00000
# 30056       20.00000                   7.00000             3.00000
# 30057        4.00000                   8.00000            -5.00000
# 30058        6.00000                   9.00000            -6.00000
# 30059        3.00000                  29.00000            -2.00000
#
#        residential_PCT_CFB  ...  Deaths_New_28_PER_100K  \
# 30020                  nan  ...                 0.00000
# 30021                  nan  ...                 0.00000
# 30022                  nan  ...                 0.00000
# 30023                  nan  ...                 0.00000
# 30024                  nan  ...                 0.00000
# 30025                  nan  ...                 0.00000
# 30026                  nan  ...                 0.00000
# 30027                  nan  ...                 0.00000
# 30028                  nan  ...                 0.00000
# 30029                  nan  ...                 0.00000
# 30030                  nan  ...                 0.00000
# 30031                  nan  ...                 0.00000
# 30032                  nan  ...                 0.00000
# 30033                  nan  ...                 0.00000
# 30034                  nan  ...                 0.00000
# 30035                  nan  ...                 0.00000
# 30036                  nan  ...                 0.00000
# 30037                  nan  ...                 0.00000
# 30038                  nan  ...                 0.00000
# 30039                  nan  ...                 0.00000
# 30040                  nan  ...                 0.00000
# 30041                  nan  ...                 0.00000
# 30042                  nan  ...                 0.00000
# 30043                  nan  ...                 0.00000
# 30044                  nan  ...                 0.00000
# 30045                  nan  ...                 0.00000
# 30046              5.00000  ...                 0.00000
# 30047              1.00000  ...                 0.00000
# 30048              0.00000  ...                 0.00000
# 30049              1.00000  ...                 0.00000
# 30050             -1.00000  ...                 0.00000
# 30051                  nan  ...                 0.00000
# 30052                  nan  ...                 0.00000
# 30053              1.00000  ...                 0.00000
# 30054              0.00000  ...                 0.00000
# 30055             -1.00000  ...                 0.00000
# 30056             -2.00000  ...                 0.00000
# 30057             -3.00000  ...                 0.00000
# 30058                  nan  ...                 0.00000
# 30059                  nan  ...                 0.00000
#
#        Confirmed_New_PER_100K  Confirmed_New_RollingAvg_PER_100K  \
# 30020                     nan                                nan
# 30021                 0.00000                                nan
# 30022                 0.00000                                nan
# 30023                 0.00000                                nan
# 30024                 0.00000                                nan
# 30025                 0.00000                                nan
# 30026                 0.00000                                nan
# 30027                 0.00000                            0.00000
# 30028                 0.00000                            0.00000
# 30029                 0.00000                            0.00000
# 30030                 0.00000                            0.00000
# 30031                 0.00000                            0.00000
# 30032                 0.00000                            0.00000
# 30033                 0.00000                            0.00000
# 30034                 0.00000                            0.00000
# 30035                 0.00000                            0.00000
# 30036                 0.00000                            0.00000
# 30037                 0.00000                            0.00000
# 30038                 0.00000                            0.00000
# 30039                 0.00000                            0.00000
# 30040                 0.00000                            0.00000
# 30041                 0.00000                            0.00000
# 30042                 0.00000                            0.00000
# 30043                 0.00000                            0.00000
# 30044                 0.00000                            0.00000
# 30045                 0.00000                            0.00000
# 30046                 0.00000                            0.00000
# 30047                 0.00000                            0.00000
# 30048                 0.00000                            0.00000
# 30049                 0.00000                            0.00000
# 30050                 0.00000                            0.00000
# 30051                 0.00000                            0.00000
# 30052                 0.00000                            0.00000
# 30053                 0.00000                            0.00000
# 30054                 0.00000                            0.00000
# 30055                 0.00000                            0.00000
# 30056                 0.00000                            0.00000
# 30057                 0.00000                            0.00000
# 30058                 0.00000                            0.00000
# 30059                 0.00000                            0.00000
#
#        Deaths_New_RollingAvg_PER_100K  Deaths_New_7_RollingAvg_PER_100K  \
# 30020                             nan                               nan
# 30021                             nan                               nan
# 30022                             nan                               nan
# 30023                             nan                               nan
# 30024                             nan                               nan
# 30025                             nan                               nan
# 30026                             nan                           0.00000
# 30027                         0.00000                           0.00000
# 30028                         0.00000                           0.00000
# 30029                         0.00000                           0.00000
# 30030                         0.00000                           0.00000
# 30031                         0.00000                           0.00000
# 30032                         0.00000                           0.00000
# 30033                         0.00000                           0.00000
# 30034                         0.00000                           0.00000
# 30035                         0.00000                           0.00000
# 30036                         0.00000                           0.00000
# 30037                         0.00000                           0.00000
# 30038                         0.00000                           0.00000
# 30039                         0.00000                           0.00000
# 30040                         0.00000                           0.00000
# 30041                         0.00000                           0.00000
# 30042                         0.00000                           0.00000
# 30043                         0.00000                           0.00000
# 30044                         0.00000                           0.00000
# 30045                         0.00000                           0.00000
# 30046                         0.00000                           0.00000
# 30047                         0.00000                           0.00000
# 30048                         0.00000                           0.00000
# 30049                         0.00000                           0.00000
# 30050                         0.00000                           0.00000
# 30051                         0.00000                           0.00000
# 30052                         0.00000                           0.00000
# 30053                         0.00000                           0.00000
# 30054                         0.00000                           0.00000
# 30055                         0.00000                           0.00000
# 30056                         0.00000                           0.00000
# 30057                         0.00000                           0.00000
# 30058                         0.00000                           0.00000
# 30059                         0.00000                           0.00000
#
#        Deaths_New_14_RollingAvg_PER_100K  Deaths_New_21_RollingAvg_PER_100K  \
# 30020                                nan                                nan
# 30021                                nan                                nan
# 30022                                nan                                nan
# 30023                                nan                                nan
# 30024                                nan                                nan
# 30025                                nan                                nan
# 30026                            0.00000                            0.00000
# 30027                            0.00000                            0.00000
# 30028                            0.00000                            0.00000
# 30029                            0.00000                            0.00000
# 30030                            0.00000                            0.00000
# 30031                            0.00000                            0.00000
# 30032                            0.00000                            0.00000
# 30033                            0.00000                            0.00000
# 30034                            0.00000                            0.00000
# 30035                            0.00000                            0.00000
# 30036                            0.00000                            0.00000
# 30037                            0.00000                            0.00000
# 30038                            0.00000                            0.00000
# 30039                            0.00000                            0.00000
# 30040                            0.00000                            0.00000
# 30041                            0.00000                            0.00000
# 30042                            0.00000                            0.00000
# 30043                            0.00000                            0.00000
# 30044                            0.00000                            0.00000
# 30045                            0.00000                            0.00000
# 30046                            0.00000                            0.00000
# 30047                            0.00000                            0.00000
# 30048                            0.00000                            0.00000
# 30049                            0.00000                            0.00000
# 30050                            0.00000                            0.00000
# 30051                            0.00000                            0.00000
# 30052                            0.00000                            0.00000
# 30053                            0.00000                            0.00000
# 30054                            0.00000                            0.00000
# 30055                            0.00000                            0.00000
# 30056                            0.00000                            0.00000
# 30057                            0.00000                            0.00000
# 30058                            0.00000                            0.00000
# 30059                            0.00000                            0.00000
#
#        Deaths_New_28_RollingAvg_PER_100K  Region  Division
# 30020                                nan    West  Mountain
# 30021                                nan    West  Mountain
# 30022                                nan    West  Mountain
# 30023                                nan    West  Mountain
# 30024                                nan    West  Mountain
# 30025                                nan    West  Mountain
# 30026                            0.00000    West  Mountain
# 30027                            0.00000    West  Mountain
# 30028                            0.00000    West  Mountain
# 30029                            0.00000    West  Mountain
# 30030                            0.00000    West  Mountain
# 30031                            0.00000    West  Mountain
# 30032                            0.00000    West  Mountain
# 30033                            0.00000    West  Mountain
# 30034                            0.00000    West  Mountain
# 30035                            0.00000    West  Mountain
# 30036                            0.00000    West  Mountain
# 30037                            0.00000    West  Mountain
# 30038                            0.00000    West  Mountain
# 30039                            0.00000    West  Mountain
# 30040                            0.00000    West  Mountain
# 30041                            0.00000    West  Mountain
# 30042                            0.00000    West  Mountain
# 30043                            0.00000    West  Mountain
# 30044                            0.00000    West  Mountain
# 30045                            0.00000    West  Mountain
# 30046                            0.00000    West  Mountain
# 30047                            0.00000    West  Mountain
# 30048                            0.00000    West  Mountain
# 30049                            0.00000    West  Mountain
# 30050                            0.00000    West  Mountain
# 30051                            0.00000    West  Mountain
# 30052                            0.00000    West  Mountain
# 30053                            0.00000    West  Mountain
# 30054                            0.00000    West  Mountain
# 30055                            0.00000    West  Mountain
# 30056                            0.00000    West  Mountain
# 30057                            0.00000    West  Mountain
# 30058                            0.00000    West  Mountain
# 30059                            0.00000    West  Mountain
#
# [40 rows x 66 columns]

# %%
sns.set_style("whitegrid")


plt.figure(figsize=(10,5)) 
sns.lineplot(x="Date", y="Confirmed_New_RollingAvg_PER_100K", label="Deaths_PER_100K", data=bigh)
sns.lineplot(x="Date", y="Deaths_New_RollingAvg_PER_100K", label="Deaths_PER_100K", data=bigh)
plt.legend(loc="upper left")
plt.show()

# %%
combined_sub[combined_sub.Date.isna() == True]
# Out:
# Empty DataFrame
# Columns: [Date, County_FIPS, State Code, Name, retail_and_recreation_PCT_CFB, grocery_and_pharmacy_PCT_CFB, parks_PCT_CFB, transit_stations_PCT_CFB, workplaces_PCT_CFB, residential_PCT_CFB, retail_and_recreation_PCT_CFB_RollingAvg, grocery_and_pharmacy_PCT_CFB_RollingAvg, parks_PCT_CFB_RollingAvg, transit_stations_PCT_CFB_RollingAvg, workplaces_PCT_CFB_RollingAvg, residential_PCT_CFB_RollingAvg, HS_DIPLOMA_ONLY_2018, SOME_COLLEGE_2018, BACHELORS_PLUS_2018, Poverty_PCT_2018, UrbanCD, Median_Income_2018, Population_ACS, Population_Black_ACS, Population_Hisp_ACS, Population_Native_ACS, PCT_Black_ACS, PCT_Hisp_ACS, PCT_Native_ACS, UrbanCD_Description, Metro, State, Confirmed, Deaths, Deaths_Previous, Confirmed_Previous, Deaths_New, Deaths_New_7, Deaths_New_14, Deaths_New_21, Deaths_New_28, Confirmed_New, locationcol, Confirmed_New_RollingAvg, Deaths_New_RollingAvg, Deaths_New_7_RollingAvg, Deaths_New_14_RollingAvg, Deaths_New_21_RollingAvg, Deaths_New_28_RollingAvg, Confirmed_PER_100K, Deaths_PER_100K, Deaths_Previous_PER_100K, Deaths_New_PER_100K, Deaths_New_7_PER_100K, Deaths_New_14_PER_100K, Deaths_New_21_PER_100K, Deaths_New_28_PER_100K, Confirmed_New_PER_100K, Confirmed_New_RollingAvg_PER_100K, Deaths_New_RollingAvg_PER_100K, Deaths_New_7_RollingAvg_PER_100K, Deaths_New_14_RollingAvg_PER_100K, Deaths_New_21_RollingAvg_PER_100K, Deaths_New_28_RollingAvg_PER_100K, Region, Division]
# Index: []
#
# [0 rows x 66 columns]

# %%
sns.set_style("white")

u_FIPS = list(combined_sub.County_FIPS.unique())
random_FIPS =  random.choice(u_FIPS)

random_df = combined_sub[combined_sub.County_FIPS == random_FIPS]
random_name = combined_sub[combined_sub.County_FIPS == random_FIPS]['Name'].iloc[0]
random_state = combined_sub[combined_sub.County_FIPS == random_FIPS]['State'].iloc[0]

plt.figure(figsize=(10,5)) 
sns.lineplot(x="Date", y="Confirmed_New_RollingAvg_PER_100K", label="Confirmed_New_PER_100K", data=random_df)
sns.lineplot(x="Date", y="Deaths_New_RollingAvg_PER_100K", label="Deaths_New_PER_100K", data=random_df)
plt.legend(loc="upper left")
plt.title("{title}".format(title=random_name.replace('|',', ')))
plt.show()
print(random_FIPS)
# Out:
# 32013

# %%
import random as random

list_counties = list(county[county.Population_ACS >= 100000].County_FIPS.unique())
list_random = random.choices(list_counties, k=4)

# %%
travis = combined_sub[combined_sub.Name=='Travis|Texas']
travis.to_csv("travis.csv")

# %%
combined_sub
# Out:
#              Date County_FIPS State Code             Name  \
# 0      2020-01-22       01001         AL  Autauga|Alabama
# 1      2020-01-23       01001         AL  Autauga|Alabama
# 2      2020-01-24       01001         AL  Autauga|Alabama
# 3      2020-01-25       01001         AL  Autauga|Alabama
# 4      2020-01-26       01001         AL  Autauga|Alabama
# ...           ...         ...        ...              ...
# 989075 2020-11-28       56045         WY   Weston|Wyoming
# 989076 2020-11-29       56045         WY   Weston|Wyoming
# 989077 2020-11-30       56045         WY   Weston|Wyoming
# 989078 2020-12-01       56045         WY   Weston|Wyoming
# 989079 2020-12-02       56045         WY   Weston|Wyoming
#
#         retail_and_recreation_PCT_CFB  grocery_and_pharmacy_PCT_CFB  \
# 0                                 nan                           nan
# 1                                 nan                           nan
# 2                                 nan                           nan
# 3                                 nan                           nan
# 4                                 nan                           nan
# ...                               ...                           ...
# 989075                            nan                           nan
# 989076                            nan                           nan
# 989077                            nan                           nan
# 989078                            nan                           nan
# 989079                            nan                           nan
#
#         parks_PCT_CFB  transit_stations_PCT_CFB  workplaces_PCT_CFB  \
# 0                 nan                       nan                 nan
# 1                 nan                       nan                 nan
# 2                 nan                       nan                 nan
# 3                 nan                       nan                 nan
# 4                 nan                       nan                 nan
# ...               ...                       ...                 ...
# 989075            nan                       nan                 nan
# 989076            nan                       nan                 nan
# 989077            nan                       nan                 nan
# 989078            nan                       nan                 nan
# 989079            nan                       nan                 nan
#
#         residential_PCT_CFB  ...  Deaths_New_28_PER_100K  \
# 0                       nan  ...                 0.00000
# 1                       nan  ...                 0.00000
# 2                       nan  ...                 0.00000
# 3                       nan  ...                 0.00000
# 4                       nan  ...                 0.00000
# ...                     ...  ...                     ...
# 989075                  nan  ...                     nan
# 989076                  nan  ...                     nan
# 989077                  nan  ...                     nan
# 989078                  nan  ...                     nan
# 989079                  nan  ...                     nan
#
#         Confirmed_New_PER_100K  Confirmed_New_RollingAvg_PER_100K  \
# 0                          nan                                nan
# 1                      0.00000                                nan
# 2                      0.00000                                nan
# 3                      0.00000                                nan
# 4                      0.00000                                nan
# ...                        ...                                ...
# 989075                 0.00000                           60.21799
# 989076                 0.00000                           48.17439
# 989077                14.05086                           50.18166
# 989078               168.61037                           52.18892
# 989079                84.30518                           58.21072
#
#         Deaths_New_RollingAvg_PER_100K  Deaths_New_7_RollingAvg_PER_100K  \
# 0                                  nan                               nan
# 1                                  nan                               nan
# 2                                  nan                               nan
# 3                                  nan                               nan
# 4                                  nan                               nan
# ...                                ...                               ...
# 989075                         2.00727                               nan
# 989076                         2.00727                               nan
# 989077                         0.00000                               nan
# 989078                         2.00727                               nan
# 989079                         2.00727                               nan
#
#         Deaths_New_14_RollingAvg_PER_100K  Deaths_New_21_RollingAvg_PER_100K  \
# 0                                     nan                                nan
# 1                                     nan                                nan
# 2                                     nan                                nan
# 3                                     nan                                nan
# 4                                     nan                                nan
# ...                                   ...                                ...
# 989075                                nan                                nan
# 989076                                nan                                nan
# 989077                                nan                                nan
# 989078                                nan                                nan
# 989079                                nan                                nan
#
#         Deaths_New_28_RollingAvg_PER_100K  Region            Division
# 0                                     nan   South  East South Central
# 1                                     nan   South  East South Central
# 2                                     nan   South  East South Central
# 3                                     nan   South  East South Central
# 4                                     nan   South  East South Central
# ...                                   ...     ...                 ...
# 989075                                nan    West            Mountain
# 989076                                nan    West            Mountain
# 989077                                nan    West            Mountain
# 989078                                nan    West            Mountain
# 989079                                nan    West            Mountain
#
# [989080 rows x 66 columns]

# %%
for i in list_random:
    sns.set_style("white")
    bigh = combined_sub[combined_sub['County_FIPS'] == i]
    bigh = bigh[bigh.Date <= '2020-11-20']
    bigh = bigh[bigh.Date >= '2020-06-01']
    name_county = bigh.Name.iloc[0]
    plt.figure(figsize=(12,3)) 
    ax = sns.lineplot(x="Date", y="Confirmed_New_RollingAvg_PER_100K", label="Confirmed", data=bigh)
    plt.legend(loc="upper right")
    ax2 = ax.twinx()
    ax2 = sns.lineplot(x="Date", y="Deaths_New_7_RollingAvg_PER_100K", label="Deaths", color='red', data=bigh)
    ax2 = sns.lineplot(x="Date", y="Deaths_New_14_RollingAvg_PER_100K", label="Deaths", color='orange', data=bigh)
    plt.title("{x} - 2020-06 to 2020-10".format(x=name_county.replace('|',' County, ')))
    plt.legend(loc="upper left")
    plt.show()

# %%
list_tup = []
for i in range(4,9):
    a = '2020-0{c}-01'.format(c=i)
    b = '2020-0{c}-01'.format(c=i+1)
    list_tup.append((a,b))

for i in range(10,12):
    a = '2020-{c}-01'.format(c=i)
    b = '2020-{c}-01'.format(c=i+1)
    list_tup.append((a,b))

# %%
list_tup
# Out:
# [('2020-04-01', '2020-05-01'),
#  ('2020-05-01', '2020-06-01'),
#  ('2020-06-01', '2020-07-01'),
#  ('2020-07-01', '2020-08-01'),
#  ('2020-08-01', '2020-09-01'),
#  ('2020-10-01', '2020-11-01'),
#  ('2020-11-01', '2020-12-01')]

# %% [markdown]
# ## Make the county level dataframe population - weighted

# %% [markdown]
# In the county-level dataset, each county is represented by one row. However, to do density analysis, this view is misleading because of the extreme inequality of county populations. To remedy this, we can explode the dataset to give each county a row in the dataset for each 1,000 residents.

# %%
sns.displot(county.Population_ACS, kind="kde").set(xscale = 'log')

# %%
list_frame = []

from tqdm import tqdm

for i in tqdm(list(county.County_FIPS.unique())):
    frame = county[county.County_FIPS == i]
    frame['pop_1k'] = frame['Population_ACS']/1000 # Each row will represent 1k people
    frame['key'] = 'key'
    joinframe = pd.DataFrame(pd.Series(list(range(0,int(frame.pop_1k.max())))))
    joinframe['key'] = 'key'
    joinframe.columns = ['val','key']
    cartesian = frame.merge(joinframe, on="key")
    #frame_weighted = cartesian[cartesian.Deaths <= cartesian.val]
    list_frame.append(cartesian)

# %%
frame_concat = pd.concat(list_frame)

# %%
frame_concat.shape[0]
# roughly one row per 1,000 inhabitants of the US

# %%
plt.figure(figsize=(16,9)) 
frame = frame_concat.sample(frac=.1)
frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro","Noncore_adjacent"])]
frame.sort_values(by="Metro", inplace=True)
#frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro"])]
frame = frame.sort_values(by="Metro")
#sns.violinplot(x="Metro", y="Deaths_PER_100K", label="work", data=frame, scale="count")
sns.boxplot(x="Metro", y="Deaths_PER_100K", data=frame,  boxprops={'facecolor':'None'}, fliersize=0)
sns.stripplot(x="Metro", y="Deaths_PER_100K", label="work", data=frame.sample(frac=.05), size=6, alpha=.4, dodge=True, palette="viridis")
plt.show()

# %%
plt.figure(figsize=(18,9)) 
frame = frame_concat.sample(frac=.1)
frame.sort_values(by="Division", inplace=True)
frame = frame.sort_values(by="Region")
sns.violinplot(x="Division", y="Deaths_PER_100K", label="work", data=frame)
sns.boxplot(x="Division", y="Deaths_PER_100K", data=frame,  boxprops={'facecolor':'None'}, fliersize=0)
#sns.swarmplot(x="Division", y="Deaths_PER_100K", label="work", data=frame, size=.5, alpha=.6, dodge=True, palette="viridis")
plt.show()

# %%
plt.figure(figsize=(18,9)) 
frame = frame_concat[frame_concat.Division == "New England"].sample(frac=.1)
frame.sort_values(by="Metro", inplace=True)
ax = sns.violinplot(x="Metro", y="Deaths_PER_100K", label="work", palette="viridis", alpha=.2, scale="count", data=frame)
#sns.boxplot(x="Metro", y="Deaths_PER_100K", data=frame,  boxprops={'facecolor':'None'}, fliersize=0)
#ax = sns.swarmplot(x="Metro", y="Deaths_PER_100K", label="work", data=frame, size=2, dodge=True, palette="viridis")
plt.setp(ax.collections, alpha=.3)
plt.show()

# %%
import numpy as np
from matplotlib.patches import PathPatch

def adjust_box_widths(g, fac):
    """
    Adjust the widths of a seaborn-generated boxplot.
    """

    # iterating through Axes instances
    for ax in g.axes:

        # iterating through axes artists:
        for c in ax.get_children():

            # searching for PathPatches
            if isinstance(c, PathPatch):
                # getting current width of box:
                p = c.get_path()
                verts = p.vertices
                verts_sub = verts[:-1]
                xmin = np.min(verts_sub[:, 0])
                xmax = np.max(verts_sub[:, 0])
                xmid = 0.5*(xmin+xmax)
                xhalf = 0.5*(xmax - xmin)

                # setting new width of box
                xmin_new = xmid-fac*xhalf
                xmax_new = xmid+fac*xhalf
                verts_sub[verts_sub[:, 0] == xmin, 0] = xmin_new
                verts_sub[verts_sub[:, 0] == xmax, 0] = xmax_new

                # setting new width of median line
                for l in ax.lines:
                    if np.all(l.get_xdata() == [xmin, xmax]):
                        l.set_xdata([xmin_new, xmax_new])

# %%
def boxplot_with_violins(df, Yvar = "Deaths_PER_100K", group="Region"):
    frame = df
    frame = frame.sort_values(by=group)
    #frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro","Noncore_adjacent"])]

    fig = plt.figure(figsize=(9,6))

    ax = sns.boxplot(x=group, y=Yvar, data=frame, boxprops={'facecolor':'None'}, fliersize=0)
    ax = sns.violinplot(x=group, y=Yvar, scale="count", data=frame, inner="quart", despine=True)

    plt.setp(ax.collections, alpha=.4)
    plt.ylim(-10,frame["{Yvar}".format(Yvar=Yvar)].max()*.95)

    adjust_box_widths(fig, 0.9)
    
    fig.show()

# %%
def upper_limit(series):
    from scipy.stats import iqr
    import numpy as np
    Q3 = np.percentile(series, 75, interpolation = 'midpoint') 
    return int(Q3+(4*iqr(series)))

# %%
def boxplot_with_violins_grp(df, Yvar = "Deaths_PER_100K",  group="Region"):
    frame = df
    frame = frame.sort_values(by=group)
    #frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro","Noncore_adjacent"])]

    fig = plt.figure(figsize=(24,12))
    
    ax = sns.boxplot(x=group, y=Yvar, hue="Metro", data=frame, boxprops={'facecolor':'None'}, fliersize=0)
    ax = sns.violinplot(x=group, y=Yvar, hue="Metro", scale="count", data=frame, inner="quart", despine=True)

    #Make legend distinct 
    handles, labels = ax.get_legend_handles_labels()
    num_legend = len(df["{x}".format(x=group)].unique())
    plt.legend(handles[0:num_legend], labels[0:num_legend], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    plt.setp(ax.collections, alpha=.4)
    
    #plt.ylim(-10,frame["{Yvar}".format(Yvar=Yvar)].max()*.75)
   
    upper_limit_number = upper_limit(frame["{Yvar}".format(Yvar=Yvar)])
    plt.ylim(-10,upper_limit_number)
    adjust_box_widths(fig, 0.8)
    #plt.legend()
    fig.show()

# %%
boxplot_with_violins_grp(frame_concat,Yvar = "Confirmed_PER_100K")

# %%
frame = frame_concat.sample(frac=.1)
#frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro","Noncore_adjacent"])]
#plt.figure(figsize=(22,9)) 

fig = plt.figure(figsize=(22, 9))

ax = sns.boxplot(x="Region", y="Deaths_PER_100K", data=frame, boxprops={'facecolor':'None'}, fliersize=0)
ax = sns.swarmplot(x="Region", y="Deaths_PER_100K",  alpha=.95, data=frame, size=.75, dodge=True)
#plt.setp(ax.collections, alpha=.9)
plt.ylim(-10,frame.Deaths_PER_100K.max()*1.1)

adjust_box_widths(fig, 0.9)

# %%
frame_concat.columns

# %%
frame = frame_concat
frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro","Noncore_adjacent"])]
#plt.figure(figsize=(22,9)) 

fig = plt.figure(figsize=(22, 9))

#ax = sns.boxplot(x="Division", y="Confirmed_New_RollingAvg_PER_100K", hue="Metro", data=frame, fliersize=0)
ax = sns.violinplot(x="Division", y="Confirmed_New_RollingAvg_PER_100K",  hue="Metro", scale="count", data=frame, inner="quart", size=2, dodge=True, despine=True)
plt.setp(ax.collections, alpha=.4)
plt.ylim(-10,150)

adjust_box_widths(fig, 0.9)

# %%
pop = pd.DataFrame(frame.groupby(["Division"])["Population_ACS"].sum())

# %%
frame = frame_concat.sample(frac=.1)
frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro"])]
#plt.figure(figsize=(22,9)) 

fig = plt.figure(figsize=(22, 9))

ax = sns.boxplot(x="Region", y="Deaths_New_7_RollingAvg_PER_100K", hue="Metro", data=frame, boxprops={'facecolor':'None'}, fliersize=0)
ax = sns.violinplot(x="Region", y="Deaths_New_7_RollingAvg_PER_100K",  hue="Metro", scale="count", data=frame, inner="quart", size=2, dodge=True, despine=True)
plt.setp(ax.collections, alpha=.4)
plt.ylim(-1,2.5)

adjust_box_widths(fig, 0.9)

# %%
sns.distplot(frame.Deaths_New_7_RollingAvg_PER_100K)

# %%
combined_sub['week_of_yr'] = combined_sub.date.dt.week

# %%
cols = list(combined_sub.columns)

list_df = [] 

for i in tqdm(range(12,combined_sub.week_of_yr.max())):
    county = combined_sub[(combined_sub.week_of_yr == i)]
    date = county.date.max()
    county = county.groupby(["County_FIPS","Metro","Division","StateCD"])[cols].mean()
    county = pd.DataFrame(county)
    county['date'] = date
    county.reset_index(inplace=True)
    list_df.append(county)

# %%
list_df[2] #.Metro

# %%
def explode_df_pop_weight(df):
    list_frame  = []
    for i in tqdm(list(df.County_FIPS.unique())):
        frame = df[df.County_FIPS == i]
        frame['pop_1k'] = frame['Population_ACS']/1000 # Each row will represent 1k people
        frame['key'] = 'key'
        joinframe = pd.DataFrame(pd.Series(list(range(0,int(frame.pop_1k.max())))))
        joinframe['key'] = 'key'
        joinframe.columns = ['val','key']
        cartesian = frame.merge(joinframe, on="key")
        list_frame.append(cartesian)
    exploded_frame = pd.concat(list_frame)
    return exploded_frame

# %%
exp = explode_df_pop_weight(list_df[2])

# %%
list_exploded_df = [explode_df_dateweight(i) for i in list_df]

# %%
colslist = list(list_exploded_df[2].columns)
Yvarlist = [i for i in colslist if "RollingAvg" in i]

# %%
colslist

# %%
Yvar_list = [
 #'retail_and_recreation_PCT_CFB_RollingAvg',
 #'grocery_and_pharmacy_PCT_CFB_RollingAvg',
 #'parks_PCT_CFB_RollingAvg',
 #'transit_stations_PCT_CFB_RollingAvg',
 'workplaces_PCT_CFB_RollingAvg',
 'residential_PCT_CFB_RollingAvg',
 'Confirmed_New_RollingAvg_PER_100K',
 'Deaths_New_RollingAvg_PER_100K']

# %%
grouplist = ['Metro','Region']

# %%
import os
os.getcwd()
os.chdir("/Users/philip.ballentine/Documents/grphimg")

# %%
#conda install -c conda-forge imageio

# %%
def gif_from_images(animated_filename="movie.gif"):
    """ goes into the working directory (set earlier) and combined all images into an animated gif"""
    import imageio
    image_list = sorted(os.listdir(os.getcwd()))
    image_list_sub = [i for i in image_list if '2020' in i]
    images = []
    for filename in image_list_sub:
        images.append(imageio.imread(filename))
    imageio.mimsave(animated_filename+'.gif', images, duration=.5)

# %%
combined_sub.columns

# %%
combined_sub['retail_and_recreation_PCT_CFB'].quantile(.10)

# %%
combined_sub['retail_and_recreation_PCT_CFB'].quantile(.9)

# %%
def loop_for_gif_by_metro(Yvar="Deaths_PER_100K", group="Metro"):
    
    ## Creating file structure
    import os 
    foldername = "{Yvar}_by_{group}".format(Yvar=Yvar, group=group)
    try:
        os.chdir("/Users/philip.ballentine/Documents/grphimg/{foldername}".format(foldername=foldername))
    except:
        os.mkdir("/Users/philip.ballentine/Documents/grphimg/{foldername}".format(foldername=foldername))
        os.chdir("/Users/philip.ballentine/Documents/grphimg/{foldername}".format(foldername=foldername))
    
    ## Iterating through dataframes and creating the plots
    for i in tqdm(random.choices(list_exploded_df, k= 3)):
    #for i in tqdm(list_exploded_df): 
        frame = i
        frame = frame.sort_values(by='{group}'.format(group=group))
        fig = plt.figure(figsize=(9, 6))
        #frame = frame[frame.Metro.isin(["Large_metro","Micropolitan","Smaller_metro"])]
        ax = sns.boxplot(x=group, y=Yvar, data=frame, boxprops={'facecolor':'None'}, fliersize=0)
        ax = sns.violinplot(x=group, y=Yvar, scale="count", data=frame, inner="quart", dodge=True, despine=True)

        plt.setp(ax.collections, alpha=.4)
        ## Setting the Y-Lims
        #if "PCT" in Yvar:
            #plt.ylim(combined_sub['{Yvar}'.format(Yvar=Yvar)].min(),combined_sub['{Yvar}'.format(Yvar=Yvar)].max())
            #quant10 = combined_sub['{Yvar}'.format(Yvar=Yvar)].quantile(.1)
            #quant90 = combined_sub['{Yvar}'.format(Yvar=Yvar)].quantile(.9)
            #plt.ylim(quant10,quant90)
        #if "Confirmed" in Yvar: 
            #stdev = combined_sub['{Yvar}'.format(Yvar=Yvar)].std()
            #mean = combined_sub['{Yvar}'.format(Yvar=Yvar)].mean()
            #limits = ((mean-(stdev*3)),(mean+(stdev*3)))
            #quant10 = combined_sub['{Yvar}'.format(Yvar=Yvar)].quantile(.1)
            #quant90 = combined_sub['{Yvar}'.format(Yvar=Yvar)].quantile(.9)
            #plt.ylim(quant10,quant90)
       # else: 
            #stdev = combined_sub['{Yvar}'.format(Yvar=Yvar)].std()
            #plt.ylim(-1,combined_sub['{Yvar}'.format(Yvar=Yvar)].mean()+(5*stdev))
        
        ## Titles and file saving
        datestr = str(i.date.max())[0:11]
        plt.title("{datestr} - {Yvar} by {group}, Population Weighted".format(datestr=datestr, Yvar=Yvar, group=group))
        plt.tight_layout()
        plt.savefig("{datestr}.png".format(datestr=datestr), dpi=300)
        #print("{datestr}.png has been created in {foldername}".format(datestr=datestr, foldername=foldername))

## Animated GIF creation
    gif_from_images(animated_filename=foldername)

# %%
loop_for_gif_by_metro("retail_and_recreation_PCT_CFB", group="Metro")

# %%
all_combo_list = []
for i in Yvar_list:
    for x in grouplist:
        all_combo_list.append((i,x))

# %%
all_combo_list

# %%
for i in all_combo_list:
    try:
        loop_for_gif_by_metro(Yvar=i[0], group=i[1])
    except:
        print("failure for {x}".format(x=str(i)))
        continue
